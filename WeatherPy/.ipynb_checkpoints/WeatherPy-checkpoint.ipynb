# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Adding a counter to call in sets of 50
counter = 0

print("Beginning Data Retrieval")
print("-------------------------------------")
# Making a request for each city
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 1 | {cities[x]}")
    counter += 1
    if counter == 50:
        break
        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 2 | {cities[x + 50]}")
    counter += 1
    if counter == 50:
        break
        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 3 | {cities[x + 100]}")
    counter += 1
    if counter == 50:
        break
        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 4 | {cities[x + 150]}")
    counter += 1
    if counter == 50:
        break
        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 5 | {cities[x + 200]}")
    counter += 1
    if counter == 50:
        break
        
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record 0 of Set 1 | mataura
# Processing Record 1 of Set 1 | ponta do sol
# Processing Record 2 of Set 1 | lalomanu
# Processing Record 3 of Set 1 | vila velha
# Processing Record 4 of Set 1 | busselton
# Processing Record 5 of Set 1 | saint stephen
# Processing Record 6 of Set 1 | crab hill
# Processing Record 7 of Set 1 | cabedelo
# Processing Record 8 of Set 1 | madimba
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | severo-kurilsk
# Processing Record 11 of Set 1 | redcliffe
# Processing Record 12 of Set 1 | mutsamudu
# Processing Record 13 of Set 1 | manono
# Processing Record 14 of Set 1 | saskylakh
# Processing Record 15 of Set 1 | owando
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | hutchinson
# Processing Record 18 of Set 1 | kupang
# Processing Record 19 of Set 1 | clyde river
# Processing Record 20 of Set 1 | byron bay
# Processing Record 21 of Set 1 | vila franca do campo
# Processing Record 22 of Set 1 | hokitika
# Processing Record 23 of Set 1 | canutama
# Processing Record 24 of Set 1 | chicama
# Processing Record 25 of Set 1 | san cristobal
# Processing Record 26 of Set 1 | okato
# Processing Record 27 of Set 1 | amderma
# Processing Record 28 of Set 1 | zharkent
# Processing Record 29 of Set 1 | east london
# Processing Record 30 of Set 1 | panaba
# Processing Record 31 of Set 1 | ballina
# Processing Record 32 of Set 1 | longyearbyen
# Processing Record 33 of Set 1 | butaritari
# Processing Record 34 of Set 1 | rio grande
# Processing Record 35 of Set 1 | imbituba
# Processing Record 36 of Set 1 | durango
# Processing Record 37 of Set 1 | albany
# Processing Record 38 of Set 1 | tasiilaq
# Processing Record 39 of Set 1 | pontal do parana
# Processing Record 40 of Set 1 | grand river south east
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | norman wells
# Processing Record 44 of Set 1 | nizhneyansk
# Processing Record 45 of Set 1 | vardo
# Processing Record 46 of Set 1 | marcona
# Processing Record 47 of Set 1 | yar-sale
# Processing Record 48 of Set 1 | rikitea
# Processing Record 49 of Set 1 | port elizabeth
# Processing Record 0 of Set 2 | moberly
# Processing Record 1 of Set 2 | fort-shevchenko
# Processing Record 2 of Set 2 | avarua
# Processing Record 3 of Set 2 | rabaul
# Processing Record 4 of Set 2 | cidreira
# Processing Record 5 of Set 2 | thompson
# Processing Record 6 of Set 2 | alyangula
# Processing Record 7 of Set 2 | cherskiy
# Processing Record 8 of Set 2 | lompoc
# Processing Record 9 of Set 2 | atuona
# Processing Record 10 of Set 2 | marawi
# Processing Record 11 of Set 2 | belushya guba
# Processing Record 12 of Set 2 | port moresby
# Processing Record 13 of Set 2 | castro
# Processing Record 14 of Set 2 | buala
# Processing Record 15 of Set 2 | khatanga
# Processing Record 16 of Set 2 | arraial do cabo
# Processing Record 17 of Set 2 | mount gambier
# Processing Record 18 of Set 2 | tezu
# Processing Record 19 of Set 2 | barrow
# Processing Record 20 of Set 2 | nikolskoye
# Processing Record 21 of Set 2 | mys shmidta
# Processing Record 22 of Set 2 | honiara
# Processing Record 23 of Set 2 | yushu
# Processing Record 24 of Set 2 | klaksvik
# Processing Record 25 of Set 2 | vanderhoof
# Processing Record 26 of Set 2 | christchurch
# Processing Record 27 of Set 2 | tuktoyaktuk
# Processing Record 28 of Set 2 | georgetown
# Processing Record 29 of Set 2 | qaanaaq
# Processing Record 30 of Set 2 | bengkulu
# Processing Record 31 of Set 2 | staraya kulatka
# Processing Record 32 of Set 2 | vaini
# Processing Record 33 of Set 2 | qeshm
# Processing Record 34 of Set 2 | torbay
# Processing Record 35 of Set 2 | geraldton
# Processing Record 36 of Set 2 | baoding
# Processing Record 37 of Set 2 | kruisfontein
# Processing Record 38 of Set 2 | wanning
# Processing Record 39 of Set 2 | yanchukan
# Processing Record 40 of Set 2 | sur
# Processing Record 41 of Set 2 | kaspiyskiy
# Processing Record 42 of Set 2 | victoria
# Processing Record 43 of Set 2 | oussouye
# Processing Record 44 of Set 2 | bacolod
# Processing Record 45 of Set 2 | arbagar
# Processing Record 46 of Set 2 | kahului
# Processing Record 47 of Set 2 | ribeira grande
# Processing Record 48 of Set 2 | esperance
# Processing Record 49 of Set 2 | caravelas
# Processing Record 0 of Set 3 | palabuhanratu
# Processing Record 1 of Set 3 | mpika
# Processing Record 2 of Set 3 | talnakh
# Processing Record 3 of Set 3 | evensk
# Processing Record 4 of Set 3 | virginia beach
# Processing Record 5 of Set 3 | tahta
# Processing Record 6 of Set 3 | mumford
# Processing Record 7 of Set 3 | novotalitsy
# Processing Record 8 of Set 3 | duz
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | medowie
# Processing Record 11 of Set 3 | bumba
# Processing Record 12 of Set 3 | cape town
# Processing Record 13 of Set 3 | yaan
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | centralia
# Processing Record 16 of Set 3 | ibia
# Processing Record 17 of Set 3 | puerto ayora
# Processing Record 18 of Set 3 | vaitupu
# Processing Record 19 of Set 3 | nome
# Processing Record 20 of Set 3 | chuy
# Processing Record 21 of Set 3 | kushiro
# Processing Record 22 of Set 3 | ati
# Processing Record 23 of Set 3 | nouadhibou
# Processing Record 24 of Set 3 | sao filipe
# Processing Record 25 of Set 3 | guerrero negro
# Processing Record 26 of Set 3 | barentsburg
# Processing Record 27 of Set 3 | labuhan
# Processing Record 28 of Set 3 | port alfred
# Processing Record 29 of Set 3 | taolanaro
# Processing Record 30 of Set 3 | ngukurr
# Processing Record 31 of Set 3 | bluff
# Processing Record 32 of Set 3 | codrington
# Processing Record 33 of Set 3 | alice town
# Processing Record 34 of Set 3 | saint anthony
# Processing Record 35 of Set 3 | beringovskiy
# Processing Record 36 of Set 3 | kaitangata
# Processing Record 37 of Set 3 | faanui
# Processing Record 38 of Set 3 | jamestown
# Processing Record 39 of Set 3 | hasaki
# Processing Record 40 of Set 3 | marsa matruh
# Processing Record 41 of Set 3 | venice
# Processing Record 42 of Set 3 | tsihombe
# Processing Record 43 of Set 3 | caconda
# Processing Record 44 of Set 3 | tilichiki
# Processing Record 45 of Set 3 | sindand
# Processing Record 46 of Set 3 | sol-iletsk
# Processing Record 47 of Set 3 | porto novo
# Processing Record 48 of Set 3 | bobrov
# Processing Record 49 of Set 3 | kamen-rybolov
# Processing Record 0 of Set 4 | aklavik
# Processing Record 1 of Set 4 | celestun
# Processing Record 2 of Set 4 | emirdag
# Processing Record 3 of Set 4 | praia
# Processing Record 4 of Set 4 | lagoa
# Processing Record 5 of Set 4 | kodiak
# Processing Record 6 of Set 4 | jiexiu
# Processing Record 7 of Set 4 | touros
# Processing Record 8 of Set 4 | kampong chhnang
# Processing Record 9 of Set 4 | hohhot
# Processing Record 10 of Set 4 | aleksandrov gay
# Processing Record 11 of Set 4 | aykhal
# Processing Record 12 of Set 4 | abu dhabi
# Processing Record 13 of Set 4 | hobart
# Processing Record 14 of Set 4 | ahipara
# Processing Record 15 of Set 4 | kailua
# Processing Record 16 of Set 4 | provideniya
# Processing Record 17 of Set 4 | santa catarina de tepehuanes
# Processing Record 18 of Set 4 | veinticinco de mayo
# Processing Record 19 of Set 4 | iracoubo
# Processing Record 20 of Set 4 | lebu
# Processing Record 21 of Set 4 | salekhard
# Processing Record 22 of Set 4 | illoqqortoormiut
# Processing Record 23 of Set 4 | oyonnax
# Processing Record 24 of Set 4 | lepe
# Processing Record 25 of Set 4 | hofn
# Processing Record 26 of Set 4 | hilo
# Processing Record 27 of Set 4 | fortuna
# Processing Record 28 of Set 4 | imperial beach
# Processing Record 29 of Set 4 | bredasdorp
# Processing Record 30 of Set 4 | macaboboni
# Processing Record 31 of Set 4 | goure
# Processing Record 32 of Set 4 | candolim
# Processing Record 33 of Set 4 | champasak
# Processing Record 34 of Set 4 | thinadhoo
# Processing Record 35 of Set 4 | kapaa
# Processing Record 36 of Set 4 | bogatyye saby
# Processing Record 37 of Set 4 | raudeberg
# Processing Record 38 of Set 4 | diu
# Processing Record 39 of Set 4 | samusu
# Processing Record 40 of Set 4 | adwa
# Processing Record 41 of Set 4 | mitu
# Processing Record 42 of Set 4 | lolua
# Processing Record 43 of Set 4 | bambous virieux
# Processing Record 44 of Set 4 | samarai
# Processing Record 45 of Set 4 | acapulco
# Processing Record 46 of Set 4 | bahia honda
# Processing Record 47 of Set 4 | taoudenni
# Processing Record 48 of Set 4 | sitka
# Processing Record 49 of Set 4 | palmerston
# Processing Record 0 of Set 5 | iqaluit
# Processing Record 1 of Set 5 | te anau
# Processing Record 2 of Set 5 | ostrovnoy
# Processing Record 3 of Set 5 | ossora
# Processing Record 4 of Set 5 | ilebo
# Processing Record 5 of Set 5 | ucluelet
# Processing Record 6 of Set 5 | araouane
# Processing Record 7 of Set 5 | boende
# Processing Record 8 of Set 5 | attawapiskat
# Processing Record 9 of Set 5 | helong
# Processing Record 10 of Set 5 | polewali
# Processing Record 11 of Set 5 | jumilla
# Processing Record 12 of Set 5 | saint-philippe
# Processing Record 13 of Set 5 | carnarvon
# Processing Record 14 of Set 5 | goundam
# Processing Record 15 of Set 5 | estepona
# Processing Record 16 of Set 5 | johor bahru
# Processing Record 17 of Set 5 | tual
# Processing Record 18 of Set 5 | merrill
# Processing Record 19 of Set 5 | new norfolk
# Processing Record 20 of Set 5 | seoul
# Processing Record 21 of Set 5 | weligama
# Processing Record 22 of Set 5 | isla mujeres
# Processing Record 23 of Set 5 | hjelset
# Processing Record 24 of Set 5 | deltona
# Processing Record 25 of Set 5 | staryy nadym
# Processing Record 26 of Set 5 | champerico
# Processing Record 27 of Set 5 | pacific grove
# Processing Record 28 of Set 5 | klupci
# Processing Record 29 of Set 5 | kristiinankaupunki
# Processing Record 30 of Set 5 | varhaug
# Processing Record 31 of Set 5 | shenjiamen
# Processing Record 32 of Set 5 | tiksi
# Processing Record 33 of Set 5 | upernavik
# Processing Record 34 of Set 5 | atambua
# Processing Record 35 of Set 5 | dunmore town
# Processing Record 36 of Set 5 | sao bartolomeu de messines
# Processing Record 37 of Set 5 | san quintin
# Processing Record 38 of Set 5 | ambilobe
# Processing Record 39 of Set 5 | kuusamo
# Processing Record 40 of Set 5 | north salt lake
# Processing Record 41 of Set 5 | walvis bay
# Processing Record 42 of Set 5 | nguru
# Processing Record 43 of Set 5 | manacor
# Processing Record 44 of Set 5 | chokurdakh
# Processing Record 45 of Set 5 | leningradskiy
# Processing Record 46 of Set 5 | hay river
# Processing Record 47 of Set 5 | monte alegre de sergipe
# Processing Record 48 of Set 5 | brae
# Processing Record 49 of Set 5 | uaua
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
query_url = f"{url}&appid={weather_api_key}&q="
print(query_url)

#Creating an empty list to store procossing log
city_name = []
cloudiness =[]
country = []
date = []
humidity =[]
lat = []
lng = []
max_temp = []
wind_speed = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city)
    response_json = response.json()
    print(json.dumps(response_json, indent=4, sort_keys=True))
    try:
        city_name.append(response_json['name'])
        cloudiness.append(response_json['clouds']['all'])
        country.append(response_json['sys']['country'])
        date.append(response_json['dt'])
        humidity.append(response_json['main']['humidity'])
        lat.append(response_json['coord']['lat'])
        lng.append(response_json['coord']['lon'])
        max_temp.append(response_json['main']['temp_max'])
        wind_speed.append(response_json['wind']['speed'])
    except:
        print("City not found")
        pass
# Out:
# https://api.openweathermap.org/data/2.5/weather?&appid=3c69e2440c645c6447da4ba851075ac7&q=
# {
#     "base": "model",
#     "clouds": {
#         "all": 65
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.19,
#         "lon": 168.86
#     },
#     "dt": 1581891927,
#     "id": 6201424,
#     "main": {
#         "feels_like": 294.31,
#         "grnd_level": 991,
#         "humidity": 82,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 292.54,
#         "temp_max": 292.54,
#         "temp_min": 292.54
#     },
#     "name": "Mataura",
#     "sys": {
#         "country": "NZ",
#         "sunrise": 1581876062,
#         "sunset": 1581926192
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 103,
#         "speed": 0.44
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 32.67,
#         "lon": -17.1
#     },
#     "dt": 1581891723,
#     "id": 2264557,
#     "main": {
#         "feels_like": 286.79,
#         "humidity": 72,
#         "pressure": 1029,
#         "temp": 288.76,
#         "temp_max": 291.15,
#         "temp_min": 286.48
#     },
#     "name": "Ponta do Sol",
#     "sys": {
#         "country": "PT",
#         "id": 6894,
#         "sunrise": 1581839475,
#         "sunset": 1581879242,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 20,
#         "speed": 3.1
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.33,
#         "lon": -40.29
#     },
#     "dt": 1581891929,
#     "id": 3445026,
#     "main": {
#         "feels_like": 304.69,
#         "humidity": 83,
#         "pressure": 1013,
#         "temp": 300.99,
#         "temp_max": 302.04,
#         "temp_min": 300.15
#     },
#     "name": "Vila Velha",
#     "sys": {
#         "country": "BR",
#         "id": 8474,
#         "sunrise": 1581841977,
#         "sunset": 1581887871,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "speed": 3.6
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.65,
#         "lon": 115.33
#     },
#     "dt": 1581891929,
#     "id": 2075265,
#     "main": {
#         "feels_like": 280.48,
#         "humidity": 60,
#         "pressure": 1015,
#         "temp": 285.29,
#         "temp_max": 286.48,
#         "temp_min": 283.71
#     },
#     "name": "Busselton",
#     "sys": {
#         "country": "AU",
#         "id": 2011706,
#         "sunrise": 1581890126,
#         "sunset": 1581937821,
#         "type": 3
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 139,
#         "speed": 5.15
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 50.33,
#         "lon": -4.9
#     },
#     "dt": 1581891929,
#     "id": 2638698,
#     "main": {
#         "feels_like": 270.4,
#         "humidity": 65,
#         "pressure": 1005,
#         "temp": 280.77,
#         "temp_max": 281.48,
#         "temp_min": 278.71
#     },
#     "name": "Saint Stephen",
#     "sys": {
#         "country": "GB",
#         "id": 1403,
#         "sunrise": 1581838225,
#         "sunset": 1581874637,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 9000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "gust": 18,
#         "speed": 12.3
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -6.98,
#         "lon": -34.83
#     },
#     "dt": 1581891763,
#     "id": 3404558,
#     "main": {
#         "feels_like": 302.43,
#         "humidity": 78,
#         "pressure": 1012,
#         "temp": 300.15,
#         "temp_max": 300.15,
#         "temp_min": 300.15
#     },
#     "name": "Cabedelo",
#     "sys": {
#         "country": "BR",
#         "id": 8391,
#         "sunrise": 1581841435,
#         "sunset": 1581885792,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 4.1
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -10.4,
#         "lon": 40.33
#     },
#     "dt": 1581891930,
#     "id": 878141,
#     "main": {
#         "feels_like": 304.65,
#         "humidity": 88,
#         "pressure": 1011,
#         "temp": 300.15,
#         "temp_max": 300.15,
#         "temp_min": 300.15
#     },
#     "name": "Madimba",
#     "sys": {
#         "country": "TZ",
#         "id": 2617,
#         "sunrise": 1581909619,
#         "sunset": 1581954326,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 350,
#         "speed": 2.6
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 62.46,
#         "lon": -114.35
#     },
#     "dt": 1581891854,
#     "id": 6185377,
#     "main": {
#         "feels_like": 235.69,
#         "humidity": 67,
#         "pressure": 1020,
#         "temp": 243.15,
#         "temp_max": 243.15,
#         "temp_min": 243.15
#     },
#     "name": "Yellowknife",
#     "sys": {
#         "country": "CA",
#         "id": 1007,
#         "sunrise": 1581866603,
#         "sunset": 1581898792,
#         "type": 1
#     },
#     "timezone": -25200,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 310,
#         "speed": 5.1
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 72
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 50.68,
#         "lon": 156.12
#     },
#     "dt": 1581891930,
#     "id": 2121385,
#     "main": {
#         "feels_like": 259.52,
#         "grnd_level": 972,
#         "humidity": 93,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 265.57,
#         "temp_max": 265.57,
#         "temp_min": 265.57
#     },
#     "name": "Severo-Kuril'sk",
#     "snow": {
#         "3h": 0.13
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581885963,
#         "sunset": 1581922405
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13d",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 293,
#         "speed": 4.45
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -27.23,
#         "lon": 153.1
#     },
#     "dt": 1581891930,
#     "id": 2151955,
#     "main": {
#         "feels_like": 302.99,
#         "humidity": 74,
#         "pressure": 1013,
#         "temp": 300.6,
#         "temp_max": 302.04,
#         "temp_min": 298.71
#     },
#     "name": "Redcliffe",
#     "sys": {
#         "country": "AU",
#         "id": 9485,
#         "sunrise": 1581881529,
#         "sunset": 1581928288,
#         "type": 1
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 140,
#         "speed": 3.6
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 73
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -7.3,
#         "lon": 27.42
#     },
#     "dt": 1581891931,
#     "id": 209598,
#     "main": {
#         "feels_like": 297.56,
#         "grnd_level": 935,
#         "humidity": 93,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 294.61,
#         "temp_max": 294.61,
#         "temp_min": 294.61
#     },
#     "name": "Manono",
#     "sys": {
#         "country": "CD",
#         "sunrise": 1581912885,
#         "sunset": 1581957257
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 153,
#         "speed": 1.25
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 94
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.92,
#         "lon": 114.08
#     },
#     "dt": 1581891720,
#     "id": 2017155,
#     "main": {
#         "feels_like": 249.58,
#         "grnd_level": 1007,
#         "humidity": 95,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 256.36,
#         "temp_max": 256.36,
#         "temp_min": 256.36
#     },
#     "name": "Saskylakh",
#     "snow": {
#         "3h": 0.19
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581901851,
#         "sunset": 1581926696
#     },
#     "timezone": 32400,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 287,
#         "speed": 4.71
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.48,
#         "lon": 15.9
#     },
#     "dt": 1581891931,
#     "id": 2255542,
#     "main": {
#         "feels_like": 301.35,
#         "grnd_level": 972,
#         "humidity": 60,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 299.17,
#         "temp_max": 299.17,
#         "temp_min": 299.17
#     },
#     "name": "Owando",
#     "sys": {
#         "country": "CG",
#         "sunrise": 1581829609,
#         "sunset": 1581873268
#     },
#     "timezone": 3600,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 169,
#         "speed": 0.66
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -53.15,
#         "lon": -70.92
#     },
#     "dt": 1581891715,
#     "id": 3874787,
#     "main": {
#         "feels_like": 274.83,
#         "humidity": 57,
#         "pressure": 994,
#         "temp": 283.96,
#         "temp_max": 284.15,
#         "temp_min": 283.71
#     },
#     "name": "Punta Arenas",
#     "sys": {
#         "country": "CL",
#         "id": 8487,
#         "sunrise": 1581846206,
#         "sunset": 1581898344,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "speed": 10.8
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 38.06,
#         "lon": -97.93
#     },
#     "dt": 1581891932,
#     "id": 4273299,
#     "main": {
#         "feels_like": 281.86,
#         "humidity": 62,
#         "pressure": 1012,
#         "temp": 285.16,
#         "temp_max": 286.48,
#         "temp_min": 284.15
#     },
#     "name": "Hutchinson",
#     "sys": {
#         "country": "US",
#         "id": 9720,
#         "sunrise": 1581859278,
#         "sunset": 1581898236,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 160,
#         "speed": 3.1
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -10.17,
#         "lon": 123.58
#     },
#     "dt": 1581891798,
#     "id": 2057087,
#     "main": {
#         "feels_like": 301.92,
#         "humidity": 100,
#         "pressure": 1011,
#         "temp": 297.15,
#         "temp_max": 297.15,
#         "temp_min": 297.15
#     },
#     "name": "Kupang",
#     "sys": {
#         "country": "ID",
#         "id": 9364,
#         "sunrise": 1581889649,
#         "sunset": 1581934338,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 140,
#         "speed": 1.5
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 70.47,
#         "lon": -68.59
#     },
#     "dt": 1581891714,
#     "id": 5924351,
#     "main": {
#         "feels_like": 242.28,
#         "humidity": 75,
#         "pressure": 991,
#         "temp": 247.15,
#         "temp_max": 247.15,
#         "temp_min": 247.15
#     },
#     "name": "Clyde River",
#     "sys": {
#         "country": "CA",
#         "id": 776,
#         "sunrise": 1581858591,
#         "sunset": 1581884840,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 14484,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 1.5
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -28.65,
#         "lon": 153.62
#     },
#     "dt": 1581891340,
#     "id": 2172880,
#     "main": {
#         "feels_like": 301.59,
#         "humidity": 78,
#         "pressure": 1013,
#         "temp": 298.91,
#         "temp_max": 301.48,
#         "temp_min": 297.15
#     },
#     "name": "Byron Bay",
#     "sys": {
#         "country": "AU",
#         "id": 9486,
#         "sunrise": 1581881305,
#         "sunset": 1581928263,
#         "type": 1
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "speed": 2.6
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 37.72,
#         "lon": -25.43
#     },
#     "dt": 1581891864,
#     "id": 3372472,
#     "main": {
#         "feels_like": 282.43,
#         "humidity": 71,
#         "pressure": 1031,
#         "temp": 286.15,
#         "temp_max": 286.15,
#         "temp_min": 286.15
#     },
#     "name": "Vila Franca do Campo",
#     "sys": {
#         "country": "PT",
#         "id": 6899,
#         "sunrise": 1581841864,
#         "sunset": 1581880851,
#         "type": 1
#     },
#     "timezone": -3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 360,
#         "speed": 4.6
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -42.72,
#         "lon": 170.97
#     },
#     "dt": 1581891936,
#     "id": 2206894,
#     "main": {
#         "feels_like": 290.58,
#         "grnd_level": 1014,
#         "humidity": 98,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 291.26,
#         "temp_max": 291.26,
#         "temp_min": 291.26
#     },
#     "name": "Hokitika",
#     "rain": {
#         "3h": 1.56
#     },
#     "sys": {
#         "country": "NZ",
#         "sunrise": 1581875940,
#         "sunset": 1581925300
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 4,
#         "speed": 4.83
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -6.53,
#         "lon": -64.38
#     },
#     "dt": 1581891936,
#     "id": 3664716,
#     "main": {
#         "feels_like": 308.88,
#         "grnd_level": 999,
#         "humidity": 89,
#         "pressure": 1006,
#         "sea_level": 1006,
#         "temp": 301.77,
#         "temp_max": 301.77,
#         "temp_min": 301.77
#     },
#     "name": "Canutama",
#     "rain": {
#         "3h": 5
#     },
#     "sys": {
#         "country": "BR",
#         "sunrise": 1581848552,
#         "sunset": 1581892858
#     },
#     "timezone": -14400,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10d",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 346,
#         "speed": 0.51
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -7.84,
#         "lon": -79.15
#     },
#     "dt": 1581891936,
#     "id": 3698359,
#     "main": {
#         "feels_like": 298.78,
#         "humidity": 83,
#         "pressure": 1006,
#         "temp": 297.15,
#         "temp_max": 297.15,
#         "temp_min": 297.15
#     },
#     "name": "Chicama",
#     "sys": {
#         "country": "PE",
#         "id": 8690,
#         "sunrise": 1581852026,
#         "sunset": 1581896474,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 9000,
#     "weather": [
#         {
#             "description": "mist",
#             "icon": "50d",
#             "id": 701,
#             "main": "Mist"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 3.6
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 7.77,
#         "lon": -72.22
#     },
#     "dt": 1581891936,
#     "id": 3628473,
#     "main": {
#         "feels_like": 303.96,
#         "humidity": 55,
#         "pressure": 1010,
#         "temp": 303.15,
#         "temp_max": 303.15,
#         "temp_min": 303.15
#     },
#     "name": "San Cristobal",
#     "sys": {
#         "country": "VE",
#         "id": 8587,
#         "sunrise": 1581851195,
#         "sunset": 1581893979,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 360,
#         "speed": 4.1
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -39.2,
#         "lon": 173.88
#     },
#     "dt": 1581891937,
#     "id": 2185763,
#     "main": {
#         "feels_like": 291.94,
#         "humidity": 79,
#         "pressure": 1019,
#         "temp": 292.58,
#         "temp_max": 293.71,
#         "temp_min": 290.93
#     },
#     "name": "Okato",
#     "rain": {
#         "3h": 0.56
#     },
#     "sys": {
#         "country": "NZ",
#         "id": 2020402,
#         "sunrise": 1581875588,
#         "sunset": 1581924256,
#         "type": 3
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 29,
#         "gust": 6.26,
#         "speed": 3.58
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 44.16,
#         "lon": 80
#     },
#     "dt": 1581891937,
#     "id": 1520253,
#     "main": {
#         "feels_like": 264.4,
#         "grnd_level": 971,
#         "humidity": 91,
#         "pressure": 1039,
#         "sea_level": 1039,
#         "temp": 269.85,
#         "temp_max": 269.85,
#         "temp_min": 269.85
#     },
#     "name": "Zharkent",
#     "sys": {
#         "country": "KZ",
#         "sunrise": 1581903483,
#         "sunset": 1581941422
#     },
#     "timezone": 21600,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 68,
#         "speed": 4.12
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 67
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.02,
#         "lon": 27.91
#     },
#     "dt": 1581891660,
#     "id": 1006984,
#     "main": {
#         "feels_like": 300.85,
#         "grnd_level": 1006,
#         "humidity": 81,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 299.92,
#         "temp_max": 299.92,
#         "temp_min": 299.92
#     },
#     "name": "East London",
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1581911169,
#         "sunset": 1581958737
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 228,
#         "speed": 6.34
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 22
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 21.28,
#         "lon": -88.27
#     },
#     "dt": 1581891937,
#     "id": 3521972,
#     "main": {
#         "feels_like": 301.39,
#         "grnd_level": 1014,
#         "humidity": 63,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 301,
#         "temp_max": 301,
#         "temp_min": 301
#     },
#     "name": "Panaba",
#     "sys": {
#         "country": "MX",
#         "sunrise": 1581855801,
#         "sunset": 1581897076
#     },
#     "timezone": -21600,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 45,
#         "speed": 4.82
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -28.87,
#         "lon": 153.57
#     },
#     "dt": 1581891676,
#     "id": 2177069,
#     "main": {
#         "feels_like": 303.14,
#         "humidity": 88,
#         "pressure": 1014,
#         "temp": 298.71,
#         "temp_max": 299.15,
#         "temp_min": 298.15
#     },
#     "name": "Ballina",
#     "sys": {
#         "country": "AU",
#         "id": 9496,
#         "sunrise": 1581881302,
#         "sunset": 1581928291,
#         "type": 1
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 1.5
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 78.22,
#         "lon": 15.64
#     },
#     "dt": 1581891795,
#     "id": 2729907,
#     "main": {
#         "feels_like": 258.03,
#         "humidity": 66,
#         "pressure": 991,
#         "temp": 262.15,
#         "temp_max": 262.15,
#         "temp_min": 262.15
#     },
#     "name": "Longyearbyen",
#     "sys": {
#         "country": "SJ",
#         "id": 1663,
#         "sunrise": 1581849883,
#         "sunset": 1581853120,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 360,
#         "speed": 1
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 3.07,
#         "lon": 172.79
#     },
#     "dt": 1581891938,
#     "id": 2110227,
#     "main": {
#         "feels_like": 300.51,
#         "grnd_level": 1006,
#         "humidity": 77,
#         "pressure": 1006,
#         "sea_level": 1006,
#         "temp": 301.38,
#         "temp_max": 301.38,
#         "temp_min": 301.38
#     },
#     "name": "Butaritari",
#     "sys": {
#         "country": "KI",
#         "sunrise": 1581878541,
#         "sunset": 1581921826
#     },
#     "timezone": 43200,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 41,
#         "speed": 9.39
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -32.03,
#         "lon": -52.1
#     },
#     "dt": 1581891938,
#     "id": 3451138,
#     "main": {
#         "feels_like": 304.73,
#         "humidity": 58,
#         "pressure": 1007,
#         "temp": 304.15,
#         "temp_max": 304.15,
#         "temp_min": 304.15
#     },
#     "name": "Rio Grande",
#     "sys": {
#         "country": "BR",
#         "id": 8408,
#         "sunrise": 1581844007,
#         "sunset": 1581891510,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "speed": 5.7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 26
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -28.24,
#         "lon": -48.67
#     },
#     "dt": 1581891825,
#     "id": 3461370,
#     "main": {
#         "feels_like": 304.33,
#         "humidity": 78,
#         "pressure": 1010,
#         "temp": 301.15,
#         "temp_max": 301.15,
#         "temp_min": 301.15
#     },
#     "name": "Imbituba",
#     "rain": {
#         "3h": 2.31
#     },
#     "sys": {
#         "country": "BR",
#         "id": 8360,
#         "sunrise": 1581843464,
#         "sunset": 1581890406,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 70,
#         "speed": 3.6
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 52
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 24.83,
#         "lon": -104.83
#     },
#     "dt": 1581891661,
#     "id": 4011741,
#     "main": {
#         "feels_like": 292.33,
#         "grnd_level": 792,
#         "humidity": 19,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 295.39,
#         "temp_max": 295.39,
#         "temp_min": 295.39
#     },
#     "name": "Durango",
#     "sys": {
#         "country": "MX",
#         "sunrise": 1581859990,
#         "sunset": 1581900836
#     },
#     "timezone": -21600,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 262,
#         "speed": 1.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.6,
#         "lon": -73.97
#     },
#     "dt": 1581891715,
#     "id": 5106841,
#     "main": {
#         "feels_like": 269.17,
#         "humidity": 51,
#         "pressure": 1017,
#         "temp": 274.55,
#         "temp_max": 276.48,
#         "temp_min": 272.04
#     },
#     "name": "Albany",
#     "sys": {
#         "country": "US",
#         "id": 3273,
#         "sunrise": 1581853934,
#         "sunset": 1581892079,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 160,
#         "speed": 3.6
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 65.61,
#         "lon": -37.64
#     },
#     "dt": 1581891716,
#     "id": 3424607,
#     "main": {
#         "feels_like": 264.05,
#         "humidity": 50,
#         "pressure": 981,
#         "temp": 272.15,
#         "temp_max": 272.15,
#         "temp_min": 272.15
#     },
#     "name": "Tasiilaq",
#     "sys": {
#         "country": "GL",
#         "id": 81,
#         "sunrise": 1581849140,
#         "sunset": 1581879435,
#         "type": 1
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 90,
#         "speed": 7.2
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -25.65,
#         "lon": -48.51
#     },
#     "dt": 1581891939,
#     "id": 6322927,
#     "main": {
#         "feels_like": 300.09,
#         "humidity": 61,
#         "pressure": 1014,
#         "temp": 299.41,
#         "temp_max": 301.15,
#         "temp_min": 296.15
#     },
#     "name": "Pontal do Parana",
#     "sys": {
#         "country": "BR",
#         "id": 8410,
#         "sunrise": 1581843606,
#         "sunset": 1581890187,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 80,
#         "speed": 3.1
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.42,
#         "lon": 19.23
#     },
#     "dt": 1581891718,
#     "id": 3366880,
#     "main": {
#         "feels_like": 293.21,
#         "humidity": 71,
#         "pressure": 1008,
#         "temp": 293.27,
#         "temp_max": 294.26,
#         "temp_min": 292.04
#     },
#     "name": "Hermanus",
#     "sys": {
#         "country": "ZA",
#         "id": 2006131,
#         "sunrise": 1581913144,
#         "sunset": 1581960929,
#         "type": 3
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 270,
#         "gust": 6.26,
#         "speed": 2.24
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -54.8,
#         "lon": -68.3
#     },
#     "dt": 1581891666,
#     "id": 3833367,
#     "main": {
#         "feels_like": 274.76,
#         "humidity": 61,
#         "pressure": 991,
#         "temp": 283.15,
#         "temp_max": 283.15,
#         "temp_min": 283.15
#     },
#     "name": "Ushuaia",
#     "sys": {
#         "country": "AR",
#         "id": 8303,
#         "sunrise": 1581845294,
#         "sunset": 1581897998,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 230,
#         "speed": 9.8
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 5
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 65.28,
#         "lon": -126.83
#     },
#     "dt": 1581891943,
#     "id": 6089245,
#     "main": {
#         "feels_like": 232.51,
#         "humidity": 66,
#         "pressure": 1030,
#         "temp": 237.15,
#         "temp_max": 237.15,
#         "temp_min": 237.15
#     },
#     "name": "Norman Wells",
#     "sys": {
#         "country": "CA",
#         "id": 951,
#         "sunrise": 1581870387,
#         "sunset": 1581900999,
#         "type": 1
#     },
#     "timezone": -25200,
#     "visibility": 48279,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 210,
#         "speed": 1
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 70.37,
#         "lon": 31.11
#     },
#     "dt": 1581891785,
#     "id": 777019,
#     "main": {
#         "feels_like": 263.84,
#         "humidity": 100,
#         "pressure": 973,
#         "temp": 272.07,
#         "temp_max": 273.15,
#         "temp_min": 271.15
#     },
#     "name": "Vardo",
#     "sys": {
#         "country": "NO",
#         "id": 1682,
#         "sunrise": 1581834692,
#         "sunset": 1581860885,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 2000,
#     "weather": [
#         {
#             "description": "snow",
#             "icon": "13n",
#             "id": 601,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 120,
#         "speed": 8.7
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 66.83,
#         "lon": 70.83
#     },
#     "dt": 1581891798,
#     "id": 1486321,
#     "main": {
#         "feels_like": 254.96,
#         "grnd_level": 1019,
#         "humidity": 94,
#         "pressure": 1021,
#         "sea_level": 1021,
#         "temp": 261.77,
#         "temp_max": 261.77,
#         "temp_min": 261.77
#     },
#     "name": "Yar-Sale",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581909767,
#         "sunset": 1581939538
#     },
#     "timezone": 18000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "speed": 5.15
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.12,
#         "lon": -134.97
#     },
#     "dt": 1581891671,
#     "id": 4030556,
#     "main": {
#         "feels_like": 298.09,
#         "grnd_level": 1015,
#         "humidity": 78,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 299.6,
#         "temp_max": 299.6,
#         "temp_min": 299.6
#     },
#     "name": "Rikitea",
#     "sys": {
#         "country": "PF",
#         "sunrise": 1581864532,
#         "sunset": 1581910761
#     },
#     "timezone": -32400,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 83,
#         "speed": 9.09
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.92,
#         "lon": 25.57
#     },
#     "dt": 1581891944,
#     "id": 964420,
#     "main": {
#         "feels_like": 293.77,
#         "humidity": 88,
#         "pressure": 1010,
#         "temp": 295.15,
#         "temp_max": 295.15,
#         "temp_min": 295.15
#     },
#     "name": "Port Elizabeth",
#     "sys": {
#         "country": "ZA",
#         "id": 1973,
#         "sunrise": 1581911661,
#         "sunset": 1581959369,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 240,
#         "speed": 7.2
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 39.42,
#         "lon": -92.44
#     },
#     "dt": 1581891841,
#     "id": 4398730,
#     "main": {
#         "feels_like": 278.8,
#         "humidity": 37,
#         "pressure": 1016,
#         "temp": 282.81,
#         "temp_max": 284.82,
#         "temp_min": 279.26
#     },
#     "name": "Moberly",
#     "sys": {
#         "country": "US",
#         "id": 6170,
#         "sunrise": 1581858076,
#         "sunset": 1581896803,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 130,
#         "speed": 2.1
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 37
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 44.51,
#         "lon": 50.26
#     },
#     "dt": 1581891948,
#     "id": 609906,
#     "main": {
#         "feels_like": 268.57,
#         "grnd_level": 1023,
#         "humidity": 94,
#         "pressure": 1036,
#         "sea_level": 1036,
#         "temp": 273.72,
#         "temp_max": 273.72,
#         "temp_min": 273.72
#     },
#     "name": "Fort-Shevchenko",
#     "sys": {
#         "country": "KZ",
#         "sunrise": 1581910647,
#         "sunset": 1581948532
#     },
#     "timezone": 18000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 79,
#         "speed": 4.46
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.21,
#         "lon": -159.78
#     },
#     "dt": 1581891722,
#     "id": 4035715,
#     "main": {
#         "feels_like": 303.36,
#         "humidity": 83,
#         "pressure": 1008,
#         "temp": 300.15,
#         "temp_max": 300.15,
#         "temp_min": 300.15
#     },
#     "name": "Avarua",
#     "rain": {
#         "3h": 1.38
#     },
#     "sys": {
#         "country": "CK",
#         "id": 7271,
#         "sunrise": 1581870610,
#         "sunset": 1581916591,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 350,
#         "speed": 3.6
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -4.2,
#         "lon": 152.17
#     },
#     "dt": 1581891948,
#     "id": 2087894,
#     "main": {
#         "feels_like": 302.48,
#         "grnd_level": 1008,
#         "humidity": 74,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 301.47,
#         "temp_max": 301.47,
#         "temp_min": 301.47
#     },
#     "name": "Rabaul",
#     "sys": {
#         "country": "PG",
#         "sunrise": 1581883107,
#         "sunset": 1581927157
#     },
#     "timezone": 36000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 264,
#         "speed": 6.23
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -30.18,
#         "lon": -50.21
#     },
#     "dt": 1581891948,
#     "id": 3466165,
#     "main": {
#         "feels_like": 298.16,
#         "grnd_level": 1009,
#         "humidity": 86,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 298.59,
#         "temp_max": 298.59,
#         "temp_min": 298.59
#     },
#     "name": "Cidreira",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1581843693,
#         "sunset": 1581890916
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 50,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 55.74,
#         "lon": -97.86
#     },
#     "dt": 1581891850,
#     "id": 6165406,
#     "main": {
#         "feels_like": 245.18,
#         "humidity": 57,
#         "pressure": 1014,
#         "temp": 251.15,
#         "temp_max": 251.15,
#         "temp_min": 251.15
#     },
#     "name": "Thompson",
#     "sys": {
#         "country": "CA",
#         "id": 935,
#         "sunrise": 1581861287,
#         "sunset": 1581896193,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "speed": 3.1
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 84
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -13.85,
#         "lon": 136.42
#     },
#     "dt": 1581891948,
#     "id": 2079582,
#     "main": {
#         "feels_like": 304.03,
#         "humidity": 88,
#         "pressure": 1007,
#         "temp": 299.15,
#         "temp_max": 299.15,
#         "temp_min": 299.15
#     },
#     "name": "Alyangula",
#     "sys": {
#         "country": "AU",
#         "id": 9527,
#         "sunrise": 1581886362,
#         "sunset": 1581931462,
#         "type": 1
#     },
#     "timezone": 34200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 299,
#         "speed": 1.21
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 68.75,
#         "lon": 161.3
#     },
#     "dt": 1581891949,
#     "id": 2126199,
#     "main": {
#         "feels_like": 233.65,
#         "grnd_level": 1021,
#         "humidity": 95,
#         "pressure": 1022,
#         "sea_level": 1022,
#         "temp": 240.24,
#         "temp_max": 240.24,
#         "temp_min": 240.24
#     },
#     "name": "Cherskiy",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581888876,
#         "sunset": 1581917006
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 148,
#         "speed": 3.87
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 34.64,
#         "lon": -120.46
#     },
#     "dt": 1581891949,
#     "id": 5367788,
#     "main": {
#         "feels_like": 286.35,
#         "humidity": 49,
#         "pressure": 1018,
#         "temp": 292.19,
#         "temp_max": 296.48,
#         "temp_min": 289.15
#     },
#     "name": "Lompoc",
#     "sys": {
#         "country": "US",
#         "id": 4747,
#         "sunrise": 1581864411,
#         "sunset": 1581903918,
#         "type": 1
#     },
#     "timezone": -28800,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 280,
#         "speed": 7.7
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 29
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.8,
#         "lon": -139.03
#     },
#     "dt": 1581891718,
#     "id": 4020109,
#     "main": {
#         "feels_like": 300.54,
#         "grnd_level": 1007,
#         "humidity": 76,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 300.59,
#         "temp_max": 300.59,
#         "temp_min": 300.59
#     },
#     "name": "Atuona",
#     "rain": {
#         "3h": 0.19
#     },
#     "sys": {
#         "country": "PF",
#         "sunrise": 1581866292,
#         "sunset": 1581910950
#     },
#     "timezone": -34200,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 72,
#         "speed": 7.43
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 52
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 8,
#         "lon": 124.29
#     },
#     "dt": 1581891949,
#     "id": 1701054,
#     "main": {
#         "feels_like": 298.46,
#         "humidity": 90,
#         "pressure": 1012,
#         "temp": 296.48,
#         "temp_max": 296.48,
#         "temp_min": 296.48
#     },
#     "name": "Marawi",
#     "sys": {
#         "country": "PH",
#         "id": 2007154,
#         "sunrise": 1581890438,
#         "sunset": 1581933208,
#         "type": 3
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 221,
#         "gust": 4.92,
#         "speed": 3.58
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.44,
#         "lon": 147.18
#     },
#     "dt": 1581891909,
#     "id": 2088122,
#     "main": {
#         "feels_like": 298.17,
#         "humidity": 100,
#         "pressure": 1009,
#         "temp": 296.15,
#         "temp_max": 296.15,
#         "temp_min": 296.15
#     },
#     "name": "Port Moresby",
#     "sys": {
#         "country": "PG",
#         "id": 42,
#         "sunrise": 1581884024,
#         "sunset": 1581928636,
#         "type": 1
#     },
#     "timezone": 36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 320,
#         "speed": 4.6
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 77
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -24.79,
#         "lon": -50.01
#     },
#     "dt": 1581891950,
#     "id": 3466704,
#     "main": {
#         "feels_like": 301.24,
#         "grnd_level": 903,
#         "humidity": 67,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 298.86,
#         "temp_max": 298.86,
#         "temp_min": 298.86
#     },
#     "name": "Castro",
#     "rain": {
#         "3h": 0.5
#     },
#     "sys": {
#         "country": "BR",
#         "sunrise": 1581844024,
#         "sunset": 1581890490
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 202,
#         "speed": 1.29
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -8.14,
#         "lon": 159.59
#     },
#     "dt": 1581891950,
#     "id": 2109528,
#     "main": {
#         "feels_like": 301.1,
#         "grnd_level": 997,
#         "humidity": 84,
#         "pressure": 1006,
#         "sea_level": 1006,
#         "temp": 299.62,
#         "temp_max": 299.62,
#         "temp_min": 299.62
#     },
#     "name": "Buala",
#     "rain": {
#         "3h": 0.88
#     },
#     "sys": {
#         "country": "SB",
#         "sunrise": 1581881115,
#         "sunset": 1581925587
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 254,
#         "speed": 5.82
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 99
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.97,
#         "lon": 102.5
#     },
#     "dt": 1581891709,
#     "id": 2022572,
#     "main": {
#         "feels_like": 249.28,
#         "grnd_level": 1019,
#         "humidity": 96,
#         "pressure": 1022,
#         "sea_level": 1022,
#         "temp": 256.1,
#         "temp_max": 256.1,
#         "temp_min": 256.1
#     },
#     "name": "Khatanga",
#     "snow": {
#         "3h": 0.19
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581904651,
#         "sunset": 1581929454
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
# ...
#         "humidity": 87,
#         "pressure": 1016,
#         "temp": 284.78,
#         "temp_max": 287.15,
#         "temp_min": 281.48
#     },
#     "name": "Kiryat Gat",
#     "sys": {
#         "country": "IL",
#         "id": 6845,
#         "sunrise": 1581913304,
#         "sunset": 1581953315,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "speed": 1
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 67
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 63.44,
#         "lon": -20.27
#     },
#     "dt": 1581892081,
#     "id": 3412093,
#     "main": {
#         "feels_like": 268.24,
#         "grnd_level": 958,
#         "humidity": 72,
#         "pressure": 958,
#         "sea_level": 958,
#         "temp": 275.35,
#         "temp_max": 275.35,
#         "temp_min": 275.35
#     },
#     "name": "Vestmannaeyjar",
#     "sys": {
#         "country": "IS",
#         "sunrise": 1581844331,
#         "sunset": 1581875907
#     },
#     "timezone": 0,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 343,
#         "speed": 6.87
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.48,
#         "lon": -54.33
#     },
#     "dt": 1581892082,
#     "id": 3440777,
#     "main": {
#         "feels_like": 306.34,
#         "grnd_level": 993,
#         "humidity": 26,
#         "pressure": 1006,
#         "sea_level": 1006,
#         "temp": 308.02,
#         "temp_max": 308.02,
#         "temp_min": 308.02
#     },
#     "name": "Rocha",
#     "sys": {
#         "country": "UY",
#         "sunrise": 1581844347,
#         "sunset": 1581892240
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 18,
#         "speed": 3.5
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 64.89,
#         "lon": -23.71
#     },
#     "dt": 1581892082,
#     "id": 3414079,
#     "main": {
#         "feels_like": 262.43,
#         "grnd_level": 955,
#         "humidity": 92,
#         "pressure": 966,
#         "sea_level": 966,
#         "temp": 274.59,
#         "temp_max": 274.59,
#         "temp_min": 274.59
#     },
#     "name": "Olafsvik",
#     "snow": {
#         "3h": 0.25
#     },
#     "sys": {
#         "country": "IS",
#         "sunrise": 1581845576,
#         "sunset": 1581876313
#     },
#     "timezone": 0,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 29,
#         "speed": 14.59
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 9.33,
#         "lon": 122.86
#     },
#     "dt": 1581892082,
#     "id": 1688363,
#     "main": {
#         "feels_like": 302.16,
#         "humidity": 83,
#         "pressure": 1011,
#         "temp": 299.15,
#         "temp_max": 299.15,
#         "temp_min": 299.15
#     },
#     "name": "Santa Catalina",
#     "sys": {
#         "country": "PH",
#         "id": 8185,
#         "sunrise": 1581890852,
#         "sunset": 1581933481,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 320,
#         "speed": 3.1
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 65.75,
#         "lon": 150.85
#     },
#     "dt": 1581892082,
#     "id": 2119283,
#     "main": {
#         "feels_like": 237.7,
#         "grnd_level": 1013,
#         "humidity": 89,
#         "pressure": 1020,
#         "sea_level": 1020,
#         "temp": 244.44,
#         "temp_max": 244.44,
#         "temp_min": 244.44
#     },
#     "name": "Zyryanka",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581890245,
#         "sunset": 1581920653
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 164,
#         "speed": 4.15
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 64.9,
#         "lon": 45.76
#     },
#     "dt": 1581892082,
#     "id": 535839,
#     "main": {
#         "feels_like": 264.81,
#         "grnd_level": 997,
#         "humidity": 91,
#         "pressure": 1005,
#         "sea_level": 1005,
#         "temp": 271.03,
#         "temp_max": 271.03,
#         "temp_min": 271.03
#     },
#     "name": "Leshukonskoye",
#     "snow": {
#         "3h": 0.13
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581915138,
#         "sunset": 1581946201
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 178,
#         "speed": 5.42
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 45.44,
#         "lon": 40.58
#     },
#     "dt": 1581892082,
#     "id": 540761,
#     "main": {
#         "feels_like": 267.72,
#         "grnd_level": 1021,
#         "humidity": 77,
#         "pressure": 1034,
#         "sea_level": 1034,
#         "temp": 273.83,
#         "temp_max": 273.83,
#         "temp_min": 273.83
#     },
#     "name": "Kropotkin",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581913062,
#         "sunset": 1581950764
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 82,
#         "speed": 5.34
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 25
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -16.84,
#         "lon": 36.99
#     },
#     "dt": 1581892083,
#     "id": 1024312,
#     "main": {
#         "feels_like": 300.32,
#         "grnd_level": 1000,
#         "humidity": 97,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 295.88,
#         "temp_max": 295.88,
#         "temp_min": 295.88
#     },
#     "name": "Mocuba",
#     "sys": {
#         "country": "MZ",
#         "sunrise": 1581910060,
#         "sunset": 1581955489
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 193,
#         "speed": 0.54
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 21.32,
#         "lon": -158.01
#     },
#     "dt": 1581892083,
#     "id": 5855051,
#     "main": {
#         "feels_like": 296.65,
#         "humidity": 64,
#         "pressure": 1018,
#         "temp": 298.27,
#         "temp_max": 301.15,
#         "temp_min": 296.15
#     },
#     "name": "'Ewa Beach",
#     "sys": {
#         "country": "US",
#         "id": 7866,
#         "sunrise": 1581872534,
#         "sunset": 1581913817,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 80,
#         "speed": 6.2
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -29.68,
#         "lon": -53.81
#     },
#     "dt": 1581892083,
#     "id": 3450083,
#     "main": {
#         "feels_like": 302.78,
#         "humidity": 74,
#         "pressure": 1009,
#         "temp": 301.15,
#         "temp_max": 301.15,
#         "temp_min": 301.15
#     },
#     "name": "Santa Maria",
#     "sys": {
#         "country": "BR",
#         "id": 8430,
#         "sunrise": 1581844595,
#         "sunset": 1581891743,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 330,
#         "speed": 5.1
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 92
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 10.11,
#         "lon": 14.45
#     },
#     "dt": 1581892083,
#     "id": 2230599,
#     "main": {
#         "feels_like": 293.54,
#         "grnd_level": 967,
#         "humidity": 11,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 300.36,
#         "temp_max": 300.36,
#         "temp_min": 300.36
#     },
#     "name": "Kaele",
#     "sys": {
#         "country": "CM",
#         "sunrise": 1581830524,
#         "sunset": 1581873049
#     },
#     "timezone": 3600,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 7,
#         "speed": 5.89
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 63.91,
#         "lon": 38.14
#     },
#     "dt": 1581892083,
#     "id": 515246,
#     "main": {
#         "feels_like": 264.45,
#         "grnd_level": 990,
#         "humidity": 95,
#         "pressure": 994,
#         "sea_level": 994,
#         "temp": 273.67,
#         "temp_max": 273.67,
#         "temp_min": 273.67
#     },
#     "name": "Onega",
#     "snow": {
#         "3h": 0.38
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581916678,
#         "sunset": 1581948318
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 166,
#         "speed": 10.3
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 88
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 54.21,
#         "lon": 72.97
#     },
#     "dt": 1581892083,
#     "id": 1496380,
#     "main": {
#         "feels_like": 258.46,
#         "grnd_level": 1013,
#         "humidity": 96,
#         "pressure": 1025,
#         "sea_level": 1025,
#         "temp": 263.75,
#         "temp_max": 263.75,
#         "temp_min": 263.75
#     },
#     "name": "Odesskoye",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581906378,
#         "sunset": 1581941901
#     },
#     "timezone": 21600,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 234,
#         "speed": 3.2
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 37.68,
#         "lon": -113.06
#     },
#     "dt": 1581891818,
#     "id": 5536630,
#     "main": {
#         "feels_like": 280.78,
#         "humidity": 30,
#         "pressure": 1016,
#         "temp": 286.49,
#         "temp_max": 287.15,
#         "temp_min": 285.37
#     },
#     "name": "Cedar City",
#     "sys": {
#         "country": "US",
#         "id": 3584,
#         "sunrise": 1581862875,
#         "sunset": 1581901901,
#         "type": 1
#     },
#     "timezone": -25200,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 200,
#         "speed": 4.6
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -32.93,
#         "lon": 151.78
#     },
#     "dt": 1581892084,
#     "id": 2155472,
#     "main": {
#         "feels_like": 296.14,
#         "humidity": 88,
#         "pressure": 1014,
#         "temp": 294.57,
#         "temp_max": 296.15,
#         "temp_min": 292.59
#     },
#     "name": "Newcastle",
#     "sys": {
#         "country": "AU",
#         "id": 9605,
#         "sunrise": 1581881429,
#         "sunset": 1581929022,
#         "type": 1
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light intensity drizzle",
#             "icon": "09d",
#             "id": 300,
#             "main": "Drizzle"
#         }
#     ],
#     "wind": {
#         "deg": 130,
#         "speed": 2.6
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 3
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 11,
#         "lon": 122.67
#     },
#     "dt": 1581891872,
#     "id": 1714733,
#     "main": {
#         "feels_like": 297.09,
#         "grnd_level": 997,
#         "humidity": 88,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 295.77,
#         "temp_max": 295.77,
#         "temp_min": 295.77
#     },
#     "name": "Dingle",
#     "sys": {
#         "country": "PH",
#         "sunrise": 1581890986,
#         "sunset": 1581933437
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 345,
#         "speed": 3.76
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 0.6,
#         "lon": -80.03
#     },
#     "dt": 1581892084,
#     "id": 3653967,
#     "main": {
#         "feels_like": 305,
#         "humidity": 94,
#         "pressure": 1005,
#         "temp": 300.15,
#         "temp_max": 300.15,
#         "temp_min": 300.15
#     },
#     "name": "Muisne",
#     "sys": {
#         "country": "EC",
#         "id": 8550,
#         "sunrise": 1581852689,
#         "sunset": 1581896233,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "speed": 3.1
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 48
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 40.81,
#         "lon": 114.88
#     },
#     "dt": 1581892084,
#     "id": 2033196,
#     "main": {
#         "feels_like": 251.47,
#         "grnd_level": 879,
#         "humidity": 90,
#         "pressure": 1037,
#         "sea_level": 1037,
#         "temp": 257.51,
#         "temp_max": 257.51,
#         "temp_min": 257.51
#     },
#     "name": "Zhangjiakou",
#     "sys": {
#         "country": "CN",
#         "sunrise": 1581894808,
#         "sunset": 1581933355
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 345,
#         "speed": 3.68
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.95,
#         "lon": 122.79
#     },
#     "dt": 1581892084,
#     "id": 1637001,
#     "main": {
#         "feels_like": 303.02,
#         "grnd_level": 1009,
#         "humidity": 75,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 300.71,
#         "temp_max": 300.71,
#         "temp_min": 300.71
#     },
#     "name": "Luwuk",
#     "sys": {
#         "country": "ID",
#         "sunrise": 1581890329,
#         "sunset": 1581934037
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 330,
#         "speed": 3.97
#     }
# }

# %%
data_list = {"City" : city_name, 
              "Cloudiness" : cloudiness, 
              "Country" : country, 
              "Date" : date, 
              "Humidity" : humidity, 
              "Latitude" : lat, 
              "Longitude" : lng, 
              "Max Temp" : max_temp, 
              "Wind Speed" : wind_speed}
plot_data = pd.DataFrame(data_list)
plot_data.count()
# Out:
# City          560
# Cloudiness    560
# Country       560
# Date          560
# Humidity      560
# Latitude      560
# Longitude     560
# Max Temp      560
# Wind Speed    560
# dtype: int64

# %%
plot_data
# Out:
#               City  Cloudiness Country        Date  Humidity  Latitude  \
# 0          Mataura          65      NZ  1581891927        82    -46.19
# 1     Ponta do Sol          40      PT  1581891723        72     32.67
# 2       Vila Velha          75      BR  1581891929        83    -20.33
# 3        Busselton           0      AU  1581891929        60    -33.65
# 4    Saint Stephen          20      GB  1581891929        65     50.33
# ..             ...         ...     ...         ...       ...       ...
# 555      Newcastle          75      AU  1581892084        88    -32.93
# 556         Dingle           3      PH  1581891872        88     11.00
# 557         Muisne          75      EC  1581892084        94      0.60
# 558    Zhangjiakou          48      CN  1581892084        90     40.81
# 559          Luwuk           0      ID  1581892084        75     -0.95
#
#      Longitude  Max Temp  Wind Speed
# 0       168.86    292.54        0.44
# 1       -17.10    291.15        3.10
# 2       -40.29    302.04        3.60
# 3       115.33    286.48        5.15
# 4        -4.90    281.48       12.30
# ..         ...       ...         ...
# 555     151.78    296.15        2.60
# 556     122.67    295.77        3.76
# 557     -80.03    300.15        3.10
# 558     114.88    257.51        3.68
# 559     122.79    300.71        3.97
#
# [560 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Max Temp"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsMaxTemp.png")

# Lets take a look
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots

# %%
# Create Northern and Southern Hemisphere DataFrames

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
