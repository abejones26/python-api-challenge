# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from datetime import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Adding a counter to call in sets of 50
counter = 0

print("Beginning Data Retrieval")
print("-------------------------------------")
# Making a request for each city
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 1 | {cities[x]}")
    counter += 1
    if counter == 50:
        break
        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 2 | {cities[x + 50]}")
    counter += 1
    if counter == 50:
        break
        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 3 | {cities[x + 100]}")
    counter += 1
    if counter == 50:
        break
        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 4 | {cities[x + 150]}")
    counter += 1
    if counter == 50:
        break
        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 5 | {cities[x + 200]}")
    counter += 1
    if counter == 50:
        break
        
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record 0 of Set 1 | avarua
# Processing Record 1 of Set 1 | touros
# Processing Record 2 of Set 1 | rikitea
# Processing Record 3 of Set 1 | mataura
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | konevo
# Processing Record 6 of Set 1 | rio claro
# Processing Record 7 of Set 1 | chapais
# Processing Record 8 of Set 1 | ushuaia
# Processing Record 9 of Set 1 | tongchuan
# Processing Record 10 of Set 1 | vestmanna
# Processing Record 11 of Set 1 | rungata
# Processing Record 12 of Set 1 | busselton
# Processing Record 13 of Set 1 | tabialan
# Processing Record 14 of Set 1 | barrow
# Processing Record 15 of Set 1 | meulaboh
# Processing Record 16 of Set 1 | punta arenas
# Processing Record 17 of Set 1 | acajutla
# Processing Record 18 of Set 1 | cidreira
# Processing Record 19 of Set 1 | yarmouth
# Processing Record 20 of Set 1 | kapaa
# Processing Record 21 of Set 1 | nisia floresta
# Processing Record 22 of Set 1 | ponta do sol
# Processing Record 23 of Set 1 | hobyo
# Processing Record 24 of Set 1 | moyale
# Processing Record 25 of Set 1 | barentsburg
# Processing Record 26 of Set 1 | kutum
# Processing Record 27 of Set 1 | mehamn
# Processing Record 28 of Set 1 | hanchuan
# Processing Record 29 of Set 1 | shambu
# Processing Record 30 of Set 1 | mlimba
# Processing Record 31 of Set 1 | dikson
# Processing Record 32 of Set 1 | qaanaaq
# Processing Record 33 of Set 1 | albany
# Processing Record 34 of Set 1 | manokwari
# Processing Record 35 of Set 1 | clyde river
# Processing Record 36 of Set 1 | ahipara
# Processing Record 37 of Set 1 | georgetown
# Processing Record 38 of Set 1 | vestmannaeyjar
# Processing Record 39 of Set 1 | puerto ayora
# Processing Record 40 of Set 1 | hilo
# Processing Record 41 of Set 1 | amahai
# Processing Record 42 of Set 1 | ilinskiy
# Processing Record 43 of Set 1 | faya
# Processing Record 44 of Set 1 | port alfred
# Processing Record 45 of Set 1 | namwala
# Processing Record 46 of Set 1 | ribeira grande
# Processing Record 47 of Set 1 | kodinar
# Processing Record 48 of Set 1 | roma
# Processing Record 49 of Set 1 | atuona
# Processing Record 0 of Set 2 | kavieng
# Processing Record 1 of Set 2 | bereda
# Processing Record 2 of Set 2 | nanortalik
# Processing Record 3 of Set 2 | tuktoyaktuk
# Processing Record 4 of Set 2 | puerto del rosario
# Processing Record 5 of Set 2 | porto murtinho
# Processing Record 6 of Set 2 | mahebourg
# Processing Record 7 of Set 2 | doha
# Processing Record 8 of Set 2 | takoradi
# Processing Record 9 of Set 2 | kavaratti
# Processing Record 10 of Set 2 | sovetskiy
# Processing Record 11 of Set 2 | okandja
# Processing Record 12 of Set 2 | honiara
# Processing Record 13 of Set 2 | paamiut
# Processing Record 14 of Set 2 | illoqqortoormiut
# Processing Record 15 of Set 2 | hami
# Processing Record 16 of Set 2 | bredasdorp
# Processing Record 17 of Set 2 | constitucion
# Processing Record 18 of Set 2 | esperance
# Processing Record 19 of Set 2 | abapo
# Processing Record 20 of Set 2 | sitka
# Processing Record 21 of Set 2 | jamestown
# Processing Record 22 of Set 2 | hoquiam
# Processing Record 23 of Set 2 | usinsk
# Processing Record 24 of Set 2 | lorengau
# Processing Record 25 of Set 2 | boa vista
# Processing Record 26 of Set 2 | pingzhuang
# Processing Record 27 of Set 2 | ixtapa
# Processing Record 28 of Set 2 | vao
# Processing Record 29 of Set 2 | port hedland
# Processing Record 30 of Set 2 | klaksvik
# Processing Record 31 of Set 2 | cabo san lucas
# Processing Record 32 of Set 2 | green river
# Processing Record 33 of Set 2 | nome
# Processing Record 34 of Set 2 | xuddur
# Processing Record 35 of Set 2 | bosarkany
# Processing Record 36 of Set 2 | saint-philippe
# Processing Record 37 of Set 2 | kovylkino
# Processing Record 38 of Set 2 | mishkino
# Processing Record 39 of Set 2 | san patricio
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | mahaicony
# Processing Record 42 of Set 2 | katsuura
# Processing Record 43 of Set 2 | inhambane
# Processing Record 44 of Set 2 | hobart
# Processing Record 45 of Set 2 | cravo norte
# Processing Record 46 of Set 2 | bluff
# Processing Record 47 of Set 2 | olinda
# Processing Record 48 of Set 2 | khatanga
# Processing Record 49 of Set 2 | kodiak
# Processing Record 0 of Set 3 | sao felix do xingu
# Processing Record 1 of Set 3 | guisa
# Processing Record 2 of Set 3 | new norfolk
# Processing Record 3 of Set 3 | vaini
# Processing Record 4 of Set 3 | pochutla
# Processing Record 5 of Set 3 | talnakh
# Processing Record 6 of Set 3 | lompoc
# Processing Record 7 of Set 3 | saint anthony
# Processing Record 8 of Set 3 | cape town
# Processing Record 9 of Set 3 | bethel
# Processing Record 10 of Set 3 | kahului
# Processing Record 11 of Set 3 | santarem
# Processing Record 12 of Set 3 | castro
# Processing Record 13 of Set 3 | east london
# Processing Record 14 of Set 3 | san
# Processing Record 15 of Set 3 | samalaeulu
# Processing Record 16 of Set 3 | chagda
# Processing Record 17 of Set 3 | mount pleasant
# Processing Record 18 of Set 3 | tuatapere
# Processing Record 19 of Set 3 | pisco
# Processing Record 20 of Set 3 | longyearbyen
# Processing Record 21 of Set 3 | mount isa
# Processing Record 22 of Set 3 | huarmey
# Processing Record 23 of Set 3 | san carlos de bariloche
# Processing Record 24 of Set 3 | smoljan
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | nikolskoye
# Processing Record 27 of Set 3 | bahia de caraquez
# Processing Record 28 of Set 3 | arnsberg
# Processing Record 29 of Set 3 | carnarvon
# Processing Record 30 of Set 3 | seoul
# Processing Record 31 of Set 3 | port elizabeth
# Processing Record 32 of Set 3 | krasnogorodsk
# Processing Record 33 of Set 3 | mecca
# Processing Record 34 of Set 3 | marcona
# Processing Record 35 of Set 3 | bambous virieux
# Processing Record 36 of Set 3 | bonthe
# Processing Record 37 of Set 3 | bekhtery
# Processing Record 38 of Set 3 | hofn
# Processing Record 39 of Set 3 | tilichiki
# Processing Record 40 of Set 3 | geraldton
# Processing Record 41 of Set 3 | los llanos de aridane
# Processing Record 42 of Set 3 | saskylakh
# Processing Record 43 of Set 3 | egvekinot
# Processing Record 44 of Set 3 | salalah
# Processing Record 45 of Set 3 | norfolk
# Processing Record 46 of Set 3 | airai
# Processing Record 47 of Set 3 | saint-augustin
# Processing Record 48 of Set 3 | pevek
# Processing Record 49 of Set 3 | tarudant
# Processing Record 0 of Set 4 | bathsheba
# Processing Record 1 of Set 4 | bac lieu
# Processing Record 2 of Set 4 | tasiilaq
# Processing Record 3 of Set 4 | taolanaro
# Processing Record 4 of Set 4 | sambava
# Processing Record 5 of Set 4 | tazovskiy
# Processing Record 6 of Set 4 | safaqis
# Processing Record 7 of Set 4 | sistranda
# Processing Record 8 of Set 4 | osias
# Processing Record 9 of Set 4 | lang son
# Processing Record 10 of Set 4 | kulhudhuffushi
# Processing Record 11 of Set 4 | bowen
# Processing Record 12 of Set 4 | fortuna
# Processing Record 13 of Set 4 | visnes
# Processing Record 14 of Set 4 | coquimbo
# Processing Record 15 of Set 4 | portales
# Processing Record 16 of Set 4 | saldanha
# Processing Record 17 of Set 4 | mahibadhoo
# Processing Record 18 of Set 4 | grand-lahou
# Processing Record 19 of Set 4 | mangrol
# Processing Record 20 of Set 4 | santander
# Processing Record 21 of Set 4 | verkh-usugli
# Processing Record 22 of Set 4 | hetauda
# Processing Record 23 of Set 4 | calama
# Processing Record 24 of Set 4 | ola
# Processing Record 25 of Set 4 | antofagasta
# Processing Record 26 of Set 4 | along
# Processing Record 27 of Set 4 | mys shmidta
# Processing Record 28 of Set 4 | tombouctou
# Processing Record 29 of Set 4 | margate
# Processing Record 30 of Set 4 | port hardy
# Processing Record 31 of Set 4 | alice springs
# Processing Record 32 of Set 4 | yarada
# Processing Record 33 of Set 4 | yerbogachen
# Processing Record 34 of Set 4 | bolungarvik
# Processing Record 35 of Set 4 | mhlume
# Processing Record 36 of Set 4 | provideniya
# Processing Record 37 of Set 4 | attawapiskat
# Processing Record 38 of Set 4 | hithadhoo
# Processing Record 39 of Set 4 | lasa
# Processing Record 40 of Set 4 | severo-kurilsk
# Processing Record 41 of Set 4 | porbandar
# Processing Record 42 of Set 4 | richha
# Processing Record 43 of Set 4 | yellowknife
# Processing Record 44 of Set 4 | kieta
# Processing Record 45 of Set 4 | jatiroto
# Processing Record 46 of Set 4 | thompson
# Processing Record 47 of Set 4 | la rioja
# Processing Record 48 of Set 4 | ilulissat
# Processing Record 49 of Set 4 | jiujiang
# Processing Record 0 of Set 5 | westport
# Processing Record 1 of Set 5 | barrancas
# Processing Record 2 of Set 5 | belushya guba
# Processing Record 3 of Set 5 | sentyabrskiy
# Processing Record 4 of Set 5 | qitaihe
# Processing Record 5 of Set 5 | asau
# Processing Record 6 of Set 5 | lampang
# Processing Record 7 of Set 5 | bonavista
# Processing Record 8 of Set 5 | nizhneyansk
# Processing Record 9 of Set 5 | hamilton
# Processing Record 10 of Set 5 | mar del plata
# Processing Record 11 of Set 5 | seddon
# Processing Record 12 of Set 5 | laramie
# Processing Record 13 of Set 5 | prince albert
# Processing Record 14 of Set 5 | nerja
# Processing Record 15 of Set 5 | stokmarknes
# Processing Record 16 of Set 5 | isangel
# Processing Record 17 of Set 5 | ondarroa
# Processing Record 18 of Set 5 | rocha
# Processing Record 19 of Set 5 | taltal
# Processing Record 20 of Set 5 | alta floresta
# Processing Record 21 of Set 5 | joensuu
# Processing Record 22 of Set 5 | bitung
# Processing Record 23 of Set 5 | torquay
# Processing Record 24 of Set 5 | itapora
# Processing Record 25 of Set 5 | port lincoln
# Processing Record 26 of Set 5 | iqaluit
# Processing Record 27 of Set 5 | half moon bay
# Processing Record 28 of Set 5 | manjacaze
# Processing Record 29 of Set 5 | kodinsk
# Processing Record 30 of Set 5 | homer
# Processing Record 31 of Set 5 | taitung
# Processing Record 32 of Set 5 | tiznit
# Processing Record 33 of Set 5 | broome
# Processing Record 34 of Set 5 | del rio
# Processing Record 35 of Set 5 | atar
# Processing Record 36 of Set 5 | victoria
# Processing Record 37 of Set 5 | srednekolymsk
# Processing Record 38 of Set 5 | tarakan
# Processing Record 39 of Set 5 | birjand
# Processing Record 40 of Set 5 | nueva loja
# Processing Record 41 of Set 5 | faanui
# Processing Record 42 of Set 5 | gua musang
# Processing Record 43 of Set 5 | san matias
# Processing Record 44 of Set 5 | labytnangi
# Processing Record 45 of Set 5 | oshnaviyeh
# Processing Record 46 of Set 5 | arraias
# Processing Record 47 of Set 5 | nombre de dios
# Processing Record 48 of Set 5 | miles city
# Processing Record 49 of Set 5 | benito juarez
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}&appid={weather_api_key}&q="
print(query_url)

#Creating an empty list to store procossing log
city_name = []
cloudiness =[]
country = []
date = []
humidity =[]
lat = []
lng = []
max_temp = []
wind_speed = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city + "&units=" + units)
    response_json = response.json()
    print(json.dumps(response_json, indent=4, sort_keys=True))
    try:
        city_name.append(response_json['name'])
        cloudiness.append(response_json['clouds']['all'])
        country.append(response_json['sys']['country'])
        date.append(response_json['dt'])
        humidity.append(response_json['main']['humidity'])
        lat.append(response_json['coord']['lat'])
        lng.append(response_json['coord']['lon'])
        max_temp.append(response_json['main']['temp_max'])
        wind_speed.append(response_json['wind']['speed'])
    except:
        print("City not found")
        pass
# Out:
# https://api.openweathermap.org/data/2.5/weather?&appid=3c69e2440c645c6447da4ba851075ac7&q=
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.21,
#         "lon": -159.78
#     },
#     "dt": 1581991646,
#     "id": 4035715,
#     "main": {
#         "feels_like": 84.22,
#         "humidity": 78,
#         "pressure": 1004,
#         "temp": 82.4,
#         "temp_max": 82.4,
#         "temp_min": 82.4
#     },
#     "name": "Avarua",
#     "sys": {
#         "country": "CK",
#         "id": 7271,
#         "sunrise": 1581957041,
#         "sunset": 1582002953,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light intensity drizzle",
#             "icon": "09d",
#             "id": 300,
#             "main": "Drizzle"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "speed": 14.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -5.2,
#         "lon": -35.46
#     },
#     "dt": 1581991647,
#     "id": 3386213,
#     "main": {
#         "feels_like": 86.38,
#         "humidity": 83,
#         "pressure": 1013,
#         "temp": 80.6,
#         "temp_max": 80.6,
#         "temp_min": 80.6
#     },
#     "name": "Touros",
#     "sys": {
#         "country": "BR",
#         "id": 8452,
#         "sunrise": 1581928088,
#         "sunset": 1581972235,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 150,
#         "speed": 8.05
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.12,
#         "lon": -134.97
#     },
#     "dt": 1581991647,
#     "id": 4030556,
#     "main": {
#         "feels_like": 80.06,
#         "grnd_level": 1013,
#         "humidity": 77,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 79.43,
#         "temp_max": 79.43,
#         "temp_min": 79.43
#     },
#     "name": "Rikitea",
#     "rain": {
#         "3h": 0.31
#     },
#     "sys": {
#         "country": "PF",
#         "sunrise": 1581950967,
#         "sunset": 1581997119
#     },
#     "timezone": -32400,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 80,
#         "speed": 13.87
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 99
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.19,
#         "lon": 168.86
#     },
#     "dt": 1581991647,
#     "id": 6201424,
#     "main": {
#         "feels_like": 69.21,
#         "humidity": 83,
#         "pressure": 1011,
#         "temp": 66.99,
#         "temp_max": 66.99,
#         "temp_min": 66.99
#     },
#     "name": "Mataura",
#     "sys": {
#         "country": "NZ",
#         "id": 2008959,
#         "sunrise": 1581962553,
#         "sunset": 1582012494,
#         "type": 3
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 102,
#         "gust": 8.99,
#         "speed": 3
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 66
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.42,
#         "lon": 19.23
#     },
#     "dt": 1581991648,
#     "id": 3366880,
#     "main": {
#         "feels_like": 64.27,
#         "humidity": 88,
#         "pressure": 1013,
#         "temp": 64.99,
#         "temp_max": 64.99,
#         "temp_min": 64.99
#     },
#     "name": "Hermanus",
#     "rain": {
#         "3h": 0.13
#     },
#     "sys": {
#         "country": "ZA",
#         "id": 2006131,
#         "sunrise": 1581999601,
#         "sunset": 1582047264,
#         "type": 3
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 120,
#         "gust": 15.01,
#         "speed": 8.01
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 62.12,
#         "lon": 39.32
#     },
#     "dt": 1581991511,
#     "id": 545467,
#     "main": {
#         "feels_like": 23.86,
#         "grnd_level": 973,
#         "humidity": 93,
#         "pressure": 989,
#         "sea_level": 989,
#         "temp": 34.86,
#         "temp_max": 34.86,
#         "temp_min": 34.86
#     },
#     "name": "Konevo",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1582002152,
#         "sunset": 1582035070
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 233,
#         "speed": 13.44
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 81
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -22.41,
#         "lon": -47.56
#     },
#     "dt": 1581991648,
#     "id": 3451234,
#     "main": {
#         "feels_like": 79.39,
#         "humidity": 83,
#         "pressure": 1016,
#         "temp": 75.2,
#         "temp_max": 75.2,
#         "temp_min": 75.2
#     },
#     "name": "Rio Claro",
#     "rain": {
#         "3h": 2.5
#     },
#     "sys": {
#         "country": "BR",
#         "id": 8462,
#         "sunrise": 1581930024,
#         "sunset": 1581976107,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 330,
#         "speed": 5.82
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 49.78,
#         "lon": -74.85
#     },
#     "dt": 1581991648,
#     "id": 5919850,
#     "main": {
#         "feels_like": -16.98,
#         "humidity": 76,
#         "pressure": 1024,
#         "temp": -7.6,
#         "temp_max": -7.6,
#         "temp_min": -7.6
#     },
#     "name": "Chapais",
#     "sys": {
#         "country": "CA",
#         "id": 859,
#         "sunrise": 1581941213,
#         "sunset": 1581978016,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 14484,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 4.7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -54.8,
#         "lon": -68.3
#     },
#     "dt": 1581991649,
#     "id": 3833367,
#     "main": {
#         "feels_like": 35.8,
#         "humidity": 66,
#         "pressure": 986,
#         "temp": 48.2,
#         "temp_max": 48.2,
#         "temp_min": 48.2
#     },
#     "name": "Ushuaia",
#     "sys": {
#         "country": "AR",
#         "id": 8303,
#         "sunrise": 1581931823,
#         "sunset": 1581984263,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light intensity drizzle",
#             "icon": "09n",
#             "id": 300,
#             "main": "Drizzle"
#         }
#     ],
#     "wind": {
#         "deg": 360,
#         "speed": 17.22
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 35.08,
#         "lon": 109.09
#     },
#     "dt": 1581991649,
#     "id": 1795196,
#     "main": {
#         "feels_like": 34.92,
#         "grnd_level": 921,
#         "humidity": 22,
#         "pressure": 1029,
#         "sea_level": 1029,
#         "temp": 42.35,
#         "temp_max": 42.35,
#         "temp_min": 42.35
#     },
#     "name": "Tongchuanshi",
#     "sys": {
#         "country": "CN",
#         "sunrise": 1581982063,
#         "sunset": 1582021671
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 182,
#         "speed": 2.55
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 62.16,
#         "lon": -7.17
#     },
#     "dt": 1581991649,
#     "id": 2610343,
#     "main": {
#         "feels_like": 28.87,
#         "humidity": 80,
#         "pressure": 980,
#         "temp": 41,
#         "temp_max": 41,
#         "temp_min": 41
#     },
#     "name": "Vestmanna",
#     "rain": {
#         "3h": 0.88
#     },
#     "sys": {
#         "country": "FO",
#         "id": 1596,
#         "sunrise": 1582013296,
#         "sunset": 1582046241,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "speed": 16.11
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.65,
#         "lon": 115.33
#     },
#     "dt": 1581991650,
#     "id": 2075265,
#     "main": {
#         "feels_like": 64.54,
#         "humidity": 25,
#         "pressure": 1012,
#         "temp": 73.87,
#         "temp_max": 79,
#         "temp_min": 71.01
#     },
#     "name": "Busselton",
#     "sys": {
#         "country": "AU",
#         "id": 2011706,
#         "sunrise": 1581976582,
#         "sunset": 1582024158,
#         "type": 3
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 93,
#         "speed": 11.27
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.29,
#         "lon": -156.79
#     },
#     "dt": 1581991650,
#     "id": 5880054,
#     "main": {
#         "feels_like": -43.58,
#         "humidity": 73,
#         "pressure": 1014,
#         "temp": -34.6,
#         "temp_max": -34.6,
#         "temp_min": -34.6
#     },
#     "name": "Barrow",
#     "sys": {
#         "country": "US",
#         "id": 7649,
#         "sunrise": 1581966228,
#         "sunset": 1581992331,
#         "type": 1
#     },
#     "timezone": -32400,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 230,
#         "speed": 3.36
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 98
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 4.14,
#         "lon": 96.13
#     },
#     "dt": 1581991491,
#     "id": 1214488,
#     "main": {
#         "feels_like": 83.12,
#         "grnd_level": 1012,
#         "humidity": 77,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 79.7,
#         "temp_max": 79.7,
#         "temp_min": 79.7
#     },
#     "name": "Meulaboh",
#     "sys": {
#         "country": "ID",
#         "sunrise": 1581983383,
#         "sunset": 1582026572
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 58,
#         "speed": 9.17
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -53.15,
#         "lon": -70.92
#     },
#     "dt": 1581991651,
#     "id": 3874787,
#     "main": {
#         "feels_like": 41.49,
#         "humidity": 54,
#         "pressure": 984,
#         "temp": 52.23,
#         "temp_max": 53.6,
#         "temp_min": 51.01
#     },
#     "name": "Punta Arenas",
#     "rain": {
#         "3h": 0.13
#     },
#     "sys": {
#         "country": "CL",
#         "id": 8487,
#         "sunrise": 1581932726,
#         "sunset": 1581984617,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 350,
#         "speed": 13.87
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 13.59,
#         "lon": -89.83
#     },
#     "dt": 1581991651,
#     "id": 3587498,
#     "main": {
#         "feels_like": 84.42,
#         "grnd_level": 1009,
#         "humidity": 72,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 82.4,
#         "temp_max": 82.4,
#         "temp_min": 82.4
#     },
#     "name": "Acajutla",
#     "sys": {
#         "country": "SV",
#         "sunrise": 1581942112,
#         "sunset": 1581984308
#     },
#     "timezone": -21600,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 327,
#         "speed": 12.24
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 77
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -30.18,
#         "lon": -50.21
#     },
#     "dt": 1581991381,
#     "id": 3466165,
#     "main": {
#         "feels_like": 75.56,
#         "grnd_level": 1008,
#         "humidity": 89,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 77.2,
#         "temp_max": 77.2,
#         "temp_min": 77.2
#     },
#     "name": "Cidreira",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1581930142,
#         "sunset": 1581977261
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 31,
#         "speed": 19.98
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 41.71,
#         "lon": -70.23
#     },
#     "dt": 1581991653,
#     "id": 4956335,
#     "main": {
#         "feels_like": 23,
#         "humidity": 64,
#         "pressure": 1029,
#         "temp": 31.8,
#         "temp_max": 37.4,
#         "temp_min": 26.6
#     },
#     "name": "Yarmouth",
#     "sys": {
#         "country": "US",
#         "id": 4119,
#         "sunrise": 1581939272,
#         "sunset": 1581977740,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "speed": 6.93
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.08,
#         "lon": -159.32
#     },
#     "dt": 1581991653,
#     "id": 5848280,
#     "main": {
#         "feels_like": 69.67,
#         "humidity": 65,
#         "pressure": 1017,
#         "temp": 75.58,
#         "temp_max": 78.8,
#         "temp_min": 73
#     },
#     "name": "Kapaa",
#     "sys": {
#         "country": "US",
#         "id": 7873,
#         "sunrise": 1581959255,
#         "sunset": 1582000519,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 18.34
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -6.09,
#         "lon": -35.21
#     },
#     "dt": 1581991653,
#     "id": 3393922,
#     "main": {
#         "feels_like": 86.63,
#         "humidity": 83,
#         "pressure": 1013,
#         "temp": 81.55,
#         "temp_max": 82.4,
#         "temp_min": 80.6
#     },
#     "name": "Nisia Floresta",
#     "sys": {
#         "country": "BR",
#         "id": 8417,
#         "sunrise": 1581927981,
#         "sunset": 1581972222,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "speed": 10.29
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 32.67,
#         "lon": -17.1
#     },
#     "dt": 1581991653,
#     "id": 2264557,
#     "main": {
#         "feels_like": 52.97,
#         "humidity": 77,
#         "pressure": 1031,
#         "temp": 59.94,
#         "temp_max": 64.4,
#         "temp_min": 55
#     },
#     "name": "Ponta do Sol",
#     "sys": {
#         "country": "PT",
#         "id": 6894,
#         "sunrise": 1582012156,
#         "sunset": 1582052147,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 10,
#         "speed": 13.87
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 66
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 5.35,
#         "lon": 48.53
#     },
#     "dt": 1581991653,
#     "id": 57000,
#     "main": {
#         "feels_like": 75.97,
#         "grnd_level": 1005,
#         "humidity": 76,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 76.26,
#         "temp_max": 76.26,
#         "temp_min": 76.26
#     },
#     "name": "Hobyo",
#     "sys": {
#         "country": "SO",
#         "sunrise": 1581994867,
#         "sunset": 1582037935
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 66,
#         "speed": 12.44
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 2
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 3.52,
#         "lon": 39.06
#     },
#     "dt": 1581991654,
#     "id": 186180,
#     "main": {
#         "feels_like": 73.26,
#         "grnd_level": 914,
#         "humidity": 64,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 74.52,
#         "temp_max": 74.52,
#         "temp_min": 74.52
#     },
#     "name": "Moyale",
#     "sys": {
#         "country": "KE",
#         "sunrise": 1581997047,
#         "sunset": 1582040300
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 141,
#         "speed": 9.08
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 14.2,
#         "lon": 24.67
#     },
#     "dt": 1581991654,
#     "id": 371745,
#     "main": {
#         "feels_like": 46.2,
#         "grnd_level": 884,
#         "humidity": 37,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 52.57,
#         "temp_max": 52.57,
#         "temp_min": 52.57
#     },
#     "name": "Kutum",
#     "sys": {
#         "country": "SD",
#         "sunrise": 1582001047,
#         "sunset": 1582043207
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 119,
#         "speed": 3.78
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.04,
#         "lon": 27.85
#     },
#     "dt": 1581991654,
#     "id": 778707,
#     "main": {
#         "feels_like": 12.58,
#         "grnd_level": 949,
#         "humidity": 81,
#         "pressure": 966,
#         "sea_level": 966,
#         "temp": 31.21,
#         "temp_max": 31.21,
#         "temp_min": 31.21
#     },
#     "name": "Mehamn",
#     "snow": {
#         "3h": 0.5
#     },
#     "sys": {
#         "country": "NO",
#         "sunrise": 1582008021,
#         "sunset": 1582034707
#     },
#     "timezone": 3600,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 332,
#         "speed": 25.34
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 30.65,
#         "lon": 113.77
#     },
#     "dt": 1581991655,
#     "id": 1808977,
#     "main": {
#         "feels_like": 36.97,
#         "humidity": 70,
#         "pressure": 1032,
#         "temp": 42.8,
#         "temp_max": 42.8,
#         "temp_min": 42.8
#     },
#     "name": "Hanchuan",
#     "sys": {
#         "country": "CN",
#         "id": 9634,
#         "sunrise": 1581980632,
#         "sunset": 1582020856,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "speed": 4.47
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 98
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 9.57,
#         "lon": 37.1
#     },
#     "dt": 1581991655,
#     "id": 328709,
#     "main": {
#         "feels_like": 59.58,
#         "grnd_level": 788,
#         "humidity": 57,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 61.95,
#         "temp_max": 61.95,
#         "temp_min": 61.95
#     },
#     "name": "Shambu",
#     "sys": {
#         "country": "ET",
#         "sunrise": 1581997824,
#         "sunset": 1582040464
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 2.8
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 59
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -8.8,
#         "lon": 35.82
#     },
#     "dt": 1581991658,
#     "id": 153384,
#     "main": {
#         "feels_like": 79.63,
#         "grnd_level": 977,
#         "humidity": 97,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 72.05,
#         "temp_max": 72.05,
#         "temp_min": 72.05
#     },
#     "name": "Mlimba",
#     "sys": {
#         "country": "TZ",
#         "sunrise": 1581997198,
#         "sunset": 1582041704
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 221,
#         "speed": 1.16
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 73.51,
#         "lon": 80.55
#     },
#     "dt": 1581991658,
#     "id": 1507390,
#     "main": {
#         "feels_like": -16.47,
#         "grnd_level": 994,
#         "humidity": 87,
#         "pressure": 995,
#         "sea_level": 995,
#         "temp": 7.63,
#         "temp_max": 7.63,
#         "temp_min": 7.63
#     },
#     "name": "Dikson",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581997021,
#         "sunset": 1582020412
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 172,
#         "speed": 31.99
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 60
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 77.48,
#         "lon": -69.36
#     },
#     "dt": 1581991659,
#     "id": 3831208,
#     "main": {
#         "feels_like": -19.52,
#         "grnd_level": 961,
#         "humidity": 63,
#         "pressure": 1002,
#         "sea_level": 1002,
#         "temp": -9.2,
#         "temp_max": -9.2,
#         "temp_min": -9.2
#     },
#     "name": "Qaanaaq",
#     "sys": {
#         "country": "GL",
#         "sunrise": 1581952009,
#         "sunset": 1581964586
#     },
#     "timezone": -14400,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 58,
#         "speed": 6.17
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.6,
#         "lon": -73.97
#     },
#     "dt": 1581991565,
#     "id": 5106841,
#     "main": {
#         "feels_like": 16.3,
#         "humidity": 62,
#         "pressure": 1026,
#         "temp": 23.2,
#         "temp_max": 28,
#         "temp_min": 18
#     },
#     "name": "Albany",
#     "sys": {
#         "country": "US",
#         "id": 5414,
#         "sunrise": 1581940250,
#         "sunset": 1581978557,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 11,
#         "speed": 2.24
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.87,
#         "lon": 134.08
#     },
#     "dt": 1581991659,
#     "id": 1636308,
#     "main": {
#         "feels_like": 83.57,
#         "grnd_level": 963,
#         "humidity": 89,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 77.5,
#         "temp_max": 77.5,
#         "temp_min": 77.5
#     },
#     "name": "Manokwari",
#     "rain": {
#         "3h": 3.81
#     },
#     "sys": {
#         "country": "ID",
#         "sunrise": 1581974022,
#         "sunset": 1582017718
#     },
#     "timezone": 32400,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10d",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 332,
#         "speed": 6.58
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 70.47,
#         "lon": -68.59
#     },
#     "dt": 1581991659,
#     "id": 5924351,
#     "main": {
#         "feels_like": -34.51,
#         "humidity": 74,
#         "pressure": 1002,
#         "temp": -25.6,
#         "temp_max": -25.6,
#         "temp_min": -25.6
#     },
#     "name": "Clyde River",
#     "sys": {
#         "country": "CA",
#         "id": 776,
#         "sunrise": 1581944689,
#         "sunset": 1581971535,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 14484,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "speed": 3.36
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 12
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -35.17,
#         "lon": 173.17
#     },
#     "dt": 1581991660,
#     "id": 2194098,
#     "main": {
#         "feels_like": 92.52,
#         "humidity": 66,
#         "pressure": 1015,
#         "temp": 86,
#         "temp_max": 86,
#         "temp_min": 86
#     },
#     "name": "Ahipara",
#     "sys": {
#         "country": "NZ",
#         "id": 2016422,
#         "sunrise": 1581962571,
#         "sunset": 1582010406,
#         "type": 3
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "speed": 5.08
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 5.41,
#         "lon": 100.34
#     },
#     "dt": 1581991417,
#     "id": 1735106,
#     "main": {
#         "feels_like": 88.39,
#         "humidity": 74,
#         "pressure": 1013,
#         "temp": 81.43,
#         "temp_max": 82.4,
#         "temp_min": 80.01
#     },
#     "name": "George Town",
#     "sys": {
#         "country": "MY",
#         "id": 9438,
#         "sunrise": 1581982437,
#         "sunset": 1582025497,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 9000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 360,
#         "speed": 3.36
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 63.44,
#         "lon": -20.27
#     },
#     "dt": 1581991660,
#     "id": 3412093,
#     "main": {
#         "feels_like": 30.02,
#         "grnd_level": 984,
#         "humidity": 61,
#         "pressure": 984,
#         "sea_level": 984,
#         "temp": 37.54,
#         "temp_max": 37.54,
#         "temp_min": 37.54
#     },
#     "name": "Vestmannaeyjar",
#     "sys": {
#         "country": "IS",
#         "sunrise": 1582016744,
#         "sunset": 1582049081
#     },
#     "timezone": 0,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 50,
#         "speed": 5.46
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 11
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.74,
#         "lon": -90.35
#     },
#     "dt": 1581991660,
#     "id": 3652764,
#     "main": {
#         "feels_like": 83.86,
#         "grnd_level": 1001,
#         "humidity": 82,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 78.19,
#         "temp_max": 78.19,
#         "temp_min": 78.19
#     },
#     "name": "Puerto Ayora",
#     "sys": {
#         "country": "EC",
#         "sunrise": 1581941493,
#         "sunset": 1581985176
#     },
#     "timezone": -21600,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 157,
#         "speed": 5.55
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 19.73,
#         "lon": -155.09
#     },
#     "dt": 1581991413,
#     "id": 5855927,
#     "main": {
#         "feels_like": 65.21,
#         "humidity": 54,
#         "pressure": 1016,
#         "temp": 70.16,
#         "temp_max": 80.6,
#         "temp_min": 53.01
#     },
#     "name": "Hilo",
#     "sys": {
#         "country": "US",
#         "id": 7881,
#         "sunrise": 1581958106,
#         "sunset": 1581999637,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 40,
#         "speed": 10.29
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 72
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -3.33,
#         "lon": 128.92
#     },
#     "dt": 1581991663,
#     "id": 1651591,
#     "main": {
#         "feels_like": 88.61,
#         "grnd_level": 1009,
#         "humidity": 65,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 84.13,
#         "temp_max": 84.13,
#         "temp_min": 84.13
#     },
#     "name": "Amahai",
#     "sys": {
#         "country": "ID",
#         "sunrise": 1581975135,
#         "sunset": 1582019082
#     },
#     "timezone": 32400,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 253,
#         "speed": 6.58
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 55.62,
#         "lon": 38.12
#     },
#     "dt": 1581991417,
#     "id": 557140,
#     "main": {
#         "feels_like": 31.51,
#         "humidity": 75,
#         "pressure": 1010,
#         "temp": 40.01,
#         "temp_max": 41,
#         "temp_min": 39
#     },
#     "name": "Ilinskiy",
#     "sys": {
#         "country": "RU",
#         "id": 9020,
#         "sunrise": 1582001211,
#         "sunset": 1582036588,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "speed": 8.95
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 18.39,
#         "lon": 42.45
#     },
#     "dt": 1581991664,
#     "id": 110690,
#     "main": {
#         "feels_like": 52.25,
#         "humidity": 54,
#         "pressure": 1023,
#         "temp": 56.26,
#         "temp_max": 57.2,
#         "temp_min": 55.4
#     },
#     "name": "Faya",
#     "sys": {
#         "country": "SA",
#         "id": 7396,
#         "sunrise": 1581997006,
#         "sunset": 1582038714,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 204,
#         "speed": 3.13
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.59,
#         "lon": 26.89
#     },
#     "dt": 1581991664,
#     "id": 964432,
#     "main": {
#         "feels_like": 71.26,
#         "humidity": 94,
#         "pressure": 1020,
#         "temp": 66.99,
#         "temp_max": 66.99,
#         "temp_min": 66.99
#     },
#     "name": "Port Alfred",
#     "rain": {
#         "3h": 0.19
#     },
#     "sys": {
#         "country": "ZA",
#         "id": 2011314,
#         "sunrise": 1581997825,
#         "sunset": 1582045363,
#         "type": 3
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 125,
#         "gust": 7,
#         "speed": 1.99
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 65
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -15.75,
#         "lon": 26.44
#     },
#     "dt": 1581991664,
#     "id": 901766,
#     "main": {
#         "feels_like": 68,
#         "grnd_level": 897,
#         "humidity": 97,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 64.45,
#         "temp_max": 64.45,
#         "temp_min": 64.45
#     },
#     "name": "Namwala",
#     "rain": {
#         "3h": 4.88
#     },
#     "sys": {
#         "country": "ZM",
#         "sunrise": 1581999076,
#         "sunset": 1582044328
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10n",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 176,
#         "speed": 2.01
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 69
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 38.52,
#         "lon": -28.7
#     },
#     "dt": 1581991387,
#     "id": 3372707,
#     "main": {
#         "feels_like": 46.74,
#         "grnd_level": 1013,
#         "humidity": 73,
#         "pressure": 1039,
#         "sea_level": 1039,
#         "temp": 52.45,
#         "temp_max": 52.45,
#         "temp_min": 52.45
#     },
#     "name": "Ribeira Grande",
#     "sys": {
#         "country": "PT",
#         "sunrise": 1582015368,
#         "sunset": 1582054503
#     },
#     "timezone": -3600,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 78,
#         "speed": 7.67
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 20.79,
#         "lon": 70.7
#     },
#     "dt": 1581991664,
#     "id": 1266397,
#     "main": {
#         "feels_like": 70.07,
#         "grnd_level": 1007,
#         "humidity": 21,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 78.26,
#         "temp_max": 78.26,
#         "temp_min": 78.26
#     },
#     "name": "Kodinar",
#     "sys": {
#         "country": "IN",
#         "sunrise": 1581990362,
#         "sunset": 1582031799
#     },
#     "timezone": 19800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 45,
#         "speed": 9.06
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 43.21,
#         "lon": -75.46
#     },
#     "dt": 1581991397,
#     "id": 5134295,
#     "main": {
#         "feels_like": 12.74,
#         "humidity": 73,
#         "pressure": 1028,
#         "temp": 20.91,
#         "temp_max": 25,
#         "temp_min": 15.01
#     },
#     "name": "Rome",
#     "sys": {
#         "country": "US",
#         "id": 5681,
#         "sunrise": 1581940664,
#         "sunset": 1581978858,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 140,
#         "speed": 4.7
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 81
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.8,
#         "lon": -139.03
#     },
#     "dt": 1581991665,
#     "id": 4020109,
#     "main": {
#         "feels_like": 79.21,
#         "grnd_level": 1006,
#         "humidity": 74,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 81.41,
#         "temp_max": 81.41,
#         "temp_min": 81.41
#     },
#     "name": "Atuona",
#     "sys": {
#         "country": "PF",
#         "sunrise": 1581952704,
#         "sunset": 1581997331
#     },
#     "timezone": -34200,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 93,
#         "speed": 19.6
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -2.57,
#         "lon": 150.8
#     },
#     "dt": 1581991665,
#     "id": 2094342,
#     "main": {
#         "feels_like": 87.04,
#         "grnd_level": 1006,
#         "humidity": 76,
#         "pressure": 1006,
#         "sea_level": 1006,
#         "temp": 84.24,
#         "temp_max": 84.24,
#         "temp_min": 84.24
#     },
#     "name": "Kavieng",
#     "rain": {
#         "3h": 3.06
#     },
#     "sys": {
#         "country": "PG",
#         "sunrise": 1581969923,
#         "sunset": 1582013792
#     },
#     "timezone": 36000,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10d",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 299,
#         "speed": 14.27
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 35
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 43.27,
#         "lon": -7.54
#     },
#     "dt": 1581991665,
#     "id": 3105522,
#     "main": {
#         "feels_like": 29.5,
#         "humidity": 100,
#         "pressure": 1035,
#         "temp": 35.76,
#         "temp_max": 43,
#         "temp_min": 30
#     },
#     "name": "Bereda",
#     "sys": {
#         "country": "ES",
#         "id": 6403,
#         "sunrise": 1582010697,
#         "sunset": 1582049017,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 5.82
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 60.14,
#         "lon": -45.24
#     },
#     "dt": 1581991665,
#     "id": 3421765,
#     "main": {
#         "feels_like": 12.18,
#         "grnd_level": 990,
#         "humidity": 68,
#         "pressure": 996,
#         "sea_level": 996,
#         "temp": 21.2,
#         "temp_max": 21.2,
#         "temp_min": 21.2
#     },
#     "name": "Nanortalik",
#     "snow": {
#         "3h": 1.38
#     },
#     "sys": {
#         "country": "GL",
#         "sunrise": 1581935745,
#         "sunset": 1581969273
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 305,
#         "speed": 6.02
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 69.45,
#         "lon": -133.04
#     },
#     "dt": 1581991666,
#     "id": 6170031,
#     "main": {
#         "feels_like": -37.16,
#         "humidity": 74,
#         "pressure": 1017,
#         "temp": -25.6,
#         "temp_max": -25.6,
#         "temp_min": -25.6
#     },
#     "name": "Tuktoyaktuk",
#     "sys": {
#         "country": "CA",
#         "id": 942,
#         "sunrise": 1581959609,
#         "sunset": 1581987551,
#         "type": 1
#     },
#     "timezone": -25200,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 28.5,
#         "lon": -13.86
#     },
#     "dt": 1581991666,
#     "id": 2512186,
#     "main": {
#         "feels_like": 56.55,
#         "humidity": 88,
#         "pressure": 1026,
#         "temp": 63.61,
#         "temp_max": 64.4,
#         "temp_min": 62.6
#     },
#     "name": "Puerto del Rosario",
#     "sys": {
#         "country": "ES",
#         "id": 2371,
#         "sunrise": 1582011105,
#         "sunset": 1582051643,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 9000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 40,
#         "speed": 18.34
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 38
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.7,
#         "lon": -57.88
#     },
#     "dt": 1581991666,
#     "id": 3452712,
#     "main": {
#         "feels_like": 89.89,
#         "grnd_level": 997,
#         "humidity": 57,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 86.25,
#         "temp_max": 86.25,
#         "temp_min": 86.25
#     },
#     "name": "Porto Murtinho",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1581932546,
#         "sunset": 1581978538
#     },
#     "timezone": -14400,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 26,
#         "speed": 6.38
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.41,
#         "lon": 57.7
#     },
#     "dt": 1581991667,
#     "id": 934322,
#     "main": {
#         "feels_like": 80.31,
#         "humidity": 88,
#         "pressure": 1014,
#         "temp": 76.05,
#         "temp_max": 77,
#         "temp_min": 75
#     },
#     "name": "Mahebourg",
#     "sys": {
#         "country": "MU",
#         "id": 2061,
#         "sunrise": 1581991305,
#         "sunset": 1582037095,
#         "type": 1
#     },
#     "timezone": 14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "shower rain",
#             "icon": "09d",
#             "id": 521,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 25.29,
#         "lon": 51.53
#     },
#     "dt": 1581991382,
#     "id": 290030,
#     "main": {
#         "feels_like": 66.06,
#         "humidity": 82,
#         "pressure": 1016,
#         "temp": 66.09,
#         "temp_max": 68,
#         "temp_min": 64.4
#     },
#     "name": "Doha",
#     "sys": {
#         "country": "QA",
#         "id": 7614,
#         "sunrise": 1581995223,
#         "sunset": 1582036139,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 118,
#         "speed": 6.17
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 2
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 4.88,
#         "lon": -1.76
#     },
#     "dt": 1581991670,
#     "id": 2294915,
#     "main": {
#         "feels_like": 85.24,
#         "grnd_level": 1003,
#         "humidity": 93,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 76.82,
#         "temp_max": 76.82,
#         "temp_min": 76.82
#     },
#     "name": "Takoradze",
#     "sys": {
#         "country": "GH",
#         "sunrise": 1582006911,
#         "sunset": 1582050029
#     },
#     "timezone": 0,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 253,
#         "speed": 3.04
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 10.57,
#         "lon": 72.64
#     },
#     "dt": 1581991671,
#     "id": 1267390,
#     "main": {
#         "feels_like": 86.13,
#         "grnd_level": 1014,
#         "humidity": 68,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 81.41,
#         "temp_max": 81.41,
#         "temp_min": 81.41
#     },
#     "name": "Kavaratti",
#     "sys": {
#         "country": "IN",
#         "sunrise": 1581989348,
#         "sunset": 1582031882
#     },
#     "timezone": 19800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 33,
#         "speed": 5.01
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 61.36,
#         "lon": 63.58
#     },
#     "dt": 1581991671,
#     "id": 1491230,
#     "main": {
#         "feels_like": 10.18,
#         "grnd_level": 979,
#         "humidity": 94,
#         "pressure": 993,
#         "sea_level": 993,
#         "temp": 24.28,
#         "temp_max": 24.28,
#         "temp_min": 24.28
#     },
#     "name": "Sovetskiy",
#     "snow": {
#         "3h": 2.88
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581996170,
#         "sunset": 1582029408
#     },
#     "timezone": 18000,
#     "weather": [
#         {
#             "description": "snow",
#             "icon": "13n",
#             "id": 601,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 212,
#         "speed": 16.64
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.43,
#         "lon": 159.95
#     },
#     "dt": 1581991671,
#     "id": 2108502,
#     "main": {
#         "feels_like": 95.31,
#         "humidity": 70,
#         "pressure": 1003,
#         "temp": 87.8,
#         "temp_max": 87.8,
#         "temp_min": 87.8
#     },
#     "name": "Honiara",
#     "sys": {
#         "country": "SB",
#         "id": 2,
#         "sunrise": 1581967370,
#         "sunset": 1582011953,
#         "type": 1
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
# ...
#     "sys": {
#         "country": "NE",
#         "sunrise": 1582005436,
#         "sunset": 1582047112
#     },
#     "timezone": 3600,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 92,
#         "speed": 6.2
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 7
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 50,
#         "lon": 2.65
#     },
#     "dt": 1581991881,
#     "id": 3038271,
#     "main": {
#         "feels_like": 29.37,
#         "humidity": 86,
#         "pressure": 1023,
#         "temp": 41.7,
#         "temp_max": 43,
#         "temp_min": 39.99
#     },
#     "name": "Albert",
#     "rain": {
#         "3h": 0.13
#     },
#     "sys": {
#         "country": "FR",
#         "id": 6446,
#         "sunrise": 1582008952,
#         "sunset": 1582045871,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 240,
#         "speed": 17.22
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 66.56,
#         "lon": 67.8
#     },
#     "dt": 1581991881,
#     "id": 1512019,
#     "main": {
#         "feels_like": 1.47,
#         "grnd_level": 980,
#         "humidity": 93,
#         "pressure": 986,
#         "sea_level": 986,
#         "temp": 19.72,
#         "temp_max": 19.72,
#         "temp_min": 19.72
#     },
#     "name": "Aksarka",
#     "snow": {
#         "3h": 3.38
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581996567,
#         "sunset": 1582026985
#     },
#     "timezone": 18000,
#     "weather": [
#         {
#             "description": "snow",
#             "icon": "13n",
#             "id": 601,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 185,
#         "speed": 23.22
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 7.77,
#         "lon": -72.22
#     },
#     "dt": 1581991881,
#     "id": 3628473,
#     "main": {
#         "feels_like": 89.06,
#         "humidity": 62,
#         "pressure": 1012,
#         "temp": 84.2,
#         "temp_max": 84.2,
#         "temp_min": 84.2
#     },
#     "name": "San Cristobal",
#     "sys": {
#         "country": "VE",
#         "id": 8587,
#         "sunrise": 1581937580,
#         "sunset": 1581980387,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 240,
#         "speed": 4.7
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 43.65,
#         "lon": 51.2
#     },
#     "dt": 1581991882,
#     "id": 610612,
#     "main": {
#         "feels_like": 19.04,
#         "humidity": 92,
#         "pressure": 1036,
#         "temp": 28.4,
#         "temp_max": 28.4,
#         "temp_min": 28.4
#     },
#     "name": "Aktau",
#     "sys": {
#         "country": "KZ",
#         "id": 8834,
#         "sunrise": 1581996649,
#         "sunset": 1582034871,
#         "type": 1
#     },
#     "timezone": 18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "speed": 8.95
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 95
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 12.59,
#         "lon": 6.58
#     },
#     "dt": 1581991882,
#     "id": 2334756,
#     "main": {
#         "feels_like": 55.04,
#         "grnd_level": 964,
#         "humidity": 22,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 65.41,
#         "temp_max": 65.41,
#         "temp_min": 65.41
#     },
#     "name": "Kaura Namoda",
#     "sys": {
#         "country": "NG",
#         "sunrise": 1582005303,
#         "sunset": 1582047634
#     },
#     "timezone": 3600,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 65,
#         "speed": 10.58
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 44.68,
#         "lon": 8.47
#     },
#     "dt": 1581991883,
#     "id": 6538185,
#     "main": {
#         "feels_like": 40.48,
#         "humidity": 100,
#         "pressure": 1022,
#         "temp": 46.47,
#         "temp_max": 55.99,
#         "temp_min": 36
#     },
#     "name": "Acqui Terme",
#     "sys": {
#         "country": "IT",
#         "id": 6737,
#         "sunrise": 1582006991,
#         "sunset": 1582045038,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 8000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 150,
#         "speed": 9.17
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 89
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 18.9,
#         "lon": -3.53
#     },
#     "dt": 1581991883,
#     "id": 2460954,
#     "main": {
#         "feels_like": 60.84,
#         "grnd_level": 983,
#         "humidity": 13,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 71.02,
#         "temp_max": 71.02,
#         "temp_min": 71.02
#     },
#     "name": "Araouane",
#     "sys": {
#         "country": "ML",
#         "sunrise": 1582008065,
#         "sunset": 1582049725
#     },
#     "timezone": 0,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 54,
#         "speed": 8.84
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 24
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -4.95,
#         "lon": 39.75
#     },
#     "dt": 1581991883,
#     "id": 156513,
#     "main": {
#         "feels_like": 88.03,
#         "grnd_level": 1011,
#         "humidity": 78,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 82.89,
#         "temp_max": 82.89,
#         "temp_min": 82.89
#     },
#     "name": "Konde",
#     "sys": {
#         "country": "TZ",
#         "sunrise": 1581996454,
#         "sunset": 1582040563
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 51,
#         "speed": 9.55
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 24
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 3.12,
#         "lon": 35.6
#     },
#     "dt": 1581991883,
#     "id": 189280,
#     "main": {
#         "feels_like": 81.9,
#         "grnd_level": 946,
#         "humidity": 46,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 83.75,
#         "temp_max": 83.75,
#         "temp_min": 83.75
#     },
#     "name": "Lodwar",
#     "sys": {
#         "country": "KE",
#         "sunrise": 1581997857,
#         "sunset": 1582041151
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 167,
#         "speed": 9.6
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 54.43,
#         "lon": 31.9
#     },
#     "dt": 1581991883,
#     "id": 525426,
#     "main": {
#         "feels_like": 29.08,
#         "grnd_level": 988,
#         "humidity": 93,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 36.57,
#         "temp_max": 36.57,
#         "temp_min": 36.57
#     },
#     "name": "Sobolevo",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1582002522,
#         "sunset": 1582038262
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 217,
#         "speed": 7.7
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 15
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -7.38,
#         "lon": 108.21
#     },
#     "dt": 1581991883,
#     "id": 1640902,
#     "main": {
#         "feels_like": 90.54,
#         "grnd_level": 944,
#         "humidity": 59,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 84.49,
#         "temp_max": 84.49,
#         "temp_min": 84.49
#     },
#     "name": "Kawalu",
#     "sys": {
#         "country": "ID",
#         "sunrise": 1581979897,
#         "sunset": 1582024260
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 175,
#         "speed": 1.54
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -17.58,
#         "lon": -67.52
#     },
#     "dt": 1581991884,
#     "id": 3902685,
#     "main": {
#         "feels_like": 41.58,
#         "grnd_level": 642,
#         "humidity": 71,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 49.53,
#         "temp_max": 49.53,
#         "temp_min": 49.53
#     },
#     "name": "Eucaliptus",
#     "rain": {
#         "3h": 0.19
#     },
#     "sys": {
#         "country": "BO",
#         "sunrise": 1581935106,
#         "sunset": 1581980605
#     },
#     "timezone": -14400,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 305,
#         "speed": 10.36
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 26.54,
#         "lon": -77.06
#     },
#     "dt": 1581991884,
#     "id": 3571913,
#     "main": {
#         "feels_like": 76.12,
#         "grnd_level": 1022,
#         "humidity": 83,
#         "pressure": 1022,
#         "sea_level": 1022,
#         "temp": 74.23,
#         "temp_max": 74.23,
#         "temp_min": 74.23
#     },
#     "name": "Marsh Harbour",
#     "sys": {
#         "country": "BS",
#         "sunrise": 1581939791,
#         "sunset": 1581980499
#     },
#     "timezone": -18000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 128,
#         "speed": 9.06
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 57.3,
#         "lon": 47.89
#     },
#     "dt": 1581991884,
#     "id": 469005,
#     "main": {
#         "feels_like": 22.21,
#         "grnd_level": 992,
#         "humidity": 96,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 35.13,
#         "temp_max": 35.13,
#         "temp_min": 35.13
#     },
#     "name": "Yaransk",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581999143,
#         "sunset": 1582033966
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 236,
#         "speed": 17.18
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 18.38,
#         "lon": -65.96
#     },
#     "dt": 1581991884,
#     "id": 4563243,
#     "main": {
#         "feels_like": 73.04,
#         "humidity": 88,
#         "pressure": 1020,
#         "temp": 73.4,
#         "temp_max": 75.2,
#         "temp_min": 72
#     },
#     "name": "Carolina",
#     "rain": {
#         "1h": 0.51
#     },
#     "sys": {
#         "country": "PR",
#         "id": 8792,
#         "sunrise": 1581936647,
#         "sunset": 1581978316,
#         "type": 1
#     },
#     "timezone": -14400,
#     "visibility": 14484,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "gust": 21.92,
#         "speed": 13.87
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 55.34,
#         "lon": -131.65
#     },
#     "dt": 1581991885,
#     "id": 5554428,
#     "main": {
#         "feels_like": 34.23,
#         "humidity": 86,
#         "pressure": 1030,
#         "temp": 40.91,
#         "temp_max": 42.8,
#         "temp_min": 39.2
#     },
#     "name": "Ketchikan",
#     "sys": {
#         "country": "US",
#         "id": 7741,
#         "sunrise": 1581955584,
#         "sunset": 1581990908,
#         "type": 1
#     },
#     "timezone": -32400,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "speed": 6.93
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -2.89,
#         "lon": -41.9
#     },
#     "dt": 1581991886,
#     "id": 3407351,
#     "main": {
#         "feels_like": 83.44,
#         "grnd_level": 1007,
#         "humidity": 93,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 76.08,
#         "temp_max": 76.08,
#         "temp_min": 76.08
#     },
#     "name": "Araioses",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1581929754,
#         "sunset": 1581973660
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 56,
#         "speed": 4.18
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -22.28,
#         "lon": 166.46
#     },
#     "dt": 1581991889,
#     "id": 2139521,
#     "main": {
#         "feels_like": 90.88,
#         "humidity": 58,
#         "pressure": 1006,
#         "temp": 87.39,
#         "temp_max": 87.8,
#         "temp_min": 87.01
#     },
#     "name": "Noumea",
#     "sys": {
#         "country": "NC",
#         "id": 7344,
#         "sunrise": 1581965081,
#         "sunset": 1582011117,
#         "type": 1
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 240,
#         "speed": 8.05
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 86
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 58.28,
#         "lon": 35.52
#     },
#     "dt": 1581991889,
#     "id": 535711,
#     "main": {
#         "feels_like": 23.22,
#         "grnd_level": 981,
#         "humidity": 88,
#         "pressure": 1002,
#         "sea_level": 1002,
#         "temp": 35.06,
#         "temp_max": 35.06,
#         "temp_min": 35.06
#     },
#     "name": "Lesnoye",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1582002278,
#         "sunset": 1582036768
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 234,
#         "speed": 14.65
#     }
# }

# %%
data_list = {"City" : city_name, 
              "Cloudiness" : cloudiness, 
              "Country" : country, 
              "Date" : date, 
              "Humidity" : humidity, 
              "Latitude" : lat, 
              "Longitude" : lng, 
              "Max Temp" : max_temp, 
              "Wind Speed" : wind_speed}
plot_data = pd.DataFrame(data_list)
plot_data.count()
# Out:
# City          570
# Cloudiness    570
# Country       570
# Date          570
# Humidity      570
# Latitude      570
# Longitude     570
# Max Temp      570
# Wind Speed    570
# dtype: int64

# %%
plot_data
# Out:
#           City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0       Avarua         100      CK  1581991646        78    -21.21    -159.78
# 1       Touros          20      BR  1581991647        83     -5.20     -35.46
# 2      Rikitea         100      PF  1581991647        77    -23.12    -134.97
# 3      Mataura          99      NZ  1581991647        83    -46.19     168.86
# 4     Hermanus          66      ZA  1581991648        88    -34.42      19.23
# ..         ...         ...     ...         ...       ...       ...        ...
# 565   Carolina          90      PR  1581991884        88     18.38     -65.96
# 566  Ketchikan          75      US  1581991885        86     55.34    -131.65
# 567   Araioses         100      BR  1581991886        93     -2.89     -41.90
# 568     Noumea          75      NC  1581991889        58    -22.28     166.46
# 569    Lesnoye          86      RU  1581991889        88     58.28      35.52
#
#      Max Temp  Wind Speed
# 0       82.40       14.99
# 1       80.60        8.05
# 2       79.43       13.87
# 3       66.99        3.00
# 4       64.99        8.01
# ..        ...         ...
# 565     75.20       13.87
# 566     42.80        6.93
# 567     76.08        4.18
# 568     87.80        8.05
# 569     35.06       14.65
#
# [570 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Max Temp"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsMaxTemp.png")

# Lets take a look
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Humidity"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsHumidity.png")

# Lets take a look
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Cloudiness"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsCloudiness.png")

# Lets take a look
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Wind Speed"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsWindSpeed.png")

# Lets take a look
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_data = plot_data.loc[plot_data['Latitude'] > 0,:]
southern_data = plot_data.loc[plot_data['Latitude'] < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = northern_data["Latitude"]
y_values = northern_data["Max Temp"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(5,-30),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Max Temp")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("N_LinearRegressMaxTemp.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: -0.8488883458893371

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_values = southern_data["Latitude"]
y_values = southern_data["Max Temp"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-30,55),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Max Temp")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("S_LinearRegressMaxTemp.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: 0.4587576316861053

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = northern_data["Latitude"]
y_values = northern_data["Humidity"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("N_LinearRegressHumidity.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: 0.4171702998268354

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_values = southern_data["Latitude"]
y_values = southern_data["Humidity"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-55,25),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("S_LinearRegressHumidity.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: 0.20500202700921266

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = northern_data["Latitude"]
y_values = northern_data["Cloudiness"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("N_LinearRegressCloudiness.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: 0.36692195914904485

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_values = southern_data["Latitude"]
y_values = southern_data["Cloudiness"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-55,10),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("S_LinearRegressCloudiness.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: 0.21570595544014548

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = northern_data["Latitude"]
y_values = northern_data["Wind Speed"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(5,38),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("N_LinearRegressWindSpeed.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: 0.09647376104332572

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_values = southern_data["Latitude"]
y_values = southern_data["Wind Speed"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-55,21),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("S_LinearRegressWindSpeed.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: -0.15140427147371938
