# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
import csv
from datetime import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 654

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Adding a counter to call in sets of 50
counter = 0

# Printing biginning note
print("Beginning Data Retrieval")
print("-------------------------------------")


# Making a request for each city in set of 50
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 1 | {cities[x]}")
    counter += 1
    if counter == 50:
        break
# Making a request for each city in set of 50      
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 2 | {cities[x + 50]}")
    counter += 1
    if counter == 50:
        break
# Making a request for each city in set of 50       
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 3 | {cities[x + 100]}")
    counter += 1
    if counter == 50:
        break
# Making a request for each city in set of 50       
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 4 | {cities[x + 150]}")
    counter += 1
    if counter == 50:
        break
# Making a request for each city in set of 50        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 5 | {cities[x + 200]}")
    counter += 1
    if counter == 50:
        break
# Printing notes to stating that processing is complete       
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record 0 of Set 1 | saskylakh
# Processing Record 1 of Set 1 | berasia
# Processing Record 2 of Set 1 | kaitangata
# Processing Record 3 of Set 1 | bilma
# Processing Record 4 of Set 1 | bud
# Processing Record 5 of Set 1 | tsihombe
# Processing Record 6 of Set 1 | artyk
# Processing Record 7 of Set 1 | chokurdakh
# Processing Record 8 of Set 1 | vaini
# Processing Record 9 of Set 1 | puerto escondido
# Processing Record 10 of Set 1 | hasaki
# Processing Record 11 of Set 1 | lamu
# Processing Record 12 of Set 1 | khatanga
# Processing Record 13 of Set 1 | jamestown
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | san antonio
# Processing Record 16 of Set 1 | derzhavinsk
# Processing Record 17 of Set 1 | qiongshan
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | otradnoye
# Processing Record 20 of Set 1 | sechura
# Processing Record 21 of Set 1 | srednekolymsk
# Processing Record 22 of Set 1 | bredasdorp
# Processing Record 23 of Set 1 | east london
# Processing Record 24 of Set 1 | rikitea
# Processing Record 25 of Set 1 | taolanaro
# Processing Record 26 of Set 1 | pangnirtung
# Processing Record 27 of Set 1 | ponta do sol
# Processing Record 28 of Set 1 | carnarvon
# Processing Record 29 of Set 1 | taltal
# Processing Record 30 of Set 1 | teknaf
# Processing Record 31 of Set 1 | north bend
# Processing Record 32 of Set 1 | pisco
# Processing Record 33 of Set 1 | mar del plata
# Processing Record 34 of Set 1 | amderma
# Processing Record 35 of Set 1 | itarema
# Processing Record 36 of Set 1 | beppu
# Processing Record 37 of Set 1 | hermanus
# Processing Record 38 of Set 1 | soyo
# Processing Record 39 of Set 1 | faya
# Processing Record 40 of Set 1 | albany
# Processing Record 41 of Set 1 | busselton
# Processing Record 42 of Set 1 | ushuaia
# Processing Record 43 of Set 1 | ancud
# Processing Record 44 of Set 1 | hithadhoo
# Processing Record 45 of Set 1 | mubi
# Processing Record 46 of Set 1 | bodden town
# Processing Record 47 of Set 1 | saint pete beach
# Processing Record 48 of Set 1 | kapaa
# Processing Record 49 of Set 1 | alice springs
# Processing Record 0 of Set 2 | illoqqortoormiut
# Processing Record 1 of Set 2 | cape town
# Processing Record 2 of Set 2 | nouadhibou
# Processing Record 3 of Set 2 | port alfred
# Processing Record 4 of Set 2 | ribeira grande
# Processing Record 5 of Set 2 | novoyegoryevskoye
# Processing Record 6 of Set 2 | yuxia
# Processing Record 7 of Set 2 | geraldton
# Processing Record 8 of Set 2 | punta arenas
# Processing Record 9 of Set 2 | belomorsk
# Processing Record 10 of Set 2 | carutapera
# Processing Record 11 of Set 2 | college park
# Processing Record 12 of Set 2 | hobart
# Processing Record 13 of Set 2 | willowmore
# Processing Record 14 of Set 2 | hualmay
# Processing Record 15 of Set 2 | cidreira
# Processing Record 16 of Set 2 | kieta
# Processing Record 17 of Set 2 | maniitsoq
# Processing Record 18 of Set 2 | lagoa
# Processing Record 19 of Set 2 | atuona
# Processing Record 20 of Set 2 | mataura
# Processing Record 21 of Set 2 | butaritari
# Processing Record 22 of Set 2 | ust-kamchatsk
# Processing Record 23 of Set 2 | wilmington
# Processing Record 24 of Set 2 | karratha
# Processing Record 25 of Set 2 | eureka
# Processing Record 26 of Set 2 | broome
# Processing Record 27 of Set 2 | luderitz
# Processing Record 28 of Set 2 | vaitupu
# Processing Record 29 of Set 2 | avarua
# Processing Record 30 of Set 2 | yellandu
# Processing Record 31 of Set 2 | nikolskoye
# Processing Record 32 of Set 2 | port elizabeth
# Processing Record 33 of Set 2 | lebu
# Processing Record 34 of Set 2 | grand river south east
# Processing Record 35 of Set 2 | cabo san lucas
# Processing Record 36 of Set 2 | varzea da palma
# Processing Record 37 of Set 2 | tabiauea
# Processing Record 38 of Set 2 | coquimbo
# Processing Record 39 of Set 2 | lata
# Processing Record 40 of Set 2 | osa
# Processing Record 41 of Set 2 | berlevag
# Processing Record 42 of Set 2 | tasiilaq
# Processing Record 43 of Set 2 | longyearbyen
# Processing Record 44 of Set 2 | hilo
# Processing Record 45 of Set 2 | tiksi
# Processing Record 46 of Set 2 | hami
# Processing Record 47 of Set 2 | fortuna
# Processing Record 48 of Set 2 | waddan
# Processing Record 49 of Set 2 | port hueneme
# Processing Record 0 of Set 3 | bambous virieux
# Processing Record 1 of Set 3 | turukhansk
# Processing Record 2 of Set 3 | nanortalik
# Processing Record 3 of Set 3 | sokolo
# Processing Record 4 of Set 3 | nanakuli
# Processing Record 5 of Set 3 | johnstown
# Processing Record 6 of Set 3 | prado
# Processing Record 7 of Set 3 | saint-philippe
# Processing Record 8 of Set 3 | chandur bazar
# Processing Record 9 of Set 3 | bubaque
# Processing Record 10 of Set 3 | novyy urengoy
# Processing Record 11 of Set 3 | dingle
# Processing Record 12 of Set 3 | talnakh
# Processing Record 13 of Set 3 | karaul
# Processing Record 14 of Set 3 | aklavik
# Processing Record 15 of Set 3 | igunga
# Processing Record 16 of Set 3 | yellowknife
# Processing Record 17 of Set 3 | sorland
# Processing Record 18 of Set 3 | fare
# Processing Record 19 of Set 3 | gerash
# Processing Record 20 of Set 3 | asau
# Processing Record 21 of Set 3 | kahului
# Processing Record 22 of Set 3 | airai
# Processing Record 23 of Set 3 | havoysund
# Processing Record 24 of Set 3 | aswan
# Processing Record 25 of Set 3 | bengkulu
# Processing Record 26 of Set 3 | rungata
# Processing Record 27 of Set 3 | maragogi
# Processing Record 28 of Set 3 | vila velha
# Processing Record 29 of Set 3 | barentsburg
# Processing Record 30 of Set 3 | broken hill
# Processing Record 31 of Set 3 | caravelas
# Processing Record 32 of Set 3 | veraval
# Processing Record 33 of Set 3 | kavieng
# Processing Record 34 of Set 3 | martin
# Processing Record 35 of Set 3 | cherskiy
# Processing Record 36 of Set 3 | new norfolk
# Processing Record 37 of Set 3 | miles city
# Processing Record 38 of Set 3 | jinka
# Processing Record 39 of Set 3 | saint-joseph
# Processing Record 40 of Set 3 | siwani
# Processing Record 41 of Set 3 | fuling
# Processing Record 42 of Set 3 | arraial do cabo
# Processing Record 43 of Set 3 | pietarsaari
# Processing Record 44 of Set 3 | kagoro
# Processing Record 45 of Set 3 | attawapiskat
# Processing Record 46 of Set 3 | barrow
# Processing Record 47 of Set 3 | tessalit
# Processing Record 48 of Set 3 | tambura
# Processing Record 49 of Set 3 | thinadhoo
# Processing Record 0 of Set 4 | heyang
# Processing Record 1 of Set 4 | quatre cocos
# Processing Record 2 of Set 4 | sao filipe
# Processing Record 3 of Set 4 | shar
# Processing Record 4 of Set 4 | sur
# Processing Record 5 of Set 4 | umzimvubu
# Processing Record 6 of Set 4 | honghu
# Processing Record 7 of Set 4 | remedios
# Processing Record 8 of Set 4 | progreso
# Processing Record 9 of Set 4 | alta floresta
# Processing Record 10 of Set 4 | grindavik
# Processing Record 11 of Set 4 | norman wells
# Processing Record 12 of Set 4 | launceston
# Processing Record 13 of Set 4 | antalaha
# Processing Record 14 of Set 4 | requena
# Processing Record 15 of Set 4 | constitucion
# Processing Record 16 of Set 4 | katsuura
# Processing Record 17 of Set 4 | atar
# Processing Record 18 of Set 4 | nizhneyansk
# Processing Record 19 of Set 4 | mys shmidta
# Processing Record 20 of Set 4 | upernavik
# Processing Record 21 of Set 4 | bestobe
# Processing Record 22 of Set 4 | san javier
# Processing Record 23 of Set 4 | pemangkat
# Processing Record 24 of Set 4 | preobrazheniye
# Processing Record 25 of Set 4 | samusu
# Processing Record 26 of Set 4 | banjar
# Processing Record 27 of Set 4 | campbell river
# Processing Record 28 of Set 4 | benicarlo
# Processing Record 29 of Set 4 | vostok
# Processing Record 30 of Set 4 | pandan
# Processing Record 31 of Set 4 | castro
# Processing Record 32 of Set 4 | mayo
# Processing Record 33 of Set 4 | kulhudhuffushi
# Processing Record 34 of Set 4 | burns lake
# Processing Record 35 of Set 4 | yatou
# Processing Record 36 of Set 4 | thompson
# Processing Record 37 of Set 4 | puerto del rosario
# Processing Record 38 of Set 4 | dekoa
# Processing Record 39 of Set 4 | sitka
# Processing Record 40 of Set 4 | peniche
# Processing Record 41 of Set 4 | guerrero negro
# Processing Record 42 of Set 4 | gornopravdinsk
# Processing Record 43 of Set 4 | ilulissat
# Processing Record 44 of Set 4 | tautira
# Processing Record 45 of Set 4 | gamba
# Processing Record 46 of Set 4 | dhidhdhoo
# Processing Record 47 of Set 4 | dangtu
# Processing Record 48 of Set 4 | ende
# Processing Record 49 of Set 4 | chuy
# Processing Record 0 of Set 5 | boralday
# Processing Record 1 of Set 5 | kruisfontein
# Processing Record 2 of Set 5 | purificacion
# Processing Record 3 of Set 5 | pevek
# Processing Record 4 of Set 5 | ahuimanu
# Processing Record 5 of Set 5 | burnie
# Processing Record 6 of Set 5 | kayerkan
# Processing Record 7 of Set 5 | nizhniy chir
# Processing Record 8 of Set 5 | dikson
# Processing Record 9 of Set 5 | lompoc
# Processing Record 10 of Set 5 | gobabis
# Processing Record 11 of Set 5 | imeni poliny osipenko
# Processing Record 12 of Set 5 | namibe
# Processing Record 13 of Set 5 | lake charles
# Processing Record 14 of Set 5 | enugu
# Processing Record 15 of Set 5 | kichera
# Processing Record 16 of Set 5 | mwingi
# Processing Record 17 of Set 5 | engen
# Processing Record 18 of Set 5 | djougou
# Processing Record 19 of Set 5 | codrington
# Processing Record 20 of Set 5 | kodiak
# Processing Record 21 of Set 5 | palabuhanratu
# Processing Record 22 of Set 5 | margate
# Processing Record 23 of Set 5 | cutzamala
# Processing Record 24 of Set 5 | severnyy
# Processing Record 25 of Set 5 | vila franca do campo
# Processing Record 26 of Set 5 | shingu
# Processing Record 27 of Set 5 | shymkent
# Processing Record 28 of Set 5 | torbay
# Processing Record 29 of Set 5 | pathein
# Processing Record 30 of Set 5 | krasnoselkup
# Processing Record 31 of Set 5 | port hedland
# Processing Record 32 of Set 5 | port lincoln
# Processing Record 33 of Set 5 | ojinaga
# Processing Record 34 of Set 5 | fairbanks
# Processing Record 35 of Set 5 | kavaratti
# Processing Record 36 of Set 5 | aykhal
# Processing Record 37 of Set 5 | victoria
# Processing Record 38 of Set 5 | nioro
# Processing Record 39 of Set 5 | tabou
# Processing Record 40 of Set 5 | shubarshi
# Processing Record 41 of Set 5 | kielce
# Processing Record 42 of Set 5 | kirakira
# Processing Record 43 of Set 5 | perigueux
# Processing Record 44 of Set 5 | yulara
# Processing Record 45 of Set 5 | vila
# Processing Record 46 of Set 5 | arkhangelskoye
# Processing Record 47 of Set 5 | san matias
# Processing Record 48 of Set 5 | denpasar
# Processing Record 49 of Set 5 | nizwa
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Configuring my api weather key
url = "https://api.openweathermap.org/data/2.5/weather?"

# Using imperial to get faherenheit
units = "imperial"

# And f string my url and api together
query_url = f"{url}&appid={weather_api_key}&q="
print(query_url)    

#Creating an empty list to store procossing log
city_name = []
cloudiness =[]
country = []
date = []
humidity =[]
lat = []
lng = []
max_temp = []
wind_speed = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city + "&units=" + units)
    response_json = response.json()
    print(json.dumps(response_json, indent=4, sort_keys=True))
    try:
        # Appending all of my results to their listes
        city_name.append(response_json['name'])
        cloudiness.append(response_json['clouds']['all'])
        country.append(response_json['sys']['country'])
        date.append(response_json['dt'])
        humidity.append(response_json['main']['humidity'])
        lat.append(response_json['coord']['lat'])
        lng.append(response_json['coord']['lon'])
        max_temp.append(response_json['main']['temp_max'])
        wind_speed.append(response_json['wind']['speed'])
    except:
        print("City not found")
        pass
# Out:
# https://api.openweathermap.org/data/2.5/weather?&appid=3c69e2440c645c6447da4ba851075ac7&q=
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.92,
#         "lon": 114.08
#     },
#     "dt": 1582051524,
#     "id": 2017155,
#     "main": {
#         "feels_like": -19.98,
#         "grnd_level": 1003,
#         "humidity": 93,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": -10.59,
#         "temp_max": -10.59,
#         "temp_min": -10.59
#     },
#     "name": "Saskylakh",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1582073972,
#         "sunset": 1582100158
#     },
#     "timezone": 32400,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 193,
#         "speed": 4.79
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 26
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 23.63,
#         "lon": 77.43
#     },
#     "dt": 1582051524,
#     "id": 1276449,
#     "main": {
#         "feels_like": 61.77,
#         "humidity": 72,
#         "pressure": 1017,
#         "temp": 62.6,
#         "temp_max": 62.6,
#         "temp_min": 62.6
#     },
#     "name": "Berasia",
#     "sys": {
#         "country": "IN",
#         "id": 9063,
#         "sunrise": 1582075268,
#         "sunset": 1582116453,
#         "type": 1
#     },
#     "timezone": 19800,
#     "visibility": 6000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 140,
#         "speed": 3.36
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 89
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.28,
#         "lon": 169.85
#     },
#     "dt": 1582051524,
#     "id": 2208248,
#     "main": {
#         "feels_like": 57.47,
#         "humidity": 96,
#         "pressure": 1007,
#         "temp": 56.82,
#         "temp_max": 57.99,
#         "temp_min": 55.99
#     },
#     "name": "Kaitangata",
#     "sys": {
#         "country": "NZ",
#         "id": 2000217,
#         "sunrise": 1582048795,
#         "sunset": 1582098567,
#         "type": 3
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 225,
#         "gust": 3,
#         "speed": 1.99
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 17
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 18.69,
#         "lon": 12.92
#     },
#     "dt": 1582051525,
#     "id": 2446796,
#     "main": {
#         "feels_like": 59.88,
#         "grnd_level": 964,
#         "humidity": 18,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 69.22,
#         "temp_max": 69.22,
#         "temp_min": 69.22
#     },
#     "name": "Bilma",
#     "sys": {
#         "country": "NE",
#         "sunrise": 1582004107,
#         "sunset": 1582045787
#     },
#     "timezone": 3600,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 17,
#         "speed": 8.41
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 39.45,
#         "lon": -86.18
#     },
#     "dt": 1582051525,
#     "id": 4255151,
#     "main": {
#         "feels_like": 31.06,
#         "humidity": 80,
#         "pressure": 1021,
#         "temp": 40.06,
#         "temp_max": 43,
#         "temp_min": 37
#     },
#     "name": "Bud",
#     "sys": {
#         "country": "US",
#         "id": 4345,
#         "sunrise": 1582029225,
#         "sunset": 1582068235,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 310,
#         "gust": 19.46,
#         "speed": 10.29
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 70.63,
#         "lon": 147.92
#     },
#     "dt": 1582051526,
#     "id": 2126123,
#     "main": {
#         "feels_like": -22.34,
#         "grnd_level": 1021,
#         "humidity": 98,
#         "pressure": 1022,
#         "sea_level": 1022,
#         "temp": -11.67,
#         "temp_max": -11.67,
#         "temp_min": -11.67
#     },
#     "name": "Chokurdakh",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1582065186,
#         "sunset": 1582092702
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 207,
#         "speed": 7.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.2,
#         "lon": -175.2
#     },
#     "dt": 1582051526,
#     "id": 4032243,
#     "main": {
#         "feels_like": 75.81,
#         "humidity": 94,
#         "pressure": 1004,
#         "temp": 69.8,
#         "temp_max": 69.8,
#         "temp_min": 69.8
#     },
#     "name": "Vaini",
#     "sys": {
#         "country": "TO",
#         "id": 7285,
#         "sunrise": 1582133604,
#         "sunset": 1582179373,
#         "type": 1
#     },
#     "timezone": 46800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "speed": 1.12
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 5
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 15.85,
#         "lon": -97.07
#     },
#     "dt": 1582051527,
#     "id": 3520994,
#     "main": {
#         "feels_like": 92.08,
#         "humidity": 84,
#         "pressure": 1012,
#         "temp": 86,
#         "temp_max": 86,
#         "temp_min": 86
#     },
#     "name": "Puerto Escondido",
#     "sys": {
#         "country": "MX",
#         "id": 7157,
#         "sunrise": 1582030342,
#         "sunset": 1582072344,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 130,
#         "speed": 13.87
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 35.73,
#         "lon": 140.83
#     },
#     "dt": 1582051527,
#     "id": 2112802,
#     "main": {
#         "feels_like": 25.03,
#         "humidity": 64,
#         "pressure": 1020,
#         "temp": 31.82,
#         "temp_max": 34,
#         "temp_min": 26.6
#     },
#     "name": "Hasaki",
#     "sys": {
#         "country": "JP",
#         "id": 7955,
#         "sunrise": 1582060832,
#         "sunset": 1582100460,
#         "type": 1
#     },
#     "timezone": 32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 280,
#         "speed": 3.36
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -2.27,
#         "lon": 40.9
#     },
#     "dt": 1582051527,
#     "id": 189741,
#     "main": {
#         "feels_like": 86.94,
#         "grnd_level": 1011,
#         "humidity": 83,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 82.02,
#         "temp_max": 82.02,
#         "temp_min": 82.02
#     },
#     "name": "Lamu",
#     "sys": {
#         "country": "KE",
#         "sunrise": 1581996314,
#         "sunset": 1582040150
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 83,
#         "speed": 11.07
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.97,
#         "lon": 102.5
#     },
#     "dt": 1582051528,
#     "id": 2022572,
#     "main": {
#         "feels_like": -18.63,
#         "grnd_level": 1006,
#         "humidity": 83,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": -6.7,
#         "temp_max": -6.7,
#         "temp_min": -6.7
#     },
#     "name": "Khatanga",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1582076770,
#         "sunset": 1582102919
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 156,
#         "speed": 9.37
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.1,
#         "lon": -79.24
#     },
#     "dt": 1582051528,
#     "id": 5122534,
#     "main": {
#         "feels_like": 34,
#         "humidity": 93,
#         "pressure": 1013,
#         "temp": 39.87,
#         "temp_max": 41,
#         "temp_min": 39
#     },
#     "name": "Jamestown",
#     "rain": {
#         "1h": 0.25
#     },
#     "sys": {
#         "country": "US",
#         "id": 3418,
#         "sunrise": 1582027784,
#         "sunset": 1582066345,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 3219,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         },
#         {
#             "description": "mist",
#             "icon": "50d",
#             "id": 701,
#             "main": "Mist"
#         }
#     ],
#     "wind": {
#         "deg": 200,
#         "speed": 5.82
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 78
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 77.48,
#         "lon": -69.36
#     },
#     "dt": 1582051528,
#     "id": 3831208,
#     "main": {
#         "feels_like": -24.72,
#         "grnd_level": 966,
#         "humidity": 55,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": -12.35,
#         "temp_max": -12.35,
#         "temp_min": -12.35
#     },
#     "name": "Qaanaaq",
#     "sys": {
#         "country": "GL",
#         "sunrise": 1582037563,
#         "sunset": 1582051823
#     },
#     "timezone": -14400,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 73,
#         "speed": 9.64
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 29.42,
#         "lon": -98.49
#     },
#     "dt": 1582051501,
#     "id": 4726206,
#     "main": {
#         "feels_like": 74.66,
#         "humidity": 83,
#         "pressure": 1015,
#         "temp": 72.84,
#         "temp_max": 77,
#         "temp_min": 69.01
#     },
#     "name": "San Antonio",
#     "sys": {
#         "country": "US",
#         "id": 5685,
#         "sunrise": 1582031462,
#         "sunset": 1582071906,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "speed": 8.05
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 51.1,
#         "lon": 66.32
#     },
#     "dt": 1582051529,
#     "id": 1524606,
#     "main": {
#         "feels_like": -0.54,
#         "grnd_level": 995,
#         "humidity": 91,
#         "pressure": 1030,
#         "sea_level": 1030,
#         "temp": 19.89,
#         "temp_max": 19.89,
#         "temp_min": 19.89
#     },
#     "name": "Derzhavinsk",
#     "snow": {
#         "3h": 0.19
#     },
#     "sys": {
#         "country": "KZ",
#         "sunrise": 1582080109,
#         "sunset": 1582116946
#     },
#     "timezone": 21600,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 236,
#         "speed": 27.04
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 20.01,
#         "lon": 110.35
#     },
#     "dt": 1582051529,
#     "id": 1797535,
#     "main": {
#         "feels_like": 65.89,
#         "humidity": 82,
#         "pressure": 1022,
#         "temp": 66.2,
#         "temp_max": 66.2,
#         "temp_min": 66.2
#     },
#     "name": "Qiongshan",
#     "sys": {
#         "country": "CN",
#         "id": 9635,
#         "sunrise": 1582067170,
#         "sunset": 1582108751,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 70,
#         "speed": 6.71
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 88
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.6,
#         "lon": 168.33
#     },
#     "dt": 1582051530,
#     "id": 2206939,
#     "main": {
#         "feels_like": 55.72,
#         "humidity": 97,
#         "pressure": 1010,
#         "temp": 55,
#         "temp_max": 55,
#         "temp_min": 55
#     },
#     "name": "Bluff",
#     "rain": {
#         "3h": 0.19
#     },
#     "sys": {
#         "country": "NZ",
#         "id": 2008959,
#         "sunrise": 1582049124,
#         "sunset": 1582098968,
#         "type": 3
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 322,
#         "gust": 5.01,
#         "speed": 1.01
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 59.78,
#         "lon": 30.82
#     },
#     "dt": 1582051530,
#     "id": 513898,
#     "main": {
#         "feels_like": 32.36,
#         "humidity": 80,
#         "pressure": 996,
#         "temp": 40.53,
#         "temp_max": 41,
#         "temp_min": 39.99
#     },
#     "name": "Otradnoye",
#     "sys": {
#         "country": "RU",
#         "id": 8926,
#         "sunrise": 1582003687,
#         "sunset": 1582037615,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "gust": 20.13,
#         "speed": 8.95
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 46
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -5.56,
#         "lon": -80.82
#     },
#     "dt": 1582051530,
#     "id": 3691954,
#     "main": {
#         "feels_like": 72.37,
#         "grnd_level": 1006,
#         "humidity": 86,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 73.26,
#         "temp_max": 73.26,
#         "temp_min": 73.26
#     },
#     "name": "Sechura",
#     "sys": {
#         "country": "PE",
#         "sunrise": 1582025361,
#         "sunset": 1582069526
#     },
#     "timezone": -18000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 241,
#         "speed": 14.07
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 93
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 67.45,
#         "lon": 153.68
#     },
#     "dt": 1582051531,
#     "id": 2121025,
#     "main": {
#         "feels_like": -22.25,
#         "grnd_level": 1019,
#         "humidity": 98,
#         "pressure": 1023,
#         "sea_level": 1023,
#         "temp": -11.81,
#         "temp_max": -11.81,
#         "temp_min": -11.81
#     },
#     "name": "Srednekolymsk",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1582062481,
#         "sunset": 1582092642
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "speed": 6.62
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 61
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.53,
#         "lon": 20.04
#     },
#     "dt": 1582051531,
#     "id": 1015776,
#     "main": {
#         "feels_like": 65.61,
#         "humidity": 77,
#         "pressure": 1018,
#         "temp": 69.87,
#         "temp_max": 70,
#         "temp_min": 69.8
#     },
#     "name": "Bredasdorp",
#     "sys": {
#         "country": "ZA",
#         "id": 1966,
#         "sunrise": 1581999398,
#         "sunset": 1582047079,
#         "type": 1
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 150,
#         "speed": 14.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.02,
#         "lon": 27.91
#     },
#     "dt": 1582051531,
#     "id": 1006984,
#     "main": {
#         "feels_like": 69.22,
#         "humidity": 93,
#         "pressure": 1021,
#         "temp": 66.2,
#         "temp_max": 66.2,
#         "temp_min": 66.2
#     },
#     "name": "East London",
#     "sys": {
#         "country": "ZA",
#         "id": 1912,
#         "sunrise": 1581997624,
#         "sunset": 1582045075,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "speed": 3.36
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.12,
#         "lon": -134.97
#     },
#     "dt": 1582051531,
#     "id": 4030556,
#     "main": {
#         "feels_like": 79.79,
#         "grnd_level": 1017,
#         "humidity": 79,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 78.87,
#         "temp_max": 78.87,
#         "temp_min": 78.87
#     },
#     "name": "Rikitea",
#     "sys": {
#         "country": "PF",
#         "sunrise": 1582037400,
#         "sunset": 1582083477
#     },
#     "timezone": -32400,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 92,
#         "speed": 13.58
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 66.15,
#         "lon": -65.71
#     },
#     "dt": 1582051532,
#     "id": 6096551,
#     "main": {
#         "feels_like": -33.88,
#         "humidity": 74,
#         "pressure": 1006,
#         "temp": -25.6,
#         "temp_max": -25.6,
#         "temp_min": -25.6
#     },
#     "name": "Pangnirtung",
#     "sys": {
#         "country": "CA",
#         "id": 968,
#         "sunrise": 1582028392,
#         "sunset": 1582059242,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 24140,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 100,
#         "speed": 2.24
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 32.67,
#         "lon": -17.1
#     },
#     "dt": 1582051532,
#     "id": 2264557,
#     "main": {
#         "feels_like": 47.93,
#         "humidity": 63,
#         "pressure": 1031,
#         "temp": 60.21,
#         "temp_max": 62.6,
#         "temp_min": 57.99
#     },
#     "name": "Ponta do Sol",
#     "sys": {
#         "country": "PT",
#         "id": 6894,
#         "sunrise": 1582012156,
#         "sunset": 1582052147,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "gust": 35.57,
#         "speed": 20.8
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 19
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -24.87,
#         "lon": 113.63
#     },
#     "dt": 1582051533,
#     "id": 2074865,
#     "main": {
#         "feels_like": 82.4,
#         "humidity": 88,
#         "pressure": 1008,
#         "temp": 77,
#         "temp_max": 77,
#         "temp_min": 77
#     },
#     "name": "Carnarvon",
#     "sys": {
#         "country": "AU",
#         "id": 9505,
#         "sunrise": 1582064040,
#         "sunset": 1582110307,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 230,
#         "speed": 6.93
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 18
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -25.4,
#         "lon": -70.48
#     },
#     "dt": 1582051533,
#     "id": 3870243,
#     "main": {
#         "feels_like": 68.47,
#         "grnd_level": 964,
#         "humidity": 66,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 70.32,
#         "temp_max": 70.32,
#         "temp_min": 70.32
#     },
#     "name": "Taltal",
#     "sys": {
#         "country": "CL",
#         "sunrise": 1582021775,
#         "sunset": 1582068149
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 275,
#         "speed": 8.08
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 20.86,
#         "lon": 92.31
#     },
#     "dt": 1582051533,
#     "id": 1185095,
#     "main": {
#         "feels_like": 56.16,
#         "grnd_level": 1005,
#         "humidity": 72,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 57.63,
#         "temp_max": 57.63,
#         "temp_min": 57.63
#     },
#     "name": "Teknaf",
#     "sys": {
#         "country": "BD",
#         "sunrise": 1582071544,
#         "sunset": 1582113035
#     },
#     "timezone": 21600,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 7,
#         "speed": 2.15
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 43.41,
#         "lon": -124.22
#     },
#     "dt": 1582051534,
#     "id": 5742974,
#     "main": {
#         "feels_like": 34.5,
#         "humidity": 75,
#         "pressure": 1025,
#         "temp": 41.59,
#         "temp_max": 46,
#         "temp_min": 32
#     },
#     "name": "North Bend",
#     "sys": {
#         "country": "US",
#         "id": 5239,
#         "sunrise": 1582038685,
#         "sunset": 1582077033,
#         "type": 1
#     },
#     "timezone": -28800,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 67,
#         "speed": 6.85
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -13.7,
#         "lon": -76.22
#     },
#     "dt": 1582051534,
#     "id": 3932145,
#     "main": {
#         "feels_like": 62.67,
#         "humidity": 30,
#         "pressure": 1007,
#         "temp": 71.6,
#         "temp_max": 71.6,
#         "temp_min": 71.6
#     },
#     "name": "Pisco",
#     "sys": {
#         "country": "PE",
#         "id": 8691,
#         "sunrise": 1582023832,
#         "sunset": 1582068847,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 280,
#         "speed": 11.41
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -38,
#         "lon": -57.56
#     },
#     "dt": 1582051504,
#     "id": 3430863,
#     "main": {
#         "feels_like": 64.92,
#         "humidity": 72,
#         "pressure": 1009,
#         "temp": 67.96,
#         "temp_max": 70,
#         "temp_min": 66
#     },
#     "name": "Mar del Plata",
#     "sys": {
#         "country": "AR",
#         "id": 8305,
#         "sunrise": 1582017752,
#         "sunset": 1582065971,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 230,
#         "speed": 10.29
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -2.92,
#         "lon": -39.92
#     },
#     "dt": 1582051535,
#     "id": 3393692,
#     "main": {
#         "feels_like": 89.91,
#         "grnd_level": 1005,
#         "humidity": 69,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 85.51,
#         "temp_max": 85.51,
#         "temp_min": 85.51
#     },
#     "name": "Itarema",
#     "rain": {
#         "3h": 1.94
#     },
#     "sys": {
#         "country": "BR",
#         "sunrise": 1582015678,
#         "sunset": 1582059578
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 73,
#         "speed": 9.73
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 33.27,
#         "lon": 131.49
#     },
#     "dt": 1582051535,
#     "id": 1864750,
#     "main": {
#         "feels_like": 24.55,
#         "grnd_level": 1001,
#         "humidity": 76,
#         "pressure": 1027,
#         "sea_level": 1027,
#         "temp": 30.52,
#         "temp_max": 30.52,
#         "temp_min": 30.52
#     },
#     "name": "Beppu",
#     "sys": {
#         "country": "JP",
#         "sunrise": 1582062899,
#         "sunset": 1582102875
#     },
#     "timezone": 32400,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 242,
#         "speed": 2.44
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 9
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.42,
#         "lon": 19.23
#     },
#     "dt": 1582051536,
#     "id": 3366880,
#     "main": {
#         "feels_like": 74.77,
#         "humidity": 83,
#         "pressure": 1013,
#         "temp": 72.9,
#         "temp_max": 75.99,
#         "temp_min": 70
#     },
#     "name": "Hermanus",
#     "sys": {
#         "country": "ZA",
#         "id": 2006131,
#         "sunrise": 1581999601,
#         "sunset": 1582047264,
#         "type": 3
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 141,
#         "gust": 14,
#         "speed": 8.01
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 15
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -6.13,
#         "lon": 12.37
#     },
#     "dt": 1582051535,
#     "id": 2236967,
#     "main": {
#         "feels_like": 88.32,
#         "grnd_level": 1006,
#         "humidity": 80,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 81.81,
#         "temp_max": 81.81,
#         "temp_min": 81.81
#     },
#     "name": "Soyo",
#     "sys": {
#         "country": "AO",
#         "sunrise": 1582002965,
#         "sunset": 1582047193
#     },
#     "timezone": 3600,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 237,
#         "speed": 6.82
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 43
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 18.39,
#         "lon": 42.45
#     },
#     "dt": 1582051536,
#     "id": 110690,
#     "main": {
#         "feels_like": 60.96,
#         "humidity": 42,
#         "pressure": 1026,
#         "temp": 67.06,
#         "temp_max": 68,
#         "temp_min": 66.2
#     },
#     "name": "Faya",
#     "sys": {
#         "country": "SA",
#         "id": 7396,
#         "sunrise": 1581997006,
#         "sunset": 1582038714,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 200,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.6,
#         "lon": -73.97
#     },
#     "dt": 1582051307,
#     "id": 5106841,
#     "main": {
#         "feels_like": 23.41,
#         "humidity": 80,
#         "pressure": 1021,
#         "temp": 33.35,
#         "temp_max": 37.99,
#         "temp_min": 28.99
#     },
#     "name": "Albany",
#     "rain": {
#         "1h": 0.76
#     },
#     "snow": {
#         "1h": 0.25
#     },
#     "sys": {
#         "country": "US",
#         "id": 3273,
#         "sunrise": 1582026564,
#         "sunset": 1582065035,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 1609,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         },
#         {
#             "description": "light snow",
#             "icon": "13d",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 10.29
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 84
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.65,
#         "lon": 115.33
#     },
#     "dt": 1582051254,
#     "id": 2075265,
#     "main": {
#         "feels_like": 50.95,
#         "humidity": 34,
#         "pressure": 1008,
#         "temp": 64.2,
#         "temp_max": 66.99,
#         "temp_min": 61
#     },
#     "name": "Busselton",
#     "sys": {
#         "country": "AU",
#         "id": 2011706,
#         "sunrise": 1582063037,
#         "sunset": 1582110494,
#         "type": 3
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 109,
#         "speed": 18.07
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -54.8,
#         "lon": -68.3
#     },
#     "dt": 1582051537,
#     "id": 3833367,
#     "main": {
#         "feels_like": 38.01,
#         "humidity": 66,
#         "pressure": 978,
#         "temp": 51.8,
#         "temp_max": 51.8,
#         "temp_min": 51.8
#     },
#     "name": "Ushuaia",
#     "sys": {
#         "country": "AR",
#         "id": 8303,
#         "sunrise": 1582018351,
#         "sunset": 1582070527,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light intensity drizzle",
#             "icon": "09d",
#             "id": 300,
#             "main": "Drizzle"
#         }
#     ],
#     "wind": {
#         "deg": 230,
#         "gust": 32.21,
#         "speed": 20.8
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -41.87,
#         "lon": -73.82
#     },
#     "dt": 1582051537,
#     "id": 3899695,
#     "main": {
#         "feels_like": 53.56,
#         "humidity": 63,
#         "pressure": 1016,
#         "temp": 62.6,
#         "temp_max": 62.6,
#         "temp_min": 62.6
#     },
#     "name": "Ancud",
#     "sys": {
#         "country": "CL",
#         "id": 8512,
#         "sunrise": 1582021307,
#         "sunset": 1582070220,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "shower rain",
#             "icon": "09d",
#             "id": 521,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 280,
#         "speed": 16.11
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 27
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.6,
#         "lon": 73.08
#     },
#     "dt": 1582051538,
#     "id": 1282256,
#     "main": {
#         "feels_like": 86.58,
#         "grnd_level": 1012,
#         "humidity": 77,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 83.21,
#         "temp_max": 83.21,
#         "temp_min": 83.21
#     },
#     "name": "Hithadhoo",
#     "rain": {
#         "3h": 0.94
#     },
#     "sys": {
#         "country": "MV",
#         "sunrise": 1581988675,
#         "sunset": 1582032343
#     },
#     "timezone": 18000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 47,
#         "speed": 12.66
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 38
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 10.27,
#         "lon": 13.26
#     },
#     "dt": 1582051538,
#     "id": 2329821,
#     "main": {
#         "feels_like": 68.2,
#         "grnd_level": 921,
#         "humidity": 18,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 77.16,
#         "temp_max": 77.16,
#         "temp_min": 77.16
#     },
#     "name": "Mubi",
#     "sys": {
#         "country": "NG",
#         "sunrise": 1582003580,
#         "sunset": 1582046150
#     },
#     "timezone": 3600,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 359,
#         "speed": 9.17
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 19.28,
#         "lon": -81.25
#     },
#     "dt": 1582051334,
#     "id": 3580733,
#     "main": {
#         "feels_like": 88.34,
#         "humidity": 66,
#         "pressure": 1015,
#         "temp": 85.6,
#         "temp_max": 86,
#         "temp_min": 84.99
#     },
#     "name": "Bodden Town",
#     "sys": {
#         "country": "KY",
#         "id": 7265,
#         "sunrise": 1582026731,
#         "sunset": 1582068362,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 130,
#         "speed": 11.41
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 27.73,
#         "lon": -82.74
#     },
#     "dt": 1582051539,
#     "id": 4171522,
#     "main": {
#         "feels_like": 90.23,
#         "humidity": 74,
#         "pressure": 1020,
#         "temp": 83.93,
#         "temp_max": 87.01,
#         "temp_min": 80.6
#     },
#     "name": "Saint Pete Beach",
#     "sys": {
#         "country": "US",
#         "id": 6046,
#         "sunrise": 1582027578,
#         "sunset": 1582068230,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "speed": 6.93
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.08,
#         "lon": -159.32
#     },
#     "dt": 1582051539,
#     "id": 5848280,
#     "main": {
#         "feels_like": 62.4,
#         "humidity": 69,
#         "pressure": 1021,
#         "temp": 70.81,
#         "temp_max": 73.4,
#         "temp_min": 66.2
#     },
#     "name": "Kapaa",
#     "sys": {
#         "country": "US",
#         "id": 7873,
#         "sunrise": 1582045615,
#         "sunset": 1582086950,
#         "type": 1
#     },
#     "timezone": -36000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "gust": 29.97,
#         "speed": 20.8
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 32
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.7,
#         "lon": 133.88
#     },
#     "dt": 1582051539,
#     "id": 2077895,
#     "main": {
#         "feels_like": 69.69,
#         "humidity": 27,
#         "pressure": 1014,
#         "temp": 77,
#         "temp_max": 77,
#         "temp_min": 77
#     },
#     "name": "Alice Springs",
#     "sys": {
#         "country": "AU",
#         "id": 9483,
#         "sunrise": 1582059250,
#         "sunset": 1582105377,
#         "type": 1
#     },
#     "timezone": 34200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 150,
#         "speed": 9.17
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.93,
#         "lon": 18.42
#     },
#     "dt": 1582051323,
#     "id": 3369157,
#     "main": {
#         "feels_like": 66.36,
#         "humidity": 60,
#         "pressure": 1013,
#         "temp": 72.36,
#         "temp_max": 75.99,
#         "temp_min": 66.99
#     },
#     "name": "Cape Town",
#     "sys": {
#         "country": "ZA",
#         "id": 1899,
#         "sunrise": 1581999833,
#         "sunset": 1582047421,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 160,
#         "speed": 14.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 23
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 20.93,
#         "lon": -17.03
#     },
#     "dt": 1582051540,
#     "id": 2377457,
#     "main": {
#         "feels_like": 78.15,
#         "humidity": 44,
#         "pressure": 1014,
#         "temp": 80.6,
#         "temp_max": 80.6,
#         "temp_min": 80.6
#     },
#     "name": "Nouadhibou",
#     "sys": {
#         "country": "MR",
#         "id": 2444,
#         "sunrise": 1582011416,
#         "sunset": 1582052853,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 8000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 340,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 96
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.59,
#         "lon": 26.89
#     },
#     "dt": 1582051540,
#     "id": 964432,
#     "main": {
#         "feels_like": 69.21,
#         "humidity": 96,
#         "pressure": 1020,
#         "temp": 64.99,
#         "temp_max": 64.99,
#         "temp_min": 64.99
#     },
#     "name": "Port Alfred",
#     "rain": {
#         "3h": 0.25
#     },
#     "sys": {
#         "country": "ZA",
#         "id": 2011314,
#         "sunrise": 1581997825,
#         "sunset": 1582045363,
#         "type": 3
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 7,
#         "gust": 5.01,
#         "speed": 1.01
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 38.52,
#         "lon": -28.7
#     },
#     "dt": 1582051541,
#     "id": 3372707,
#     "main": {
#         "feels_like": 49.93,
#         "humidity": 67,
#         "pressure": 1035,
#         "temp": 57.2,
#         "temp_max": 57.2,
#         "temp_min": 57.2
#     },
#     "name": "Ribeira Grande",
#     "sys": {
#         "country": "PT",
#         "id": 6883,
#         "sunrise": 1582015368,
#         "sunset": 1582054503,
#         "type": 1
#     },
#     "timezone": -3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 150,
#         "speed": 11.41
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 34.06,
#         "lon": 108.63
#     },
#     "dt": 1582051541,
#     "id": 1785572,
#     "main": {
#         "feels_like": 31.78,
#         "humidity": 63,
#         "pressure": 1023,
#         "temp": 38.53,
#         "temp_max": 45,
#         "temp_min": 28.4
#     },
#     "name": "Yuxia",
#     "sys": {
#         "country": "CN",
#         "id": 9645,
#         "sunrise": 1582068436,
#         "sunset": 1582108311,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 7000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "speed": 4.47
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -28.77,
#         "lon": 114.6
#     },
#     "dt": 1582051542,
#     "id": 2070998,
#     "main": {
#         "feels_like": 75.31,
#         "humidity": 61,
#         "pressure": 1010,
#         "temp": 78.8,
#         "temp_max": 78.8,
#         "temp_min": 78.8
#     },
#     "name": "Geraldton",
#     "sys": {
#         "country": "AU",
#         "id": 9522,
#         "sunrise": 1582063556,
#         "sunset": 1582110325,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 14.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -53.15,
#         "lon": -70.92
#     },
#     "dt": 1582051542,
#     "id": 3874787,
#     "main": {
#         "feels_like": 25.99,
#         "humidity": 54,
#         "pressure": 986,
#         "temp": 53.96,
#         "temp_max": 55.4,
#         "temp_min": 53.01
#     },
#     "name": "Punta Arenas",
#     "sys": {
#         "country": "CL",
#         "id": 8487,
#         "sunrise": 1582019246,
#         "sunset": 1582070889,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 270,
#         "gust": 59.73,
#         "speed": 44.96
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 64.52,
#         "lon": 34.77
#     },
#     "dt": 1582051542,
#     "id": 577922,
#     "main": {
#         "feels_like": 24.26,
#         "grnd_level": 982,
#         "humidity": 95,
#         "pressure": 982,
#         "sea_level": 982,
#         "temp": 34.86,
#         "temp_max": 34.86,
#         "temp_min": 34.86
#     },
#     "name": "Belomorsk",
#     "snow": {
#         "3h": 0.5
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1582003852,
#         "sunset": 1582035554
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 247,
#         "speed": 12.88
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 73
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -1.2,
#         "lon": -46.02
#     },
#     "dt": 1582051543,
#     "id": 3402648,
#     "main": {
#         "feels_like": 81.14,
#         "grnd_level": 1009,
#         "humidity": 84,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 80.78,
#         "temp_max": 80.78,
#         "temp_min": 80.78
#     },
#     "name": "Carutapera",
#     "rain": {
#         "3h": 3
#     },
#     "sys": {
#         "country": "BR",
#         "sunrise": 1582017228,
#         "sunset": 1582060955
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 24,
#         "speed": 18.23
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 38.98,
#         "lon": -76.94
#     },
#     "dt": 1582051331,
#     "id": 4351977,
#     "main": {
#         "feels_like": 49.05,
#         "humidity": 47,
#         "pressure": 1019,
#         "temp": 56.44,
#         "temp_max": 60.01,
#         "temp_min": 53.01
#     },
#     "name": "College Park",
#     "sys": {
#         "country": "US",
#         "id": 4115,
#         "sunrise": 1582026972,
#         "sunset": 1582066053,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 210,
#         "gust": 16.11,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -42.88,
#         "lon": 147.33
#     },
#     "dt": 1582051543,
#     "id": 2163355,
#     "main": {
#         "feels_like": 38.97,
#         "humidity": 62,
#         "pressure": 1007,
#         "temp": 52.86,
#         "temp_max": 57.2,
#         "temp_min": 48
#     },
#     "name": "Hobart",
#     "sys": {
#         "country": "AU",
#         "id": 9545,
#         "sunrise": 1582054562,
#         "sunset": 1582103609,
#         "type": 1
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 160,
#         "speed": 20.8
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.29,
#         "lon": 23.49
#     },
#     "dt": 1582051544,
#     "id": 939676,
#     "main": {
#         "feels_like": 58.77,
#         "grnd_level": 898,
#         "humidity": 79,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 64.44,
#         "temp_max": 64.44,
#         "temp_min": 64.44
#     },
#     "name": "Willowmore",
#     "sys": {
#         "country": "ZA",
#         "sunrise": 1581998665,
#         "sunset": 1582046156
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 77,
#         "speed": 14.45
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 4
# ...
#         "grnd_level": 985,
#         "humidity": 73,
#         "pressure": 986,
#         "sea_level": 986,
#         "temp": 42.8,
#         "temp_max": 42.8,
#         "temp_min": 42.8
#     },
#     "name": "Vagur",
#     "sys": {
#         "country": "FO",
#         "sunrise": 1582013054,
#         "sunset": 1582046310
#     },
#     "timezone": 0,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 302,
#         "speed": 19.35
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.1,
#         "lon": 146.27
#     },
#     "dt": 1582051722,
#     "id": 2171722,
#     "main": {
#         "feels_like": 82.74,
#         "grnd_level": 975,
#         "humidity": 91,
#         "pressure": 1006,
#         "sea_level": 1006,
#         "temp": 75.97,
#         "temp_max": 75.97,
#         "temp_min": 75.97
#     },
#     "name": "Charters Towers",
#     "sys": {
#         "country": "AU",
#         "sunrise": 1582056488,
#         "sunset": 1582102192
#     },
#     "timezone": 36000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 67,
#         "speed": 4.5
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 54.72,
#         "lon": 135.31
#     },
#     "dt": 1582051722,
#     "id": 2025256,
#     "main": {
#         "feels_like": -2.47,
#         "grnd_level": 990,
#         "humidity": 87,
#         "pressure": 1019,
#         "sea_level": 1019,
#         "temp": 5.22,
#         "temp_max": 5.22,
#         "temp_min": 5.22
#     },
#     "name": "Chumikan",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1582064051,
#         "sunset": 1582099889
#     },
#     "timezone": 36000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 258,
#         "speed": 2.62
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 29
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 41.82,
#         "lon": 140.65
#     },
#     "dt": 1582051722,
#     "id": 2129766,
#     "main": {
#         "feels_like": 9.81,
#         "grnd_level": 972,
#         "humidity": 95,
#         "pressure": 1018,
#         "sea_level": 1018,
#         "temp": 17.71,
#         "temp_max": 17.71,
#         "temp_min": 17.71
#     },
#     "name": "Kamiiso",
#     "sys": {
#         "country": "JP",
#         "sunrise": 1582061353,
#         "sunset": 1582100025
#     },
#     "timezone": 32400,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 289,
#         "speed": 4.61
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -4.39,
#         "lon": -59.59
#     },
#     "dt": 1582051723,
#     "id": 3405051,
#     "main": {
#         "feels_like": 98.38,
#         "grnd_level": 1002,
#         "humidity": 48,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 93.42,
#         "temp_max": 93.42,
#         "temp_min": 93.42
#     },
#     "name": "Borba",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1582020325,
#         "sunset": 1582064372
#     },
#     "timezone": -14400,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 43,
#         "speed": 5.39
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 7
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 16.13,
#         "lon": 119.78
#     },
#     "dt": 1582051723,
#     "id": 1731298,
#     "main": {
#         "feels_like": 67.75,
#         "grnd_level": 1000,
#         "humidity": 71,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 68.16,
#         "temp_max": 68.16,
#         "temp_min": 68.16
#     },
#     "name": "Aloleng",
#     "sys": {
#         "country": "PH",
#         "sunrise": 1582064701,
#         "sunset": 1582106694
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 105,
#         "speed": 5.53
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 32
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -18.06,
#         "lon": 13.84
#     },
#     "dt": 1582051723,
#     "id": 3354077,
#     "main": {
#         "feels_like": 66.34,
#         "grnd_level": 872,
#         "humidity": 26,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 76.98,
#         "temp_max": 76.98,
#         "temp_min": 76.98
#     },
#     "name": "Opuwo",
#     "sys": {
#         "country": "NA",
#         "sunrise": 1582001971,
#         "sunset": 1582047481
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 218,
#         "speed": 14.76
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 61.08,
#         "lon": 44.61
#     },
#     "dt": 1582051724,
#     "id": 533916,
#     "main": {
#         "feels_like": 22.82,
#         "grnd_level": 975,
#         "humidity": 96,
#         "pressure": 995,
#         "sea_level": 995,
#         "temp": 34.36,
#         "temp_max": 34.36,
#         "temp_min": 34.36
#     },
#     "name": "Loyga",
#     "snow": {
#         "3h": 0.38
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1582000653,
#         "sunset": 1582034031
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 240,
#         "speed": 14.5
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 53.1,
#         "lon": 57.44
#     },
#     "dt": 1582051724,
#     "id": 488618,
#     "main": {
#         "feels_like": 12.7,
#         "grnd_level": 958,
#         "humidity": 91,
#         "pressure": 1023,
#         "sea_level": 1023,
#         "temp": 27.68,
#         "temp_max": 27.68,
#         "temp_min": 27.68
#     },
#     "name": "Starosubkhangulovo",
#     "snow": {
#         "3h": 2.13
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581996214,
#         "sunset": 1582032311
#     },
#     "timezone": 18000,
#     "weather": [
#         {
#             "description": "snow",
#             "icon": "13n",
#             "id": 601,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "speed": 18.72
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 84
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 3.82,
#         "lon": 117.25
#     },
#     "dt": 1582051724,
#     "id": 1627877,
#     "main": {
#         "feels_like": 80.2,
#         "grnd_level": 1010,
#         "humidity": 88,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 75.02,
#         "temp_max": 75.02,
#         "temp_min": 75.02
#     },
#     "name": "Sembakung",
#     "sys": {
#         "country": "ID",
#         "sunrise": 1582064689,
#         "sunset": 1582107920
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 4,
#         "speed": 5.46
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.09,
#         "lon": -78.58
#     },
#     "dt": 1582051725,
#     "id": 3698304,
#     "main": {
#         "feels_like": 82.08,
#         "grnd_level": 985,
#         "humidity": 50,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 84.61,
#         "temp_max": 84.61,
#         "temp_min": 84.61
#     },
#     "name": "Chimbote",
#     "sys": {
#         "country": "PE",
#         "sunrise": 1582024642,
#         "sunset": 1582069170
#     },
#     "timezone": -18000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 215,
#         "speed": 13.04
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 71
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 63.05,
#         "lon": 179.32
#     },
#     "dt": 1582051725,
#     "id": 2126710,
#     "main": {
#         "feels_like": -26.95,
#         "grnd_level": 1006,
#         "humidity": 82,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": -8.9,
#         "temp_max": -8.9,
#         "temp_min": -8.9
#     },
#     "name": "Beringovskiy",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1582055059,
#         "sunset": 1582087758
#     },
#     "timezone": 43200,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 334,
#         "speed": 20.11
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 49.78,
#         "lon": -74.85
#     },
#     "dt": 1582051725,
#     "id": 5919850,
#     "main": {
#         "feels_like": -2.22,
#         "humidity": 78,
#         "pressure": 1008,
#         "temp": 12.2,
#         "temp_max": 12.2,
#         "temp_min": 12.2
#     },
#     "name": "Chapais",
#     "sys": {
#         "country": "CA",
#         "id": 859,
#         "sunrise": 1582027503,
#         "sunset": 1582064519,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 2816,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13d",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 150,
#         "gust": 24.16,
#         "speed": 14.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 13
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 6.5,
#         "lon": 2.6
#     },
#     "dt": 1582051726,
#     "id": 2392087,
#     "main": {
#         "feels_like": 91.69,
#         "humidity": 89,
#         "pressure": 1009,
#         "temp": 84.2,
#         "temp_max": 84.2,
#         "temp_min": 84.2
#     },
#     "name": "Porto-Novo",
#     "sys": {
#         "country": "BJ",
#         "id": 1119,
#         "sunrise": 1582005947,
#         "sunset": 1582048901,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 3500,
#     "weather": [
#         {
#             "description": "haze",
#             "icon": "50n",
#             "id": 721,
#             "main": "Haze"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "speed": 11.41
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 8
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 15.17,
#         "lon": 44.32
#     },
#     "dt": 1582051726,
#     "id": 70979,
#     "main": {
#         "feels_like": 53.82,
#         "grnd_level": 778,
#         "humidity": 30,
#         "pressure": 1016,
#         "sea_level": 1016,
#         "temp": 58.73,
#         "temp_max": 58.73,
#         "temp_min": 58.73
#     },
#     "name": "Sayyan",
#     "sys": {
#         "country": "YE",
#         "sunrise": 1581996384,
#         "sunset": 1582038439
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 35,
#         "speed": 1.28
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 30.7,
#         "lon": 70.65
#     },
#     "dt": 1582051727,
#     "id": 1163724,
#     "main": {
#         "feels_like": 61.59,
#         "grnd_level": 968,
#         "humidity": 13,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 70.75,
#         "temp_max": 70.75,
#         "temp_min": 70.75
#     },
#     "name": "Taunsa",
#     "sys": {
#         "country": "PK",
#         "sunrise": 1581990977,
#         "sunset": 1582031207
#     },
#     "timezone": 18000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 274,
#         "speed": 7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 32.63,
#         "lon": -16.85
#     },
#     "dt": 1582051727,
#     "id": 2270258,
#     "main": {
#         "feels_like": 47.43,
#         "humidity": 72,
#         "pressure": 1031,
#         "temp": 59.56,
#         "temp_max": 60.8,
#         "temp_min": 57.99
#     },
#     "name": "Canico",
#     "sys": {
#         "country": "PT",
#         "id": 6894,
#         "sunrise": 1582012093,
#         "sunset": 1582052090,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "speed": 21.92
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 31
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.78,
#         "lon": -45.36
#     },
#     "dt": 1582051727,
#     "id": 3461425,
#     "main": {
#         "feels_like": 83.79,
#         "grnd_level": 1009,
#         "humidity": 77,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 83.03,
#         "temp_max": 83.03,
#         "temp_min": 83.03
#     },
#     "name": "Ilhabela",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1582015845,
#         "sunset": 1582062022
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 95,
#         "speed": 17.11
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -26.18,
#         "lon": -58.18
#     },
#     "dt": 1582051728,
#     "id": 3433899,
#     "main": {
#         "feels_like": 77.31,
#         "humidity": 94,
#         "pressure": 1012,
#         "temp": 73.4,
#         "temp_max": 73.4,
#         "temp_min": 73.4
#     },
#     "name": "Formosa",
#     "sys": {
#         "country": "AR",
#         "id": 8259,
#         "sunrise": 1582018772,
#         "sunset": 1582065248,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 4000,
#     "weather": [
#         {
#             "description": "thunderstorm with light rain",
#             "icon": "11d",
#             "id": 200,
#             "main": "Thunderstorm"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 8.05
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 18.83,
#         "lon": 100.67
#     },
#     "dt": 1582051728,
#     "id": 1608451,
#     "main": {
#         "feels_like": 64.24,
#         "grnd_level": 945,
#         "humidity": 62,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 65.52,
#         "temp_max": 65.52,
#         "temp_min": 65.52
#     },
#     "name": "Nan",
#     "sys": {
#         "country": "TH",
#         "sunrise": 1582069429,
#         "sunset": 1582111138
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 122,
#         "speed": 3.49
#     }
# }

# %%
# Zipping my list together to create a dataframe
zip_csv = zip(city_name, cloudiness, country, date, humidity, lat, lng, max_temp, wind_speed)

# Creating a csv file of my lists results
with open(output_data_file, 'w', newline='') as datafile:
    writer = csv.writer(datafile)
    
    # Initialize csv.writer
    csvwriter = csv.writer(datafile, delimiter=',')
    
    # Writing the header row
    writer.writerow(["City", "Cloudiness", "Country", "Date", "Humidity", "Latitude", "Longitude", "Max Temp", "Wind Speed"])
    
    # Writing in zipped rows
    writer.writerows(zip_csv)

# %%
# Creating a dataframe and adding a count
data_list = {"City" : city_name, 
              "Cloudiness" : cloudiness, 
              "Country" : country, 
              "Date" : date, 
              "Humidity" : humidity, 
              "Latitude" : lat, 
              "Longitude" : lng, 
              "Max Temp" : max_temp, 
              "Wind Speed" : wind_speed}
plot_data = pd.DataFrame(data_list)
plot_data.count()
# Out:
# City          570
# Cloudiness    570
# Country       570
# Date          570
# Humidity      570
# Latitude      570
# Longitude     570
# Max Temp      570
# Wind Speed    570
# dtype: int64

# %%
plot_data
# Out:
#           City  Cloudiness Country        Date  Humidity  Latitude  Longitude  \
# 0       Avarua         100      CK  1581991646        78    -21.21    -159.78
# 1       Touros          20      BR  1581991647        83     -5.20     -35.46
# 2      Rikitea         100      PF  1581991647        77    -23.12    -134.97
# 3      Mataura          99      NZ  1581991647        83    -46.19     168.86
# 4     Hermanus          66      ZA  1581991648        88    -34.42      19.23
# ..         ...         ...     ...         ...       ...       ...        ...
# 565   Carolina          90      PR  1581991884        88     18.38     -65.96
# 566  Ketchikan          75      US  1581991885        86     55.34    -131.65
# 567   Araioses         100      BR  1581991886        93     -2.89     -41.90
# 568     Noumea          75      NC  1581991889        58    -22.28     166.46
# 569    Lesnoye          86      RU  1581991889        88     58.28      35.52
#
#      Max Temp  Wind Speed
# 0       82.40       14.99
# 1       80.60        8.05
# 2       79.43       13.87
# 3       66.99        3.00
# 4       64.99        8.01
# ..        ...         ...
# 565     75.20       13.87
# 566     42.80        6.93
# 567     76.08        4.18
# 568     87.80        8.05
# 569     35.06       14.65
#
# [570 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Max Temp"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsMaxTemp.png")

# Lets take a look
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Humidity"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsHumidity.png")

# Lets take a look
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Cloudiness"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsCloudiness.png")

# Lets take a look
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Wind Speed"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsWindSpeed.png")

# Lets take a look
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_data = plot_data.loc[plot_data['Latitude'] > 0,:]
southern_data = plot_data.loc[plot_data['Latitude'] < 0,:]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Filtering for north of the hemishere and Max Temp
x_values = northern_data["Latitude"]
y_values = northern_data["Max Temp"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(5,-30),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Max Temp")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("N_LinearRegressMaxTemp.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: -0.8488883458893371

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Filtering for South of the hemisphere and Max Temp
x_values = southern_data["Latitude"]
y_values = southern_data["Max Temp"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-30,55),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Max Temp")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("S_LinearRegressMaxTemp.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: 0.4587576316861053

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Filtering Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = northern_data["Latitude"]
y_values = northern_data["Humidity"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("N_LinearRegressHumidity.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: 0.4171702998268354

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Filter Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression
x_values = southern_data["Latitude"]
y_values = southern_data["Humidity"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-55,25),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("S_LinearRegressHumidity.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: 0.20500202700921266

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Filter Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = northern_data["Latitude"]
y_values = northern_data["Cloudiness"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(45,10),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("N_LinearRegressCloudiness.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: 0.36692195914904485

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Filter Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression
x_values = southern_data["Latitude"]
y_values = southern_data["Cloudiness"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-55,10),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("S_LinearRegressCloudiness.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: 0.21570595544014548

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Filter Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = northern_data["Latitude"]
y_values = northern_data["Wind Speed"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(5,38),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("N_LinearRegressWindSpeed.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: 0.09647376104332572

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Filter Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
x_values = southern_data["Latitude"]
y_values = southern_data["Wind Speed"]

# Linear regression
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# Building a scatter plot for Lat and max temp
plt.scatter(x_values, y_values)

# Plotting regression line
plt.plot(x_values, regress_values, "r-")
plt.annotate(line_eq,(-55,21),fontsize=15,color="red")

# Incorporating the other graph properties
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")

print(f"The r-squared is: {rvalue}")

# Saving the figure
plt.savefig("S_LinearRegressWindSpeed.png")

# Lets take a look
plt.show()
# Out:
# The r-squared is: -0.15140427147371938
