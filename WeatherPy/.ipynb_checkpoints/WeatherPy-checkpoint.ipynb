# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import json
from datetime import datetime
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)
        
# Print the city count to confirm sufficient count
len(cities)
# Out:
# 647

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Adding a counter to call in sets of 50
counter = 0

print("Beginning Data Retrieval")
print("-------------------------------------")
# Making a request for each city
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 1 | {cities[x]}")
    counter += 1
    if counter == 50:
        break
        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 2 | {cities[x + 50]}")
    counter += 1
    if counter == 50:
        break
        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 3 | {cities[x + 100]}")
    counter += 1
    if counter == 50:
        break
        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 4 | {cities[x + 150]}")
    counter += 1
    if counter == 50:
        break
        
counter = 0      
for x in range(len(cities)):
    print(f"Processing Record {x} of Set 5 | {cities[x + 200]}")
    counter += 1
    if counter == 50:
        break
        
print("----------------------------")
print("Data Retrieval Complete")
print("----------------------------")
# Out:
# Beginning Data Retrieval
# -------------------------------------
# Processing Record 0 of Set 1 | vaini
# Processing Record 1 of Set 1 | olinda
# Processing Record 2 of Set 1 | tsihombe
# Processing Record 3 of Set 1 | georgetown
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | mataura
# Processing Record 6 of Set 1 | hobart
# Processing Record 7 of Set 1 | cagayan de tawi-tawi
# Processing Record 8 of Set 1 | killarney
# Processing Record 9 of Set 1 | hermanus
# Processing Record 10 of Set 1 | sindand
# Processing Record 11 of Set 1 | akyab
# Processing Record 12 of Set 1 | dunedin
# Processing Record 13 of Set 1 | bluff
# Processing Record 14 of Set 1 | kozulka
# Processing Record 15 of Set 1 | sitka
# Processing Record 16 of Set 1 | cape coast
# Processing Record 17 of Set 1 | mutsamudu
# Processing Record 18 of Set 1 | barrow
# Processing Record 19 of Set 1 | ancud
# Processing Record 20 of Set 1 | svetlogorsk
# Processing Record 21 of Set 1 | nikolskoye
# Processing Record 22 of Set 1 | jiddah
# Processing Record 23 of Set 1 | warri
# Processing Record 24 of Set 1 | bethel
# Processing Record 25 of Set 1 | peniche
# Processing Record 26 of Set 1 | qaanaaq
# Processing Record 27 of Set 1 | jamestown
# Processing Record 28 of Set 1 | tasiilaq
# Processing Record 29 of Set 1 | ushuaia
# Processing Record 30 of Set 1 | saskylakh
# Processing Record 31 of Set 1 | griffith
# Processing Record 32 of Set 1 | albany
# Processing Record 33 of Set 1 | atuona
# Processing Record 34 of Set 1 | khatanga
# Processing Record 35 of Set 1 | sorvag
# Processing Record 36 of Set 1 | kavieng
# Processing Record 37 of Set 1 | luderitz
# Processing Record 38 of Set 1 | brae
# Processing Record 39 of Set 1 | sakaiminato
# Processing Record 40 of Set 1 | rikitea
# Processing Record 41 of Set 1 | porto murtinho
# Processing Record 42 of Set 1 | kuche
# Processing Record 43 of Set 1 | vila velha
# Processing Record 44 of Set 1 | chabahar
# Processing Record 45 of Set 1 | zhigansk
# Processing Record 46 of Set 1 | dikson
# Processing Record 47 of Set 1 | pacific grove
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | fevralsk
# Processing Record 0 of Set 2 | port alfred
# Processing Record 1 of Set 2 | sistranda
# Processing Record 2 of Set 2 | gwanda
# Processing Record 3 of Set 2 | byron bay
# Processing Record 4 of Set 2 | sentyabrskiy
# Processing Record 5 of Set 2 | cidreira
# Processing Record 6 of Set 2 | bredasdorp
# Processing Record 7 of Set 2 | wurzen
# Processing Record 8 of Set 2 | nsanje
# Processing Record 9 of Set 2 | souillac
# Processing Record 10 of Set 2 | zelenets
# Processing Record 11 of Set 2 | hauterive
# Processing Record 12 of Set 2 | kodiak
# Processing Record 13 of Set 2 | barentsburg
# Processing Record 14 of Set 2 | honiara
# Processing Record 15 of Set 2 | westpunt
# Processing Record 16 of Set 2 | taolanaro
# Processing Record 17 of Set 2 | codrington
# Processing Record 18 of Set 2 | victoria
# Processing Record 19 of Set 2 | lebu
# Processing Record 20 of Set 2 | ahipara
# Processing Record 21 of Set 2 | mahebourg
# Processing Record 22 of Set 2 | rassvet
# Processing Record 23 of Set 2 | rafraf
# Processing Record 24 of Set 2 | tuktoyaktuk
# Processing Record 25 of Set 2 | mount gambier
# Processing Record 26 of Set 2 | east london
# Processing Record 27 of Set 2 | puerto ayora
# Processing Record 28 of Set 2 | killybegs
# Processing Record 29 of Set 2 | saldanha
# Processing Record 30 of Set 2 | ixtapa
# Processing Record 31 of Set 2 | sagua la grande
# Processing Record 32 of Set 2 | klaksvik
# Processing Record 33 of Set 2 | kavaratti
# Processing Record 34 of Set 2 | torbay
# Processing Record 35 of Set 2 | prince george
# Processing Record 36 of Set 2 | ilulissat
# Processing Record 37 of Set 2 | cape town
# Processing Record 38 of Set 2 | bonthe
# Processing Record 39 of Set 2 | upernavik
# Processing Record 40 of Set 2 | iqaluit
# Processing Record 41 of Set 2 | broome
# Processing Record 42 of Set 2 | tabuk
# Processing Record 43 of Set 2 | sapa
# Processing Record 44 of Set 2 | haacht
# Processing Record 45 of Set 2 | gushikawa
# Processing Record 46 of Set 2 | sorland
# Processing Record 47 of Set 2 | galle
# Processing Record 48 of Set 2 | zharkent
# Processing Record 49 of Set 2 | nenjiang
# Processing Record 0 of Set 3 | thompson
# Processing Record 1 of Set 3 | lagoa
# Processing Record 2 of Set 3 | marsaxlokk
# Processing Record 3 of Set 3 | eureka
# Processing Record 4 of Set 3 | busselton
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | ribeira grande
# Processing Record 7 of Set 3 | kristiansund
# Processing Record 8 of Set 3 | kaitangata
# Processing Record 9 of Set 3 | cururupu
# Processing Record 10 of Set 3 | beitbridge
# Processing Record 11 of Set 3 | pyaozerskiy
# Processing Record 12 of Set 3 | mangrol
# Processing Record 13 of Set 3 | talnakh
# Processing Record 14 of Set 3 | mar del plata
# Processing Record 15 of Set 3 | aksu
# Processing Record 16 of Set 3 | port elizabeth
# Processing Record 17 of Set 3 | arraial do cabo
# Processing Record 18 of Set 3 | binzhou
# Processing Record 19 of Set 3 | waipawa
# Processing Record 20 of Set 3 | yerofey pavlovich
# Processing Record 21 of Set 3 | la seyne-sur-mer
# Processing Record 22 of Set 3 | chase
# Processing Record 23 of Set 3 | butaritari
# Processing Record 24 of Set 3 | tura
# Processing Record 25 of Set 3 | kayunga
# Processing Record 26 of Set 3 | sorong
# Processing Record 27 of Set 3 | provideniya
# Processing Record 28 of Set 3 | strezhevoy
# Processing Record 29 of Set 3 | illoqqortoormiut
# Processing Record 30 of Set 3 | atikokan
# Processing Record 31 of Set 3 | srednekolymsk
# Processing Record 32 of Set 3 | avarua
# Processing Record 33 of Set 3 | pisco
# Processing Record 34 of Set 3 | kapaa
# Processing Record 35 of Set 3 | leningradskiy
# Processing Record 36 of Set 3 | esperance
# Processing Record 37 of Set 3 | coron
# Processing Record 38 of Set 3 | olafsvik
# Processing Record 39 of Set 3 | wulanhaote
# Processing Record 40 of Set 3 | mys shmidta
# Processing Record 41 of Set 3 | paamiut
# Processing Record 42 of Set 3 | san jose
# Processing Record 43 of Set 3 | castro
# Processing Record 44 of Set 3 | ponta do sol
# Processing Record 45 of Set 3 | san quintin
# Processing Record 46 of Set 3 | lawrenceburg
# Processing Record 47 of Set 3 | labuhan
# Processing Record 48 of Set 3 | palana
# Processing Record 49 of Set 3 | longhua
# Processing Record 0 of Set 4 | falealupo
# Processing Record 1 of Set 4 | daru
# Processing Record 2 of Set 4 | phan rang
# Processing Record 3 of Set 4 | poso
# Processing Record 4 of Set 4 | katsuura
# Processing Record 5 of Set 4 | faanui
# Processing Record 6 of Set 4 | hilo
# Processing Record 7 of Set 4 | port hardy
# Processing Record 8 of Set 4 | pacocha
# Processing Record 9 of Set 4 | aykhal
# Processing Record 10 of Set 4 | hofn
# Processing Record 11 of Set 4 | la ronge
# Processing Record 12 of Set 4 | coahuayana
# Processing Record 13 of Set 4 | shingu
# Processing Record 14 of Set 4 | wahran
# Processing Record 15 of Set 4 | concepcion del oro
# Processing Record 16 of Set 4 | nova prata
# Processing Record 17 of Set 4 | alexandria
# Processing Record 18 of Set 4 | tabiauea
# Processing Record 19 of Set 4 | akhmeta
# Processing Record 20 of Set 4 | marawi
# Processing Record 21 of Set 4 | sioux city
# Processing Record 22 of Set 4 | touros
# Processing Record 23 of Set 4 | novo aripuana
# Processing Record 24 of Set 4 | ribeira brava
# Processing Record 25 of Set 4 | arica
# Processing Record 26 of Set 4 | tucuman
# Processing Record 27 of Set 4 | tifton
# Processing Record 28 of Set 4 | mehamn
# Processing Record 29 of Set 4 | nemuro
# Processing Record 30 of Set 4 | matara
# Processing Record 31 of Set 4 | naze
# Processing Record 32 of Set 4 | yellowknife
# Processing Record 33 of Set 4 | lishu
# Processing Record 34 of Set 4 | pevek
# Processing Record 35 of Set 4 | bambous virieux
# Processing Record 36 of Set 4 | amderma
# Processing Record 37 of Set 4 | belushya guba
# Processing Record 38 of Set 4 | hasaki
# Processing Record 39 of Set 4 | sydney
# Processing Record 40 of Set 4 | jalu
# Processing Record 41 of Set 4 | cheuskiny
# Processing Record 42 of Set 4 | trairi
# Processing Record 43 of Set 4 | annau
# Processing Record 44 of Set 4 | indramayu
# Processing Record 45 of Set 4 | saint george
# Processing Record 46 of Set 4 | kimbe
# Processing Record 47 of Set 4 | tezu
# Processing Record 48 of Set 4 | cherskiy
# Processing Record 49 of Set 4 | jhelum
# Processing Record 0 of Set 5 | skibbereen
# Processing Record 1 of Set 5 | lusambo
# Processing Record 2 of Set 5 | petropavlovsk-kamchatskiy
# Processing Record 3 of Set 5 | tumannyy
# Processing Record 4 of Set 5 | stephenville
# Processing Record 5 of Set 5 | ostrovnoy
# Processing Record 6 of Set 5 | carnarvon
# Processing Record 7 of Set 5 | saint-pierre
# Processing Record 8 of Set 5 | rosetta
# Processing Record 9 of Set 5 | luau
# Processing Record 10 of Set 5 | mangai
# Processing Record 11 of Set 5 | port lincoln
# Processing Record 12 of Set 5 | ust-nera
# Processing Record 13 of Set 5 | nanlong
# Processing Record 14 of Set 5 | yerbogachen
# Processing Record 15 of Set 5 | tshikapa
# Processing Record 16 of Set 5 | chimbote
# Processing Record 17 of Set 5 | namibe
# Processing Record 18 of Set 5 | saint-augustin
# Processing Record 19 of Set 5 | pran buri
# Processing Record 20 of Set 5 | sinnamary
# Processing Record 21 of Set 5 | palmer
# Processing Record 22 of Set 5 | santa isabel
# Processing Record 23 of Set 5 | saint anthony
# Processing Record 24 of Set 5 | pangnirtung
# Processing Record 25 of Set 5 | hami
# Processing Record 26 of Set 5 | lima
# Processing Record 27 of Set 5 | one hundred mile house
# Processing Record 28 of Set 5 | hambantota
# Processing Record 29 of Set 5 | westport
# Processing Record 30 of Set 5 | luwuk
# Processing Record 31 of Set 5 | chokurdakh
# Processing Record 32 of Set 5 | muhos
# Processing Record 33 of Set 5 | lensk
# Processing Record 34 of Set 5 | prince rupert
# Processing Record 35 of Set 5 | darovskoy
# Processing Record 36 of Set 5 | campo grande
# Processing Record 37 of Set 5 | sao lourenco do sul
# Processing Record 38 of Set 5 | san luis
# Processing Record 39 of Set 5 | dom pedrito
# Processing Record 40 of Set 5 | morro bay
# Processing Record 41 of Set 5 | broken hill
# Processing Record 42 of Set 5 | pringsewu
# Processing Record 43 of Set 5 | akdepe
# Processing Record 44 of Set 5 | dinar
# Processing Record 45 of Set 5 | saleaula
# Processing Record 46 of Set 5 | zhuanghe
# Processing Record 47 of Set 5 | bowen
# Processing Record 48 of Set 5 | de aar
# Processing Record 49 of Set 5 | isangel
# ----------------------------
# Data Retrieval Complete
# ----------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
url = "https://api.openweathermap.org/data/2.5/weather?"
units = "imperial"
query_url = f"{url}&appid={weather_api_key}&q="
print(query_url)

#Creating an empty list to store procossing log
city_name = []
cloudiness =[]
country = []
date = []
humidity =[]
lat = []
lng = []
max_temp = []
wind_speed = []

# Loop through the list of cities and perform a request for data on each
for city in cities:
    response = requests.get(query_url + city + "&units=" + units)
    response_json = response.json()
    print(json.dumps(response_json, indent=4, sort_keys=True))
    try:
        city_name.append(response_json['name'])
        cloudiness.append(response_json['clouds']['all'])
        country.append(response_json['sys']['country'])
        date.append(response_json['dt'])
        humidity.append(response_json['main']['humidity'])
        lat.append(response_json['coord']['lat'])
        lng.append(response_json['coord']['lon'])
        max_temp.append(response_json['main']['temp_max'])
        wind_speed.append(response_json['wind']['speed'])
    except:
        print("City not found")
        pass
# Out:
# https://api.openweathermap.org/data/2.5/weather?&appid=3c69e2440c645c6447da4ba851075ac7&q=
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.2,
#         "lon": -175.2
#     },
#     "dt": 1581963109,
#     "id": 4032243,
#     "main": {
#         "feels_like": 79.9,
#         "humidity": 78,
#         "pressure": 1004,
#         "temp": 77,
#         "temp_max": 77,
#         "temp_min": 77
#     },
#     "name": "Vaini",
#     "sys": {
#         "country": "TO",
#         "id": 7285,
#         "sunrise": 1582047174,
#         "sunset": 1582093013,
#         "type": 1
#     },
#     "timezone": 46800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 140,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -8.01,
#         "lon": -34.86
#     },
#     "dt": 1581962826,
#     "id": 3393536,
#     "main": {
#         "feels_like": 92.35,
#         "humidity": 66,
#         "pressure": 1010,
#         "temp": 87.8,
#         "temp_max": 87.8,
#         "temp_min": 87.8
#     },
#     "name": "Olinda",
#     "sys": {
#         "country": "BR",
#         "id": 8426,
#         "sunrise": 1581927795,
#         "sunset": 1581972240,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 110,
#         "speed": 10.29
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 5.41,
#         "lon": 100.34
#     },
#     "dt": 1581962992,
#     "id": 1735106,
#     "main": {
#         "feels_like": 90.16,
#         "humidity": 88,
#         "pressure": 1012,
#         "temp": 82.27,
#         "temp_max": 82.4,
#         "temp_min": 82
#     },
#     "name": "George Town",
#     "sys": {
#         "country": "MY",
#         "id": 9438,
#         "sunrise": 1581982437,
#         "sunset": 1582025497,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 9000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 150,
#         "speed": 8.05
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -53.15,
#         "lon": -70.92
#     },
#     "dt": 1581963110,
#     "id": 3874787,
#     "main": {
#         "feels_like": 39.07,
#         "humidity": 50,
#         "pressure": 996,
#         "temp": 51.49,
#         "temp_max": 51.8,
#         "temp_min": 51.01
#     },
#     "name": "Punta Arenas",
#     "sys": {
#         "country": "CL",
#         "id": 8487,
#         "sunrise": 1581932726,
#         "sunset": 1581984617,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 350,
#         "speed": 16.11
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.19,
#         "lon": 168.86
#     },
#     "dt": 1581963111,
#     "id": 6201424,
#     "main": {
#         "feels_like": 55.17,
#         "humidity": 97,
#         "pressure": 1014,
#         "temp": 55,
#         "temp_max": 55,
#         "temp_min": 55
#     },
#     "name": "Mataura",
#     "rain": {
#         "3h": 0.13
#     },
#     "sys": {
#         "country": "NZ",
#         "id": 2008959,
#         "sunrise": 1581962553,
#         "sunset": 1582012494,
#         "type": 3
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 83,
#         "gust": 7,
#         "speed": 1.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 3
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -42.88,
#         "lon": 147.33
#     },
#     "dt": 1581963111,
#     "id": 2163355,
#     "main": {
#         "feels_like": 38.66,
#         "humidity": 81,
#         "pressure": 1011,
#         "temp": 45.43,
#         "temp_max": 50,
#         "temp_min": 41
#     },
#     "name": "Hobart",
#     "sys": {
#         "country": "AU",
#         "id": 9545,
#         "sunrise": 1581968083,
#         "sunset": 1582017298,
#         "type": 1
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 300,
#         "speed": 8.05
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 52.05,
#         "lon": -9.52
#     },
#     "dt": 1581963112,
#     "id": 2963370,
#     "main": {
#         "feels_like": 31.82,
#         "humidity": 86,
#         "pressure": 1013,
#         "temp": 41,
#         "temp_max": 41,
#         "temp_min": 41
#     },
#     "name": "Killarney",
#     "sys": {
#         "country": "IE",
#         "id": 1552,
#         "sunrise": 1581925842,
#         "sunset": 1581962030,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "speed": 11.41
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 13
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.42,
#         "lon": 19.23
#     },
#     "dt": 1581963112,
#     "id": 3366880,
#     "main": {
#         "feels_like": 69.4,
#         "humidity": 78,
#         "pressure": 1014,
#         "temp": 68.45,
#         "temp_max": 69.01,
#         "temp_min": 68
#     },
#     "name": "Hermanus",
#     "sys": {
#         "country": "ZA",
#         "id": 2006131,
#         "sunrise": 1581913144,
#         "sunset": 1581960929,
#         "type": 3
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 109,
#         "gust": 11.01,
#         "speed": 5.01
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 20.15,
#         "lon": 92.9
#     },
#     "dt": 1581963113,
#     "id": 1295765,
#     "main": {
#         "feels_like": 67.24,
#         "grnd_level": 1013,
#         "humidity": 67,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 69.76,
#         "temp_max": 69.76,
#         "temp_min": 69.76
#     },
#     "name": "Sittwe",
#     "sys": {
#         "country": "MM",
#         "sunrise": 1581985001,
#         "sunset": 1582026505
#     },
#     "timezone": 23400,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 336,
#         "speed": 9.19
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 87
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -45.87,
#         "lon": 170.5
#     },
#     "dt": 1581963113,
#     "id": 2191562,
#     "main": {
#         "feels_like": 53.42,
#         "humidity": 90,
#         "pressure": 997,
#         "temp": 57.51,
#         "temp_max": 57.99,
#         "temp_min": 57
#     },
#     "name": "Dunedin",
#     "rain": {
#         "1h": 0.25
#     },
#     "sys": {
#         "country": "NZ",
#         "id": 2031989,
#         "sunrise": 1581962195,
#         "sunset": 1582012064,
#         "type": 3
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 227,
#         "speed": 9.78
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -46.6,
#         "lon": 168.33
#     },
#     "dt": 1581963113,
#     "id": 2206939,
#     "main": {
#         "feels_like": 55.17,
#         "humidity": 97,
#         "pressure": 1014,
#         "temp": 55,
#         "temp_max": 55,
#         "temp_min": 55
#     },
#     "name": "Bluff",
#     "rain": {
#         "3h": 1.94
#     },
#     "sys": {
#         "country": "NZ",
#         "id": 2008959,
#         "sunrise": 1581962632,
#         "sunset": 1582012668,
#         "type": 3
#     },
#     "timezone": 46800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 83,
#         "gust": 7,
#         "speed": 1.99
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 50.04,
#         "lon": 23.8
#     },
#     "dt": 1581963114,
#     "id": 687093,
#     "main": {
#         "feels_like": 42.98,
#         "humidity": 66,
#         "pressure": 1018,
#         "temp": 48.2,
#         "temp_max": 48.2,
#         "temp_min": 48.2
#     },
#     "name": "Kozulka",
#     "sys": {
#         "country": "UA",
#         "id": 8909,
#         "sunrise": 1581917599,
#         "sunset": 1581954281,
#         "type": 1
#     },
#     "timezone": 7200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "speed": 4.47
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 57.05,
#         "lon": -135.33
#     },
#     "dt": 1581963114,
#     "id": 5557293,
#     "main": {
#         "feels_like": 27.86,
#         "humidity": 100,
#         "pressure": 1026,
#         "temp": 33.8,
#         "temp_max": 33.8,
#         "temp_min": 33.8
#     },
#     "name": "Sitka",
#     "sys": {
#         "country": "US",
#         "id": 7795,
#         "sunrise": 1581956745,
#         "sunset": 1581991514,
#         "type": 1
#     },
#     "timezone": -32400,
#     "visibility": 14484,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 120,
#         "speed": 4.7
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 95
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 5.11,
#         "lon": -1.25
#     },
#     "dt": 1581963114,
#     "id": 2302357,
#     "main": {
#         "feels_like": 83.88,
#         "grnd_level": 1009,
#         "humidity": 85,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 81.61,
#         "temp_max": 81.61,
#         "temp_min": 81.61
#     },
#     "name": "Cape Coast",
#     "sys": {
#         "country": "GH",
#         "sunrise": 1581920412,
#         "sunset": 1581963491
#     },
#     "timezone": 0,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 215,
#         "speed": 16.11
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.29,
#         "lon": -156.79
#     },
#     "dt": 1581963115,
#     "id": 5880054,
#     "main": {
#         "feels_like": -52.19,
#         "humidity": 88,
#         "pressure": 1014,
#         "temp": -41.8,
#         "temp_max": -41.8,
#         "temp_min": -41.8
#     },
#     "name": "Barrow",
#     "sys": {
#         "country": "US",
#         "id": 7649,
#         "sunrise": 1581966228,
#         "sunset": 1581992331,
#         "type": 1
#     },
#     "timezone": -32400,
#     "visibility": 4828,
#     "weather": [
#         {
#             "description": "mist",
#             "icon": "50n",
#             "id": 701,
#             "main": "Mist"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 5.82
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -41.87,
#         "lon": -73.82
#     },
#     "dt": 1581963115,
#     "id": 3899695,
#     "main": {
#         "feels_like": 55.02,
#         "humidity": 58,
#         "pressure": 1017,
#         "temp": 59,
#         "temp_max": 59,
#         "temp_min": 59
#     },
#     "name": "Ancud",
#     "sys": {
#         "country": "CL",
#         "id": 8512,
#         "sunrise": 1581934830,
#         "sunset": 1581983905,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 80,
#         "speed": 4.7
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 52.63,
#         "lon": 29.73
#     },
#     "dt": 1581963116,
#     "id": 10722858,
#     "main": {
#         "feels_like": 35.8,
#         "grnd_level": 1000,
#         "humidity": 77,
#         "pressure": 1017,
#         "sea_level": 1017,
#         "temp": 44.04,
#         "temp_max": 44.04,
#         "temp_min": 44.04
#     },
#     "name": "Svetlogorsk",
#     "rain": {
#         "3h": 0.13
#     },
#     "sys": {
#         "country": "BY",
#         "sunrise": 1581916514,
#         "sunset": 1581952519
#     },
#     "timezone": 10800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 226,
#         "speed": 9.82
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 59.7,
#         "lon": 30.79
#     },
#     "dt": 1581963116,
#     "id": 546105,
#     "main": {
#         "feels_like": 30.43,
#         "humidity": 75,
#         "pressure": 994,
#         "temp": 40.17,
#         "temp_max": 41,
#         "temp_min": 39
#     },
#     "name": "Nikolskoye",
#     "sys": {
#         "country": "RU",
#         "id": 8926,
#         "sunrise": 1581917441,
#         "sunset": 1581951083,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light intensity shower rain",
#             "icon": "09n",
#             "id": 520,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "gust": 29.08,
#         "speed": 11.18
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 45
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 5.52,
#         "lon": 5.75
#     },
#     "dt": 1581963117,
#     "id": 2319133,
#     "main": {
#         "feels_like": 88.68,
#         "grnd_level": 1006,
#         "humidity": 62,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 85.6,
#         "temp_max": 85.6,
#         "temp_min": 85.6
#     },
#     "name": "Warri",
#     "sys": {
#         "country": "NG",
#         "sunrise": 1581918753,
#         "sunset": 1581961790
#     },
#     "timezone": 3600,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 244,
#         "speed": 9.06
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 41.37,
#         "lon": -73.41
#     },
#     "dt": 1581963117,
#     "id": 5282297,
#     "main": {
#         "feels_like": 38.53,
#         "humidity": 41,
#         "pressure": 1024,
#         "temp": 45.14,
#         "temp_max": 48.99,
#         "temp_min": 41
#     },
#     "name": "Bethel",
#     "sys": {
#         "country": "US",
#         "id": 3888,
#         "sunrise": 1581940005,
#         "sunset": 1581978534,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 210,
#         "speed": 3.36
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 39.36,
#         "lon": -9.38
#     },
#     "dt": 1581963025,
#     "id": 2264923,
#     "main": {
#         "feels_like": 46.71,
#         "humidity": 67,
#         "pressure": 1031,
#         "temp": 55.71,
#         "temp_max": 57.2,
#         "temp_min": 54
#     },
#     "name": "Peniche",
#     "sys": {
#         "country": "PT",
#         "id": 6901,
#         "sunrise": 1581924479,
#         "sunset": 1581963327,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 340,
#         "speed": 13.87
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 74
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 77.48,
#         "lon": -69.36
#     },
#     "dt": 1581963118,
#     "id": 3831208,
#     "main": {
#         "feels_like": -15.14,
#         "grnd_level": 958,
#         "humidity": 60,
#         "pressure": 998,
#         "sea_level": 998,
#         "temp": -6.41,
#         "temp_max": -6.41,
#         "temp_min": -6.41
#     },
#     "name": "Qaanaaq",
#     "sys": {
#         "country": "GL",
#         "sunrise": 1581952009,
#         "sunset": 1581964586
#     },
#     "timezone": -14400,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 54,
#         "speed": 3.42
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 1
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.1,
#         "lon": -79.24
#     },
#     "dt": 1581963118,
#     "id": 5122534,
#     "main": {
#         "feels_like": 27.5,
#         "humidity": 74,
#         "pressure": 1024,
#         "temp": 34.39,
#         "temp_max": 39.99,
#         "temp_min": 30.2
#     },
#     "name": "Jamestown",
#     "sys": {
#         "country": "US",
#         "id": 4588,
#         "sunrise": 1581941468,
#         "sunset": 1581979869,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 150,
#         "speed": 4.7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 65.61,
#         "lon": -37.64
#     },
#     "dt": 1581963118,
#     "id": 3424607,
#     "main": {
#         "feels_like": 14.32,
#         "humidity": 68,
#         "pressure": 990,
#         "temp": 30.2,
#         "temp_max": 30.2,
#         "temp_min": 30.2
#     },
#     "name": "Tasiilaq",
#     "sys": {
#         "country": "GL",
#         "id": 81,
#         "sunrise": 1581935323,
#         "sunset": 1581966046,
#         "type": 1
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 80,
#         "speed": 19.46
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -54.8,
#         "lon": -68.3
#     },
#     "dt": 1581963119,
#     "id": 3833367,
#     "main": {
#         "feels_like": 42.17,
#         "humidity": 46,
#         "pressure": 994,
#         "temp": 52.83,
#         "temp_max": 53.6,
#         "temp_min": 51.8
#     },
#     "name": "Ushuaia",
#     "sys": {
#         "country": "AR",
#         "id": 8303,
#         "sunrise": 1581931823,
#         "sunset": 1581984263,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 340,
#         "speed": 12.75
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 97
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.92,
#         "lon": 114.08
#     },
#     "dt": 1581963119,
#     "id": 2017155,
#     "main": {
#         "feels_like": -6.02,
#         "grnd_level": 1010,
#         "humidity": 91,
#         "pressure": 1020,
#         "sea_level": 1020,
#         "temp": 6.49,
#         "temp_max": 6.49,
#         "temp_min": 6.49
#     },
#     "name": "Saskylakh",
#     "snow": {
#         "3h": 0.13
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581987910,
#         "sunset": 1582013430
#     },
#     "timezone": 32400,
#     "weather": [
#         {
#             "description": "light snow",
#             "icon": "13n",
#             "id": 600,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 264,
#         "speed": 11.39
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 41.53,
#         "lon": -87.42
#     },
#     "dt": 1581963119,
#     "id": 4920986,
#     "main": {
#         "feels_like": 20.32,
#         "humidity": 48,
#         "pressure": 1018,
#         "temp": 38.26,
#         "temp_max": 41,
#         "temp_min": 35.6
#     },
#     "name": "Griffith",
#     "sys": {
#         "country": "US",
#         "id": 4309,
#         "sunrise": 1581943378,
#         "sunset": 1581981885,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 140,
#         "speed": 23.04
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.6,
#         "lon": -73.97
#     },
#     "dt": 1581962865,
#     "id": 5106841,
#     "main": {
#         "feels_like": 23.61,
#         "humidity": 44,
#         "pressure": 1026,
#         "temp": 34.83,
#         "temp_max": 39,
#         "temp_min": 30
#     },
#     "name": "Albany",
#     "sys": {
#         "country": "US",
#         "id": 3273,
#         "sunrise": 1581940250,
#         "sunset": 1581978557,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 300,
#         "speed": 10.29
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.8,
#         "lon": -139.03
#     },
#     "dt": 1581963120,
#     "id": 4020109,
#     "main": {
#         "feels_like": 78.75,
#         "grnd_level": 1009,
#         "humidity": 78,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 81.23,
#         "temp_max": 81.23,
#         "temp_min": 81.23
#     },
#     "name": "Atuona",
#     "rain": {
#         "3h": 0.12
#     },
#     "sys": {
#         "country": "PF",
#         "sunrise": 1581952704,
#         "sunset": 1581997331
#     },
#     "timezone": -34200,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 81,
#         "speed": 21.45
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 71.97,
#         "lon": 102.5
#     },
#     "dt": 1581963120,
#     "id": 2022572,
#     "main": {
#         "feels_like": -9.6,
#         "grnd_level": 1019,
#         "humidity": 90,
#         "pressure": 1022,
#         "sea_level": 1022,
#         "temp": 3,
#         "temp_max": 3,
#         "temp_min": 3
#     },
#     "name": "Khatanga",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581990709,
#         "sunset": 1582016189
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 232,
#         "speed": 11.23
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -2.57,
#         "lon": 150.8
#     },
#     "dt": 1581963121,
#     "id": 2094342,
#     "main": {
#         "feels_like": 88.72,
#         "grnd_level": 1006,
#         "humidity": 77,
#         "pressure": 1006,
#         "sea_level": 1006,
#         "temp": 83.37,
#         "temp_max": 83.37,
#         "temp_min": 83.37
#     },
#     "name": "Kavieng",
#     "sys": {
#         "country": "PG",
#         "sunrise": 1581969923,
#         "sunset": 1582013792
#     },
#     "timezone": 36000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 262,
#         "speed": 9.31
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 17
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -26.65,
#         "lon": 15.16
#     },
#     "dt": 1581963121,
#     "id": 3355672,
#     "main": {
#         "feels_like": 55.6,
#         "grnd_level": 1012,
#         "humidity": 84,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 64.36,
#         "temp_max": 64.36,
#         "temp_min": 64.36
#     },
#     "name": "Luderitz",
#     "sys": {
#         "country": "NA",
#         "sunrise": 1581914691,
#         "sunset": 1581961336
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 177,
#         "speed": 21
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 60.4,
#         "lon": -1.35
#     },
#     "dt": 1581963121,
#     "id": 2654970,
#     "main": {
#         "feels_like": 26.37,
#         "humidity": 75,
#         "pressure": 980,
#         "temp": 44.6,
#         "temp_max": 44.6,
#         "temp_min": 44.6
#     },
#     "name": "Brae",
#     "sys": {
#         "country": "GB",
#         "id": 1447,
#         "sunrise": 1581925286,
#         "sunset": 1581958665,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "shower rain",
#             "icon": "09n",
#             "id": 521,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "speed": 27.51
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 35.55,
#         "lon": 133.23
#     },
#     "dt": 1581963122,
#     "id": 1853174,
#     "main": {
#         "feels_like": 19.4,
#         "humidity": 80,
#         "pressure": 1013,
#         "temp": 35.6,
#         "temp_max": 35.6,
#         "temp_min": 35.6
#     },
#     "name": "Sakaiminato",
#     "sys": {
#         "country": "JP",
#         "id": 8028,
#         "sunrise": 1581976309,
#         "sunset": 1582015839,
#         "type": 1
#     },
#     "timezone": 32400,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "light shower snow",
#             "icon": "13n",
#             "id": 620,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 230,
#         "speed": 21.92
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -23.12,
#         "lon": -134.97
#     },
#     "dt": 1581963122,
#     "id": 4030556,
#     "main": {
#         "feels_like": 79.29,
#         "grnd_level": 1015,
#         "humidity": 80,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 78.67,
#         "temp_max": 78.67,
#         "temp_min": 78.67
#     },
#     "name": "Rikitea",
#     "rain": {
#         "3h": 0.44
#     },
#     "sys": {
#         "country": "PF",
#         "sunrise": 1581950967,
#         "sunset": 1581997119
#     },
#     "timezone": -32400,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 77,
#         "speed": 14.27
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 5
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -21.7,
#         "lon": -57.88
#     },
#     "dt": 1581963122,
#     "id": 3452712,
#     "main": {
#         "feels_like": 101.26,
#         "grnd_level": 994,
#         "humidity": 33,
#         "pressure": 1004,
#         "sea_level": 1004,
#         "temp": 101.88,
#         "temp_max": 101.88,
#         "temp_min": 101.88
#     },
#     "name": "Porto Murtinho",
#     "sys": {
#         "country": "BR",
#         "sunrise": 1581932546,
#         "sunset": 1581978538
#     },
#     "timezone": -14400,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 1,
#         "speed": 12.3
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.33,
#         "lon": -40.29
#     },
#     "dt": 1581962982,
#     "id": 3445026,
#     "main": {
#         "feels_like": 85.32,
#         "humidity": 66,
#         "pressure": 1014,
#         "temp": 84.94,
#         "temp_max": 86,
#         "temp_min": 84
#     },
#     "name": "Vila Velha",
#     "sys": {
#         "country": "BR",
#         "id": 8474,
#         "sunrise": 1581928406,
#         "sunset": 1581974235,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 60,
#         "speed": 14.99
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 71
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 25.29,
#         "lon": 60.64
#     },
#     "dt": 1581963123,
#     "id": 1161724,
#     "main": {
#         "feels_like": 66.51,
#         "grnd_level": 1013,
#         "humidity": 38,
#         "pressure": 1018,
#         "sea_level": 1018,
#         "temp": 71.06,
#         "temp_max": 71.06,
#         "temp_min": 71.06
#     },
#     "name": "Chabahar",
#     "sys": {
#         "country": "IR",
#         "sunrise": 1581906683,
#         "sunset": 1581947514
#     },
#     "timezone": 12600,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 280,
#         "speed": 5.68
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 98
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 66.77,
#         "lon": 123.37
#     },
#     "dt": 1581963124,
#     "id": 2012530,
#     "main": {
#         "feels_like": -24.75,
#         "grnd_level": 1019,
#         "humidity": 99,
#         "pressure": 1025,
#         "sea_level": 1025,
#         "temp": -17.09,
#         "temp_max": -17.09,
#         "temp_min": -17.09
#     },
#     "name": "Zhigansk",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581983338,
#         "sunset": 1582013543
#     },
#     "timezone": 32400,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 1,
#         "speed": 1.5
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 73.51,
#         "lon": 80.55
#     },
#     "dt": 1581963124,
#     "id": 1507390,
#     "main": {
#         "feels_like": -16.19,
#         "grnd_level": 1006,
#         "humidity": 91,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 4.05,
#         "temp_max": 4.05,
#         "temp_min": 4.05
#     },
#     "name": "Dikson",
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581997021,
#         "sunset": 1582020412
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 185,
#         "speed": 24.9
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 36.62,
#         "lon": -121.92
#     },
#     "dt": 1581963124,
#     "id": 5380437,
#     "main": {
#         "feels_like": 46.69,
#         "humidity": 100,
#         "pressure": 1020,
#         "temp": 53.71,
#         "temp_max": 59,
#         "temp_min": 48.2
#     },
#     "name": "Pacific Grove",
#     "sys": {
#         "country": "US",
#         "id": 5885,
#         "sunrise": 1581951245,
#         "sunset": 1581990577,
#         "type": 1
#     },
#     "timezone": -28800,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 17,
#         "speed": 14.5
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 18
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -0.6,
#         "lon": 73.08
#     },
#     "dt": 1581963125,
#     "id": 1282256,
#     "main": {
#         "feels_like": 90.3,
#         "grnd_level": 1012,
#         "humidity": 73,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 83.91,
#         "temp_max": 83.91,
#         "temp_min": 83.91
#     },
#     "name": "Hithadhoo",
#     "rain": {
#         "3h": 1
#     },
#     "sys": {
#         "country": "MV",
#         "sunrise": 1581902278,
#         "sunset": 1581945948
#     },
#     "timezone": 18000,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 72,
#         "speed": 6.33
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "stations",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.59,
#         "lon": 26.89
#     },
#     "dt": 1581963125,
#     "id": 964432,
#     "main": {
#         "feels_like": 75.29,
#         "humidity": 88,
#         "pressure": 1019,
#         "temp": 70,
#         "temp_max": 70,
#         "temp_min": 70
#     },
#     "name": "Port Alfred",
#     "rain": {
#         "3h": 0.63
#     },
#     "sys": {
#         "country": "ZA",
#         "id": 2011314,
#         "sunrise": 1581911370,
#         "sunset": 1581959026,
#         "type": 3
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 286,
#         "gust": 4,
#         "speed": 1.01
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 63.73,
#         "lon": 8.83
#     },
#     "dt": 1581963126,
#     "id": 3139597,
#     "main": {
#         "feels_like": 24.19,
#         "humidity": 93,
#         "pressure": 968,
#         "temp": 41.9,
#         "temp_max": 43,
#         "temp_min": 41
#     },
#     "name": "Sistranda",
#     "sys": {
#         "country": "NO",
#         "id": 1647,
#         "sunrise": 1581923647,
#         "sunset": 1581955418,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "shower rain",
#             "icon": "09n",
#             "id": 521,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "speed": 27.51
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 57
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.93,
#         "lon": 29
#     },
#     "dt": 1581963126,
#     "id": 890516,
#     "main": {
#         "feels_like": 76.96,
#         "grnd_level": 904,
#         "humidity": 61,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 76.59,
#         "temp_max": 76.59,
#         "temp_min": 76.59
#     },
#     "name": "Gwanda",
#     "sys": {
#         "country": "ZW",
#         "sunrise": 1581911734,
#         "sunset": 1581957649
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 97,
#         "speed": 6.6
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -28.65,
#         "lon": 153.62
#     },
#     "dt": 1581963126,
#     "id": 2172880,
#     "main": {
#         "feels_like": 77.04,
#         "humidity": 94,
#         "pressure": 1010,
#         "temp": 70.59,
#         "temp_max": 75,
#         "temp_min": 68
#     },
#     "name": "Byron Bay",
#     "sys": {
#         "country": "AU",
#         "id": 9486,
#         "sunrise": 1581967750,
#         "sunset": 1582014611,
#         "type": 1
#     },
#     "timezone": 39600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 259,
#         "speed": 1.05
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 29
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -30.18,
#         "lon": -50.21
#     },
#     "dt": 1581963127,
#     "id": 3466165,
#     "main": {
#         "feels_like": 76.62,
#         "grnd_level": 1010,
#         "humidity": 87,
#         "pressure": 1010,
#         "sea_level": 1010,
#         "temp": 77.72,
#         "temp_max": 77.72,
#         "temp_min": 77.72
#     },
#     "name": "Cidreira",
#     "rain": {
#         "3h": 2
#     },
#     "sys": {
#         "country": "BR",
#         "sunrise": 1581930142,
#         "sunset": 1581977261
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10d",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 42,
#         "speed": 18.84
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 65
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -34.53,
#         "lon": 20.04
#     },
#     "dt": 1581963127,
#     "id": 1015776,
#     "main": {
#         "feels_like": 66.94,
#         "humidity": 68,
#         "pressure": 1020,
#         "temp": 68,
#         "temp_max": 68,
#         "temp_min": 68
#     },
#     "name": "Bredasdorp",
#     "sys": {
#         "country": "ZA",
#         "id": 1966,
#         "sunrise": 1581912940,
#         "sunset": 1581960744,
#         "type": 1
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 200,
#         "speed": 5.82
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 51.37,
#         "lon": 12.73
#     },
#     "dt": 1581963127,
#     "id": 2805597,
#     "main": {
#         "feels_like": 35.69,
#         "humidity": 70,
#         "pressure": 1014,
#         "temp": 45.73,
#         "temp_max": 46.99,
#         "temp_min": 44.01
#     },
#     "name": "Wurzen",
#     "sys": {
#         "country": "DE",
#         "id": 1273,
#         "sunrise": 1581920420,
#         "sunset": 1581956773,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02n",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 210,
#         "speed": 12.75
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 49
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -16.92,
#         "lon": 35.26
#     },
#     "dt": 1581963128,
#     "id": 924572,
#     "main": {
#         "feels_like": 81.99,
#         "grnd_level": 991,
#         "humidity": 91,
#         "pressure": 1011,
#         "sea_level": 1011,
#         "temp": 75.31,
#         "temp_max": 75.31,
#         "temp_min": 75.31
#     },
#     "name": "Nsanje",
#     "sys": {
#         "country": "MW",
#         "sunrise": 1581910470,
#         "sunset": 1581955908
#     },
#     "timezone": 7200,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 121,
#         "speed": 4.03
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.52,
#         "lon": 57.52
#     },
#     "dt": 1581963128,
#     "id": 933995,
#     "main": {
#         "feels_like": 83.57,
#         "humidity": 94,
#         "pressure": 1016,
#         "temp": 76.62,
#         "temp_max": 77,
#         "temp_min": 75.99
#     },
#     "name": "Souillac",
#     "sys": {
#         "country": "MU",
#         "id": 2061,
#         "sunrise": 1581904912,
#         "sunset": 1581950782,
#         "type": 1
#     },
#     "timezone": 14400,
#     "visibility": 6000,
#     "weather": [
#         {
#             "description": "shower rain",
#             "icon": "09n",
#             "id": 521,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 50,
#         "speed": 5.82
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 61.88,
#         "lon": 50.75
#     },
#     "dt": 1581963128,
#     "id": 463880,
#     "main": {
#         "feels_like": 20.82,
#         "humidity": 99,
#         "pressure": 987,
#         "temp": 32,
#         "temp_max": 32,
#         "temp_min": 32
#     },
#     "name": "Zelenets",
#     "sys": {
#         "country": "RU",
#         "id": 9036,
#         "sunrise": 1581913139,
#         "sunset": 1581945805,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 1000,
#     "weather": [
#         {
#             "description": "shower snow",
#             "icon": "13n",
#             "id": 621,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "speed": 13.42
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 46.09,
#         "lon": 3.45
#     },
#     "dt": 1581963129,
#     "id": 3013748,
#     "main": {
#         "feels_like": 39.49,
#         "humidity": 61,
#         "pressure": 1026,
#         "temp": 46.13,
#         "temp_max": 50,
#         "temp_min": 41
#     },
#     "name": "Hauterive",
#     "sys": {
#         "country": "FR",
#         "id": 6496,
#         "sunrise": 1581922030,
#         "sunset": 1581959617,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 190,
#         "speed": 5.82
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 90
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 57.79,
#         "lon": -152.41
#     },
#     "dt": 1581963129,
#     "id": 5866583,
#     "main": {
#         "feels_like": 25.83,
#         "humidity": 86,
#         "pressure": 1004,
#         "temp": 39.2,
#         "temp_max": 39.2,
#         "temp_min": 39.2
#     },
#     "name": "Kodiak",
#     "sys": {
#         "country": "US",
#         "id": 7668,
#         "sunrise": 1581960966,
#         "sunset": 1581995491,
#         "type": 1
#     },
#     "timezone": -32400,
#     "visibility": 11265,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04d",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 140,
#         "gust": 25.28,
#         "speed": 18.34
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -9.43,
#         "lon": 159.95
#     },
#     "dt": 1581963130,
#     "id": 2108502,
#     "main": {
#         "feels_like": 79.23,
#         "grnd_level": 962,
#         "humidity": 92,
#         "pressure": 1003,
#         "sea_level": 1003,
#         "temp": 73.47,
#         "temp_max": 73.47,
#         "temp_min": 73.47
#     },
#     "name": "Honiara",
#     "rain": {
#         "3h": 1.63
#     },
#     "sys": {
#         "country": "SB",
#         "sunrise": 1581967370,
#         "sunset": 1582011953
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "light rain",
#             "icon": "10n",
#             "id": 500,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 207,
#         "speed": 4.25
#     }
# }
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "cod": "404",
#     "message": "city not found"
# }
# City not found
# {
#     "base": "model",
#     "clouds": {
#         "all": 43
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -38.27,
#         "lon": 141.97
#     },
#     "dt": 1581963131,
#     "id": 2171099,
#     "main": {
#         "feels_like": 62.22,
#         "grnd_level": 1005,
#         "humidity": 88,
#         "pressure": 1006,
#         "sea_level": 1006,
#         "temp": 62.91,
#         "temp_max": 62.91,
#         "temp_min": 62.91
#     },
#     "name": "Codrington",
#     "sys": {
#         "country": "AU",
#         "sunrise": 1581969805,
#         "sunset": 1582018148
#     },
#     "timezone": 39600,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 231,
#         "speed": 6.55
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 22.29,
#         "lon": 114.16
#     },
#     "dt": 1581962967,
#     "id": 1819729,
#     "main": {
#         "feels_like": 44.37,
#         "humidity": 35,
#         "pressure": 1027,
#         "temp": 54.93,
#         "temp_max": 59,
#         "temp_min": 53.6
#     },
#     "name": "Hong Kong",
#     "sys": {
#         "country": "HK",
#         "id": 9154,
#         "sunrise": 1581980022,
#         "sunset": 1582021279,
#         "type": 1
#     },
#     "timezone": 28800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 50,
#         "speed": 11.41
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 3
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -37.62,
#         "lon": -73.65
#     },
#     "dt": 1581963131,
#     "id": 3883457,
#     "main": {
#         "feels_like": 62.4,
#         "grnd_level": 1000,
#         "humidity": 39,
#         "pressure": 1019,
#         "sea_level": 1019,
#         "temp": 69.26,
#         "temp_max": 69.26,
#         "temp_min": 69.26
#     },
#     "name": "Lebu",
#     "sys": {
#         "country": "CL",
#         "sunrise": 1581935183,
#         "sunset": 1581983470
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 225,
#         "speed": 9.42
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -35.17,
# ...
#     "id": 1337619,
#     "main": {
#         "feels_like": 83.05,
#         "grnd_level": 1013,
#         "humidity": 80,
#         "pressure": 1012,
#         "sea_level": 1012,
#         "temp": 81.84,
#         "temp_max": 81.84,
#         "temp_min": 81.84
#     },
#     "name": "Ugoofaaru",
#     "sys": {
#         "country": "MV",
#         "sunrise": 1581902623,
#         "sunset": 1581945641
#     },
#     "timezone": 18000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 70,
#         "speed": 16.28
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 50
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -36.82,
#         "lon": 174.45
#     },
#     "dt": 1581963327,
#     "id": 2186363,
#     "main": {
#         "feels_like": 68.67,
#         "humidity": 88,
#         "pressure": 1017,
#         "temp": 66.27,
#         "temp_max": 68,
#         "temp_min": 64
#     },
#     "name": "Muriwai Beach",
#     "sys": {
#         "country": "NZ",
#         "id": 7345,
#         "sunrise": 1581962128,
#         "sunset": 1582010235,
#         "type": 1
#     },
#     "timezone": 46800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 30,
#         "speed": 3.36
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -10.17,
#         "lon": 123.58
#     },
#     "dt": 1581963327,
#     "id": 2057087,
#     "main": {
#         "feels_like": 91.42,
#         "grnd_level": 1009,
#         "humidity": 76,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 84.31,
#         "temp_max": 84.31,
#         "temp_min": 84.31
#     },
#     "name": "Kupang",
#     "sys": {
#         "country": "ID",
#         "sunrise": 1581976061,
#         "sunset": 1582020719
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 199,
#         "speed": 6.71
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 18.39,
#         "lon": 42.45
#     },
#     "dt": 1581963327,
#     "id": 110690,
#     "main": {
#         "feels_like": 62.17,
#         "humidity": 63,
#         "pressure": 1025,
#         "temp": 64.33,
#         "temp_max": 66.2,
#         "temp_min": 62.6
#     },
#     "name": "Faya",
#     "sys": {
#         "country": "SA",
#         "id": 7396,
#         "sunrise": 1581910639,
#         "sunset": 1581952289,
#         "type": 1
#     },
#     "timezone": 10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 200,
#         "speed": 4.7
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 12.25,
#         "lon": 109.18
#     },
#     "dt": 1581963189,
#     "id": 1572151,
#     "main": {
#         "feels_like": 74.43,
#         "humidity": 73,
#         "pressure": 1018,
#         "temp": 77,
#         "temp_max": 77,
#         "temp_min": 77
#     },
#     "name": "Nha Trang",
#     "sys": {
#         "country": "VN",
#         "id": 9304,
#         "sunrise": 1581980668,
#         "sunset": 1582023023,
#         "type": 1
#     },
#     "timezone": 25200,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 20,
#         "speed": 16.11
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 36
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 4.31,
#         "lon": -72.08
#     },
#     "dt": 1581963053,
#     "id": 3769976,
#     "main": {
#         "feels_like": 95.16,
#         "grnd_level": 989,
#         "humidity": 24,
#         "pressure": 1007,
#         "sea_level": 1007,
#         "temp": 100,
#         "temp_max": 100,
#         "temp_min": 100
#     },
#     "name": "Puerto Gaitan",
#     "sys": {
#         "country": "CO",
#         "sunrise": 1581937368,
#         "sunset": 1581980532
#     },
#     "timezone": -18000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03d",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 42,
#         "speed": 12.33
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 96
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 12.71,
#         "lon": 104.89
#     },
#     "dt": 1581963328,
#     "id": 1831125,
#     "main": {
#         "feels_like": 76.77,
#         "grnd_level": 1014,
#         "humidity": 53,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 78.55,
#         "temp_max": 78.55,
#         "temp_min": 78.55
#     },
#     "name": "Kampong Thom",
#     "sys": {
#         "country": "KH",
#         "sunrise": 1581981721,
#         "sunset": 1582024029
#     },
#     "timezone": 25200,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 87,
#         "speed": 8.95
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 12.78,
#         "lon": 76.24
#     },
#     "dt": 1581963329,
#     "id": 1269985,
#     "main": {
#         "feels_like": 58.93,
#         "grnd_level": 909,
#         "humidity": 24,
#         "pressure": 1015,
#         "sea_level": 1015,
#         "temp": 66.13,
#         "temp_max": 66.13,
#         "temp_min": 66.13
#     },
#     "name": "Holenarasipura",
#     "sys": {
#         "country": "IN",
#         "sunrise": 1581902222,
#         "sunset": 1581944487
#     },
#     "timezone": 19800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 71,
#         "speed": 5.53
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 63.66,
#         "lon": 9.57
#     },
#     "dt": 1581963329,
#     "id": 3160100,
#     "main": {
#         "feels_like": 22.39,
#         "humidity": 93,
#         "pressure": 968,
#         "temp": 40.39,
#         "temp_max": 43,
#         "temp_min": 37
#     },
#     "name": "Beian",
#     "sys": {
#         "country": "NO",
#         "id": 1647,
#         "sunrise": 1581923451,
#         "sunset": 1581955258,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "shower rain",
#             "icon": "09n",
#             "id": 521,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 250,
#         "speed": 27.51
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -33.19,
#         "lon": -68.46
#     },
#     "dt": 1581963329,
#     "id": 3838759,
#     "main": {
#         "feels_like": 75.76,
#         "humidity": 57,
#         "pressure": 1005,
#         "temp": 78.8,
#         "temp_max": 78.8,
#         "temp_min": 78.8
#     },
#     "name": "Rivadavia",
#     "sys": {
#         "country": "AR",
#         "id": 8238,
#         "sunrise": 1581934300,
#         "sunset": 1581981863,
#         "type": 1
#     },
#     "timezone": -10800,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04d",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 140,
#         "speed": 12.75
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 20
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 46.13,
#         "lon": -67.84
#     },
#     "dt": 1581963330,
#     "id": 4967563,
#     "main": {
#         "feels_like": 6.66,
#         "humidity": 57,
#         "pressure": 1020,
#         "temp": 20.39,
#         "temp_max": 23,
#         "temp_min": 17.6
#     },
#     "name": "Houlton",
#     "sys": {
#         "country": "US",
#         "id": 4439,
#         "sunrise": 1581939125,
#         "sunset": 1581976740,
#         "type": 1
#     },
#     "timezone": -18000,
#     "visibility": 16093,
#     "weather": [
#         {
#             "description": "few clouds",
#             "icon": "02d",
#             "id": 801,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 360,
#         "gust": 20.8,
#         "speed": 13.87
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 44.62,
#         "lon": 21.18
#     },
#     "dt": 1581963330,
#     "id": 786827,
#     "main": {
#         "feels_like": 42.49,
#         "humidity": 53,
#         "pressure": 1020,
#         "temp": 47.44,
#         "temp_max": 50,
#         "temp_min": 45
#     },
#     "name": "Pozarevac",
#     "sys": {
#         "country": "RS",
#         "id": 7045,
#         "sunrise": 1581917630,
#         "sunset": 1581955507,
#         "type": 1
#     },
#     "timezone": 3600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "broken clouds",
#             "icon": "04n",
#             "id": 803,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "speed": 2.24
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -3.37,
#         "lon": 135.48
#     },
#     "dt": 1581963330,
#     "id": 1634614,
#     "main": {
#         "feels_like": 78.21,
#         "grnd_level": 988,
#         "humidity": 98,
#         "pressure": 1009,
#         "sea_level": 1009,
#         "temp": 71.42,
#         "temp_max": 71.42,
#         "temp_min": 71.42
#     },
#     "name": "Nabire",
#     "rain": {
#         "3h": 3.88
#     },
#     "sys": {
#         "country": "ID",
#         "sunrise": 1581973558,
#         "sunset": 1582017509
#     },
#     "timezone": 32400,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10n",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 138,
#         "speed": 2.26
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 18.69,
#         "lon": 12.92
#     },
#     "dt": 1581963186,
#     "id": 2446796,
#     "main": {
#         "feels_like": 61.11,
#         "grnd_level": 962,
#         "humidity": 20,
#         "pressure": 1014,
#         "sea_level": 1014,
#         "temp": 68.7,
#         "temp_max": 68.7,
#         "temp_min": 68.7
#     },
#     "name": "Bilma",
#     "sys": {
#         "country": "NE",
#         "sunrise": 1581917740,
#         "sunset": 1581959361
#     },
#     "timezone": 3600,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 19,
#         "speed": 5.75
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 78
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -6.4,
#         "lon": -48.55
#     },
#     "dt": 1581963331,
#     "id": 3388760,
#     "main": {
#         "feels_like": 97.3,
#         "grnd_level": 985,
#         "humidity": 82,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 84.83,
#         "temp_max": 84.83,
#         "temp_min": 84.83
#     },
#     "name": "Sao Geraldo do Araguaia",
#     "rain": {
#         "3h": 4.12
#     },
#     "sys": {
#         "country": "BR",
#         "sunrise": 1581931166,
#         "sunset": 1581975440
#     },
#     "timezone": -10800,
#     "weather": [
#         {
#             "description": "moderate rain",
#             "icon": "10d",
#             "id": 501,
#             "main": "Rain"
#         }
#     ],
#     "wind": {
#         "deg": 312,
#         "speed": 0.31
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 14.3,
#         "lon": -91.92
#     },
#     "dt": 1581963331,
#     "id": 3598787,
#     "main": {
#         "feels_like": 92.12,
#         "humidity": 58,
#         "pressure": 1013,
#         "temp": 87.8,
#         "temp_max": 87.8,
#         "temp_min": 87.8
#     },
#     "name": "Champerico",
#     "sys": {
#         "country": "GT",
#         "id": 7068,
#         "sunrise": 1581942651,
#         "sunset": 1581984771,
#         "type": 1
#     },
#     "timezone": -21600,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01d",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 180,
#         "speed": 6.93
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 42.95,
#         "lon": 72.76
#     },
#     "dt": 1581963332,
#     "id": 1521293,
#     "main": {
#         "feels_like": 23.59,
#         "grnd_level": 952,
#         "humidity": 73,
#         "pressure": 1034,
#         "sea_level": 1034,
#         "temp": 29.7,
#         "temp_max": 29.7,
#         "temp_min": 29.7
#     },
#     "name": "Lugovoy",
#     "sys": {
#         "country": "KZ",
#         "sunrise": 1581991416,
#         "sunset": 1582029756
#     },
#     "timezone": 21600,
#     "weather": [
#         {
#             "description": "overcast clouds",
#             "icon": "04n",
#             "id": 804,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 107,
#         "speed": 2.33
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 0
#     },
#     "cod": 200,
#     "coord": {
#         "lat": -20.74,
#         "lon": 116.85
#     },
#     "dt": 1581963332,
#     "id": 6620339,
#     "main": {
#         "feels_like": 82.85,
#         "grnd_level": 1008,
#         "humidity": 80,
#         "pressure": 1008,
#         "sea_level": 1008,
#         "temp": 82.15,
#         "temp_max": 82.15,
#         "temp_min": 82.15
#     },
#     "name": "Karratha",
#     "sys": {
#         "country": "AU",
#         "sunrise": 1581977085,
#         "sunset": 1582022925
#     },
#     "timezone": 28800,
#     "weather": [
#         {
#             "description": "clear sky",
#             "icon": "01n",
#             "id": 800,
#             "main": "Clear"
#         }
#     ],
#     "wind": {
#         "deg": 243,
#         "speed": 17.49
#     }
# }
# {
#     "base": "model",
#     "clouds": {
#         "all": 100
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 56.27,
#         "lon": 51.51
#     },
#     "dt": 1581963332,
#     "id": 547831,
#     "main": {
#         "feels_like": 16.03,
#         "grnd_level": 993,
#         "humidity": 95,
#         "pressure": 1013,
#         "sea_level": 1013,
#         "temp": 30.99,
#         "temp_max": 30.99,
#         "temp_min": 30.99
#     },
#     "name": "Kizner",
#     "snow": {
#         "3h": 2.25
#     },
#     "sys": {
#         "country": "RU",
#         "sunrise": 1581911846,
#         "sunset": 1581946734
#     },
#     "timezone": 14400,
#     "weather": [
#         {
#             "description": "snow",
#             "icon": "13n",
#             "id": 601,
#             "main": "Snow"
#         }
#     ],
#     "wind": {
#         "deg": 220,
#         "speed": 19.64
#     }
# }
# {
#     "base": "stations",
#     "clouds": {
#         "all": 40
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 53.63,
#         "lon": -8.18
#     },
#     "dt": 1581963333,
#     "id": 2961732,
#     "main": {
#         "feels_like": 18.05,
#         "humidity": 73,
#         "pressure": 1007,
#         "temp": 35.78,
#         "temp_max": 36,
#         "temp_min": 35.6
#     },
#     "name": "Roscommon",
#     "sys": {
#         "country": "IE",
#         "id": 1566,
#         "sunrise": 1581925740,
#         "sunset": 1581961489,
#         "type": 1
#     },
#     "timezone": 0,
#     "visibility": 10000,
#     "weather": [
#         {
#             "description": "scattered clouds",
#             "icon": "03n",
#             "id": 802,
#             "main": "Clouds"
#         }
#     ],
#     "wind": {
#         "deg": 260,
#         "speed": 24.16
#     }
# }

# %%
data_list = {"City" : city_name, 
              "Cloudiness" : cloudiness, 
              "Country" : country, 
              "Date" : date, 
              "Humidity" : humidity, 
              "Latitude" : lat, 
              "Longitude" : lng, 
              "Max Temp" : max_temp, 
              "Wind Speed" : wind_speed}
plot_data = pd.DataFrame(data_list)
plot_data.count()
# Out:
# City          582
# Cloudiness    582
# Country       582
# Date          582
# Humidity      582
# Latitude      582
# Longitude     582
# Max Temp      582
# Wind Speed    582
# dtype: int64

# %%
plot_data
# Out:
#              City  Cloudiness Country        Date  Humidity  Latitude  \
# 0           Vaini          40      TO  1581963109        78    -21.20
# 1          Olinda          75      BR  1581962826        66     -8.01
# 2     George Town          20      MY  1581962992        88      5.41
# 3    Punta Arenas          90      CL  1581963110        50    -53.15
# 4         Mataura         100      NZ  1581963111        97    -46.19
# ..            ...         ...     ...         ...       ...       ...
# 577    Champerico           0      GT  1581963331        58     14.30
# 578       Lugovoy         100      KZ  1581963332        73     42.95
# 579      Karratha           0      AU  1581963332        80    -20.74
# 580        Kizner         100      RU  1581963332        95     56.27
# 581     Roscommon          40      IE  1581963333        73     53.63
#
#      Longitude  Max Temp  Wind Speed
# 0      -175.20     77.00        8.05
# 1       -34.86     87.80       10.29
# 2       100.34     82.40        8.05
# 3       -70.92     51.80       16.11
# 4       168.86     55.00        1.99
# ..         ...       ...         ...
# 577     -91.92     87.80        6.93
# 578      72.76     29.70        2.33
# 579     116.85     82.15       17.49
# 580      51.51     30.99       19.64
# 581      -8.18     36.00       24.16
#
# [582 rows x 9 columns]

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Max Temp"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Max Temperature")
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsMaxTemp.png")

# Lets take a look
plt.show()

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Humidity"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Humidity")
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsHumidity.png")

# Lets take a look
plt.show()

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Cloudiness"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Cloudiness")
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsCloudiness.png")

# Lets take a look
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Building a scatter plot for Lat and max temp
plt.scatter(plot_data["Latitude"], plot_data["Wind Speed"])

# Incorporating the other graph properties
plt.title("City Latitude vs. Wind Speed")
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Saving the figure
plt.savefig("LatvsWindSpeed.png")

# Lets take a look
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
(slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
regress_values = x_values * slope + intercept
line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_data = plot_data.loc[plot_data['Latitude'] > 0,:]
southern_data = plot_data.loc[plot_data['Latitude'] < 0,:]
# Out:
#                         City  Cloudiness Country        Date  Humidity  \
# 0                      Vaini          40      TO  1581963109        78
# 1                     Olinda          75      BR  1581962826        66
# 3               Punta Arenas          90      CL  1581963110        50
# 4                    Mataura         100      NZ  1581963111        97
# 5                     Hobart           3      AU  1581963111        81
# ..                       ...         ...     ...         ...       ...
# 564                   Kupang         100      ID  1581963327        76
# 571                Rivadavia          75      AR  1581963329        57
# 574                   Nabire         100      ID  1581963330        98
# 576  Sao Geraldo do Araguaia          78      BR  1581963331        82
# 579                 Karratha           0      AU  1581963332        80
#
#      Latitude  Longitude  Max Temp  Wind Speed
# 0      -21.20    -175.20     77.00        8.05
# 1       -8.01     -34.86     87.80       10.29
# 3      -53.15     -70.92     51.80       16.11
# 4      -46.19     168.86     55.00        1.99
# 5      -42.88     147.33     50.00        8.05
# ..        ...        ...       ...         ...
# 564    -10.17     123.58     84.31        6.71
# 571    -33.19     -68.46     78.80       12.75
# 574     -3.37     135.48     71.42        2.26
# 576     -6.40     -48.55     84.83        0.31
# 579    -20.74     116.85     82.15       17.49
#
# [179 rows x 9 columns]

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression
